# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.metrics import mean_squared_error,mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score
color_pal=sns.color_palette()

# %%
df=pd.read_csv('product k.csv', parse_dates=['Month-Year'], index_col='Month-Year')

# %%
df.head()
# Out:
#            Product Name Product Category     Month  Year   Sales  Market Size  \
# Month-Year
# 2019-01-01    Product K     Multivitamin   January  2019  505010       797644
# 2019-02-01    Product K     Multivitamin  February  2019  521132       823109
# 2019-03-01    Product K     Multivitamin     March  2019  580897       917505
# 2019-04-01    Product K     Multivitamin     April  2019  612559       967514
# 2019-05-01    Product K     Multivitamin       May  2019  550697       869805
#
#             Marketing Expense  Month No.
# Month-Year
# 2019-01-01            8355561          1
# 2019-02-01            8622305          2
# 2019-03-01            9611137          3
# 2019-04-01           10134996          4
# 2019-05-01            9111468          5

# %%
sales_k= df.drop(['Product Name','Product Category','Month','Market Size', 'Marketing Expense'],axis=1)

# %%
sales_k.head()
# Out:
#             Year   Sales  Month No.
# Month-Year
# 2019-01-01  2019  505010          1
# 2019-02-01  2019  521132          2
# 2019-03-01  2019  580897          3
# 2019-04-01  2019  612559          4
# 2019-05-01  2019  550697          5

# %%
sales_k['Sales'].plot(figsize=(12,6),color=color_pal[2],title='Product K')
# Out:
# <Axes: title={'center': 'Product K'}, xlabel='Month-Year'>

# %%
sales_k['Sales'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Visualization

# %%
sales_k.head()
# Out:
#             Year   Sales  Month No.
# Month-Year
# 2019-01-01  2019  505010          1
# 2019-02-01  2019  521132          2
# 2019-03-01  2019  580897          3
# 2019-04-01  2019  612559          4
# 2019-05-01  2019  550697          5

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=sales_k, x='Month No.',y='Sales')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=sales_k, x='Year',y='Sales')
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
sales_k = df.drop(['Product Name','Product Category','Month','Market Size', 'Marketing Expense','Month No.','Year'],axis=1)

# %%
sales_k['quarter'] = sales_k.index.quarter
sales_k['month'] = sales_k.index.month
sales_k['year'] = sales_k.index.year

# %%
# Create lagged values
lagged_intervals = [6, 7, 8]  # Lagged intervals in months
for lag in lagged_intervals:
    sales_k[f'sales_lag_{lag}'] = sales_k['Sales'].shift(lag)

# %%
print(sales_k)
# Out:
#               Sales  quarter  month  year  sales_lag_6  sales_lag_7  \
# Month-Year
# 2019-01-01   505010        1      1  2019          NaN          NaN
# 2019-02-01   521132        1      2  2019          NaN          NaN
# 2019-03-01   580897        1      3  2019          NaN          NaN
# 2019-04-01   612559        2      4  2019          NaN          NaN
# 2019-05-01   550697        2      5  2019          NaN          NaN
# 2019-06-01   552137        2      6  2019          NaN          NaN
# 2019-07-01   489712        3      7  2019     505010.0          NaN
# 2019-08-01   597098        3      8  2019     521132.0     505010.0
# 2019-09-01   621078        3      9  2019     580897.0     521132.0
# 2019-10-01   543258        4     10  2019     612559.0     580897.0
# 2019-11-01   746408        4     11  2019     550697.0     612559.0
# 2019-12-01   537548        4     12  2019     552137.0     550697.0
# 2020-01-01   312081        1      1  2020     489712.0     552137.0
# 2020-02-01   455033        1      2  2020     597098.0     489712.0
# 2020-03-01   784102        1      3  2020     621078.0     597098.0
# 2020-04-01   359512        2      4  2020     543258.0     621078.0
# 2020-05-01   438162        2      5  2020     746408.0     543258.0
# 2020-06-01   951340        2      6  2020     537548.0     746408.0
# 2020-07-01   225570        3      7  2020     312081.0     537548.0
# 2020-08-01   402391        3      8  2020     455033.0     312081.0
# 2020-09-01   769842        3      9  2020     784102.0     455033.0
# 2020-10-01   327210        4     10  2020     359512.0     784102.0
# 2020-11-01   753134        4     11  2020     438162.0     359512.0
# 2020-12-01   568885        4     12  2020     951340.0     438162.0
# 2021-01-01   243900        1      1  2021     225570.0     951340.0
# 2021-02-01   378867        1      2  2021     402391.0     225570.0
# 2021-03-01   806927        1      3  2021     769842.0     402391.0
# 2021-04-01   266371        2      4  2021     327210.0     769842.0
# 2021-05-01   790707        2      5  2021     753134.0     327210.0
# 2021-06-01   301207        2      6  2021     568885.0     753134.0
# 2021-07-01   733971        3      7  2021     243900.0     568885.0
# 2021-08-01   317170        3      8  2021     378867.0     243900.0
# 2021-09-01   768197        3      9  2021     806927.0     378867.0
# 2021-10-01   327569        4     10  2021     266371.0     806927.0
# 2021-11-01   745295        4     11  2021     790707.0     266371.0
# 2021-12-01   590751        4     12  2021     301207.0     790707.0
# 2022-01-01   230200        1      1  2022     733971.0     301207.0
# 2022-02-01   380866        1      2  2022     317170.0     733971.0
# 2022-03-01  1003679        1      3  2022     768197.0     317170.0
# 2022-04-01   226939        2      4  2022     327569.0     768197.0
# 2022-05-01   826087        2      5  2022     745295.0     327569.0
# 2022-06-01   236473        2      6  2022     590751.0     745295.0
# 2022-07-01   784789        3      7  2022     230200.0     590751.0
# 2022-08-01   329037        3      8  2022     380866.0     230200.0
# 2022-09-01   819358        3      9  2022    1003679.0     380866.0
# 2022-10-01   330845        4     10  2022     226939.0    1003679.0
# 2022-11-01   778835        4     11  2022     826087.0     226939.0
# 2022-12-01   412174        4     12  2022     236473.0     826087.0
# 2023-01-01   234804        1      1  2023     784789.0     236473.0
# 2023-02-01   405296        1      2  2023     329037.0     784789.0
# 2023-03-01   820679        1      3  2023     819358.0     329037.0
# 2023-04-01   320174        2      4  2023     330845.0     819358.0
# 2023-05-01   842609        2      5  2023     778835.0     330845.0
# 2023-06-01   316593        2      6  2023     412174.0     778835.0
# 2023-07-01   800485        3      7  2023     234804.0     412174.0
# 2023-08-01   335618        3      8  2023     405296.0     234804.0
# 2023-09-01   835745        3      9  2023     820679.0     405296.0
# 2023-10-01   337462        4     10  2023     320174.0     820679.0
# 2023-11-01   794412        4     11  2023     842609.0     320174.0
# 2023-12-01   420417        4     12  2023     316593.0     842609.0
#
#             sales_lag_8
# Month-Year
# 2019-01-01          NaN
# 2019-02-01          NaN
# 2019-03-01          NaN
# 2019-04-01          NaN
# 2019-05-01          NaN
# 2019-06-01          NaN
# 2019-07-01          NaN
# 2019-08-01          NaN
# 2019-09-01     505010.0
# 2019-10-01     521132.0
# 2019-11-01     580897.0
# 2019-12-01     612559.0
# 2020-01-01     550697.0
# 2020-02-01     552137.0
# 2020-03-01     489712.0
# 2020-04-01     597098.0
# 2020-05-01     621078.0
# 2020-06-01     543258.0
# 2020-07-01     746408.0
# 2020-08-01     537548.0
# 2020-09-01     312081.0
# 2020-10-01     455033.0
# 2020-11-01     784102.0
# 2020-12-01     359512.0
# 2021-01-01     438162.0
# 2021-02-01     951340.0
# 2021-03-01     225570.0
# 2021-04-01     402391.0
# 2021-05-01     769842.0
# 2021-06-01     327210.0
# 2021-07-01     753134.0
# 2021-08-01     568885.0
# 2021-09-01     243900.0
# 2021-10-01     378867.0
# 2021-11-01     806927.0
# 2021-12-01     266371.0
# 2022-01-01     790707.0
# 2022-02-01     301207.0
# 2022-03-01     733971.0
# 2022-04-01     317170.0
# 2022-05-01     768197.0
# 2022-06-01     327569.0
# 2022-07-01     745295.0
# 2022-08-01     590751.0
# 2022-09-01     230200.0
# 2022-10-01     380866.0
# 2022-11-01    1003679.0
# 2022-12-01     226939.0
# 2023-01-01     826087.0
# 2023-02-01     236473.0
# 2023-03-01     784789.0
# 2023-04-01     329037.0
# 2023-05-01     819358.0
# 2023-06-01     330845.0
# 2023-07-01     778835.0
# 2023-08-01     412174.0
# 2023-09-01     234804.0
# 2023-10-01     405296.0
# 2023-11-01     820679.0
# 2023-12-01     320174.0

# %% [markdown]
# # Train/Test Split

# %%
train= sales_k[:54]
test=sales_k[54:]

# %%
fig,ax=plt.subplots(figsize=(10,4))
train['Sales'].plot(ax=ax,label='Train set',title='Train/Test')
test['Sales'].plot(ax=ax,label='Test set')
plt.legend(['Train','Test'])
plt.show()

# %%
len(train)
# Out:
# 54

# %%
x_train = train.drop(columns=['Sales'])
y_train=train['Sales']
x_test=test.drop(columns=['Sales'])
y_test=test['Sales']

# %%
from sklearn.model_selection import GridSearchCV


# Define the parameter grid
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.001,0.01, 0.1, 0.2],
    'n_estimators': [100, 500, 1000, 2000],
    'colsample_bytree': [0.7, 0.8, 0.9, 1.0],
    'subsample': [0.7, 0.8, 0.9, 1.0]
}

# Instantiate the XGBoost regressor
regressor = xgb.XGBRegressor(objective='reg:squarederror')

# Instantiate GridSearchCV
grid_search = GridSearchCV(estimator=regressor, param_grid=param_grid, 
                           cv=5, scoring='neg_mean_squared_error', 
                           verbose=2, n_jobs=-1)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Access the best parameters
best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

print("Best parameters:", best_params)
print("Best estimator:", best_estimator)
# Out:
# Fitting 5 folds for each of 768 candidates, totalling 3840 fits
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.001, 'max_depth': 7, 'n_estimators': 2000, 'subsample': 0.7}
# Best estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.001, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=2000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=2000,
                       objective='reg:squarederror',
                       max_depth=7,
                       colsample_bytree=0.7,
                       subsample= 0.7,
                       early_stopping_rounds=50,
                       learning_rate=0.001)

reg.fit(x_train, y_train,
        eval_set=[(x_train, y_train), (x_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:574999.20009	validation_1-rmse:628499.55489
# [100]	validation_0-rmse:527869.37284	validation_1-rmse:582527.14451
# [200]	validation_0-rmse:485136.96341	validation_1-rmse:540463.62841
# [300]	validation_0-rmse:447223.70229	validation_1-rmse:503413.71157
# [400]	validation_0-rmse:412677.79060	validation_1-rmse:468282.88239
# [500]	validation_0-rmse:381141.10144	validation_1-rmse:436311.15757
# [600]	validation_0-rmse:352545.83136	validation_1-rmse:406101.96022
# [700]	validation_0-rmse:326509.92064	validation_1-rmse:379336.75351
# [800]	validation_0-rmse:302630.60609	validation_1-rmse:355269.95155
# [900]	validation_0-rmse:281162.78451	validation_1-rmse:331982.60080
# [1000]	validation_0-rmse:261619.77365	validation_1-rmse:311316.12736
# [1100]	validation_0-rmse:243587.08687	validation_1-rmse:291046.55180
# [1200]	validation_0-rmse:227160.99105	validation_1-rmse:272441.88671
# [1300]	validation_0-rmse:212113.64623	validation_1-rmse:255042.93566
# [1400]	validation_0-rmse:198137.75720	validation_1-rmse:239537.56658
# [1500]	validation_0-rmse:185596.06358	validation_1-rmse:225049.43504
# [1600]	validation_0-rmse:173839.25500	validation_1-rmse:211845.32028
# [1700]	validation_0-rmse:163229.33611	validation_1-rmse:199941.53236
# [1800]	validation_0-rmse:153523.05396	validation_1-rmse:188954.78728
# [1900]	validation_0-rmse:144389.23707	validation_1-rmse:179169.44180
# [1999]	validation_0-rmse:136126.41192	validation_1-rmse:169532.54319
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.001, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=2000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
reg.best_iteration
# Out:
# 1999

# %%
results = reg.evals_result()

plt.figure(figsize=(10,7))
plt.plot(results["validation_0"]["rmse"], label="Training loss")
plt.plot(results["validation_1"]["rmse"], label="Validation loss")
plt.axvline(1999,color='green',ls='--', label="Optimal tree number")
plt.xlabel("Number of trees")
plt.ylabel("Loss")
plt.legend()

# %%
pred=reg.predict(x_test)
sales_k['prediction']=[None]*len(train) + list(pred)

ax = sales_k['Sales'].plot(figsize=(15, 5))
sales_k['prediction'].plot()
plt.legend(['Actual Sales', 'Predictions'])
ax.set_title('Product K: Actual Sales and Prediction')
plt.show()

# %%
mae_xgb= mean_absolute_error(test['Sales'],pred)
mse_xgb=mean_squared_error(test['Sales'], pred)
mape_xgb= mean_absolute_percentage_error(test['Sales'],pred)
rmse_xgb= np.sqrt(mean_squared_error(test['Sales'],pred))

print(f'MAE - XGBoost: {mae_xgb:0.3f}')
print(f'MAPE - XGBoost: {mape_xgb:0.3f}')
print(f'MSE - XGBoost: {mse_xgb:0.3f}')
print(f'RMSE - XGBoost: {rmse_xgb:0.3f}')
# Out:
# MAE - XGBoost: 149127.409
# MAPE - XGBoost: 0.246
# MSE - XGBoost: 28741282650.613
# RMSE - XGBoost: 169532.542

# %%
from xgboost import plot_importance

_ = plot_importance(reg, height=0.9)
