# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.metrics import mean_squared_error,mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score
color_pal=sns.color_palette()

# %%
df=pd.read_csv('product h.csv', parse_dates=['Month-Year'], index_col='Month-Year')

# %%
df.head()
# Out:
#            Product Name               Product Category     Month  Year  Sales  \
# Month-Year
# 2019-01-01    Product H  Anti Biotic Upper Respiratory   January  2019  62686
# 2019-02-01    Product H  Anti Biotic Upper Respiratory  February  2019  74426
# 2019-03-01    Product H  Anti Biotic Upper Respiratory     March  2019  91347
# 2019-04-01    Product H  Anti Biotic Upper Respiratory     April  2019  60600
# 2019-05-01    Product H  Anti Biotic Upper Respiratory       May  2019  37374
#
#             Market Size  Marketing Expense  Month No.
# Month-Year
# 2019-01-01       142038             447509          1
# 2019-02-01       168635             531319          2
# 2019-03-01       206976             652116          3
# 2019-04-01       137309             432617          4
# 2019-05-01        84683             266809          5

# %%
sales_h= df.drop(['Product Name','Product Category','Month'],axis=1)

# %%
sales_h.head()
# Out:
#             Year  Sales  Market Size  Marketing Expense  Month No.
# Month-Year
# 2019-01-01  2019  62686       142038             447509          1
# 2019-02-01  2019  74426       168635             531319          2
# 2019-03-01  2019  91347       206976             652116          3
# 2019-04-01  2019  60600       137309             432617          4
# 2019-05-01  2019  37374        84683             266809          5

# %%
sales_h['Sales'].plot(figsize=(12,6),color=color_pal[2],title='Product H')
# Out:
# <Axes: title={'center': 'Product H'}, xlabel='Month-Year'>

# %%
sales_h['Sales'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Visualization

# %%
sales_h.head()
# Out:
#             Year  Sales  Market Size  Marketing Expense  Month No.
# Month-Year
# 2019-01-01  2019  62686       142038             447509          1
# 2019-02-01  2019  74426       168635             531319          2
# 2019-03-01  2019  91347       206976             652116          3
# 2019-04-01  2019  60600       137309             432617          4
# 2019-05-01  2019  37374        84683             266809          5

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=sales_h, x='Month No.',y='Sales')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=sales_h, x='Year',y='Sales')
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
sales_h= df.drop(['Product Name','Product Category','Month','Month No.','Year'],axis=1)

# %%
sales_h['quarter'] = sales_h.index.quarter
sales_h['month'] = sales_h.index.month
sales_h['year'] = sales_h.index.year

# %%
print(sales_h)
# Out:
#              Sales  Market Size  Marketing Expense  quarter  month  year
# Month-Year
# 2019-01-01   62686       142038             447509        1      1  2019
# 2019-02-01   74426       168635             531319        1      2  2019
# 2019-03-01   91347       206976             652116        1      3  2019
# 2019-04-01   60600       137309             432617        2      4  2019
# 2019-05-01   37374        84683             266809        2      5  2019
# 2019-06-01   30737        69648             219428        2      6  2019
# 2019-07-01   29683        67255             211904        3      7  2019
# 2019-08-01   34788        78824             248348        3      8  2019
# 2019-09-01   43408        98356             309885        3      9  2019
# 2019-10-01   64323       214290             675154        4     10  2019
# 2019-11-01   94574       247365             779360        4     11  2019
# 2019-12-01  109171       145748             459195        4     12  2019
# 2020-01-01  108329       151076             118967        1      1  2020
# 2020-02-01   84031       117189              92283        1      2  2020
# 2020-03-01   70140        97819              77027        1      3  2020
# 2020-04-01   49066        68430              53884        2      4  2020
# 2020-05-01   40363        56293              44326        2      5  2020
# 2020-06-01   31950        44556              35087        2      6  2020
# 2020-07-01   26500        36960              29102        3      7  2020
# 2020-08-01   32716        45624              35929        3      8  2020
# 2020-09-01   46216        64457              50754        3      9  2020
# 2020-10-01   64406       161352             127054        4     10  2020
# 2020-11-01  115693       194545             153196        4     11  2020
# 2020-12-01  139498        89824              70730        4     12  2020
# 2021-01-01   81038       138103             118235        1      1  2021
# 2021-02-01   77930       132806             113700        1      2  2021
# 2021-03-01   67706       115384              98784        1      3  2021
# 2021-04-01   49801        84870              72660        2      4  2021
# 2021-05-01   40984        69841              59796        2      5  2021
# 2021-06-01   20298        34593              29615        2      6  2021
# 2021-07-01   39907        68011              58225        3      7  2021
# 2021-08-01   34366        58567              50140        3      8  2021
# 2021-09-01   41168        70160              60064        3      9  2021
# 2021-10-01  104512       182571             156306        4     10  2021
# 2021-11-01  107132       225297             192885        4     11  2021
# 2021-12-01  132203       178105             152484        4     12  2021
# 2022-01-01   65638       123292             172748        1      1  2022
# 2022-02-01  119304       224103             313987        1      2  2022
# 2022-03-01   70494       132418             185528        1      3  2022
# 2022-04-01   56667       106446             149138        2      4  2022
# 2022-05-01   50000        93921             131591        2      5  2022
# 2022-06-01   40000        75138             105273        2      6  2022
# 2022-07-01   39633        74445             104307        3      7  2022
# 2022-08-01   45189        84883             118930        3      8  2022
# 2022-09-01   48868        91791             128612        3      9  2022
# 2022-10-01   78522       199674             279763        4     10  2022
# 2022-11-01  106300       230975             323620        4     11  2022
# 2022-12-01  122964       147497             206656        4     12  2022
# 2023-01-01   70232       113254             267739        1      1  2023
# 2023-02-01   90139       145361             343629        1      2  2023
# 2023-03-01   85600       138040             326326        1      3  2023
# 2023-04-01   60633        97775             231146        2      4  2023
# 2023-05-01   53500        86276             203954        2      5  2023
# 2023-06-01   42800        69017             163163        2      6  2023
# 2023-07-01   42408        68386             161668        3      7  2023
# 2023-08-01   48352        77974             184328        3      8  2023
# 2023-09-01   52288        84321             199333        3      9  2023
# 2023-10-01   84019       183420             433605        4     10  2023
# 2023-11-01  113741       212173             501581        4     11  2023
# 2023-12-01  131572       135491             320298        4     12  2023

# %% [markdown]
# # Train/Test Split

# %%
train= sales_h[:48]
test=sales_h[48:]

# %%
fig,ax=plt.subplots(figsize=(10,4))
train['Sales'].plot(ax=ax,label='Train set',title='Train/Test')
test['Sales'].plot(ax=ax,label='Test set')
plt.legend(['Train','Test'])
plt.show()

# %%
len(train)
# Out:
# 48

# %%
x_train = train.drop(columns=['Sales'])
y_train=train['Sales']
x_test=test.drop(columns=['Sales'])
y_test=test['Sales']

# %%
from sklearn.model_selection import GridSearchCV


# Define the parameter grid
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.001,0.01, 0.1, 0.2],
    'n_estimators': [100, 500, 1000, 2000],
    'colsample_bytree': [0.7, 0.8, 0.9, 1.0],
    'subsample': [0.7, 0.8, 0.9, 1.0]
}

# Instantiate the XGBoost regressor
regressor = xgb.XGBRegressor(objective='reg:squarederror')

# Instantiate GridSearchCV
grid_search = GridSearchCV(estimator=regressor, param_grid=param_grid, 
                           cv=5, scoring='neg_mean_squared_error', 
                           verbose=2, n_jobs=-1)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Access the best parameters
best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

print("Best parameters:", best_params)
print("Best estimator:", best_estimator)
# Out:
# Fitting 5 folds for each of 768 candidates, totalling 3840 fits
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'subsample': 0.7}
# Best estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=500,
                       objective='reg:squarederror',
                       max_depth=3,
                       colsample_bytree=0.7,
                       subsample= 0.7,
                       early_stopping_rounds=50,
                       learning_rate=0.1)

reg.fit(x_train, y_train,
        eval_set=[(x_train, y_train), (x_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:67066.84313	validation_1-rmse:71582.50587
# [100]	validation_0-rmse:2374.65454	validation_1-rmse:14038.12314
# [115]	validation_0-rmse:1873.26401	validation_1-rmse:13895.12441
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
reg.best_iteration
# Out:
# 66

# %%
results = reg.evals_result()

plt.figure(figsize=(10,7))
plt.plot(results["validation_0"]["rmse"], label="Training loss")
plt.plot(results["validation_1"]["rmse"], label="Validation loss")
plt.axvline(66,color='green',ls='--', label="Optimal tree number")
plt.xlabel("Number of trees")
plt.ylabel("Loss")
plt.legend()

# %%
pred=reg.predict(x_test)
sales_h['prediction']=[None]*len(train) + list(pred)

ax = sales_h['Sales'].plot(figsize=(15, 5))
sales_h['prediction'].plot()
plt.legend(['Actual Sales', 'Predictions'])
ax.set_title('Product H: Actual Sales and Prediction')
plt.show()

# %%
mae_xgb= mean_absolute_error(test['Sales'],pred)
mse_xgb=mean_squared_error(test['Sales'], pred)
mape_xgb= mean_absolute_percentage_error(test['Sales'],pred)
rmse_xgb= np.sqrt(mean_squared_error(test['Sales'],pred))

print(f'MAE - XGBoost: {mae_xgb:0.3f}')
print(f'MAPE - XGBoost: {mape_xgb:0.3f}')
print(f'MSE - XGBoost: {mse_xgb:0.3f}')
print(f'RMSE - XGBoost: {rmse_xgb:0.3f}')
# Out:
# MAE - XGBoost: 11718.882
# MAPE - XGBoost: 0.169
# MSE - XGBoost: 189968182.975
# RMSE - XGBoost: 13782.895

# %%
from xgboost import plot_importance

_ = plot_importance(reg, height=0.9)
