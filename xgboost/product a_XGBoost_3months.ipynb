# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.metrics import mean_squared_error,mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score
color_pal=sns.color_palette()

# %%
df=pd.read_csv('product a.csv', parse_dates=['Month-Year'], index_col='Month-Year')

# %%
sales_a= df.drop(['Product Name','Product Category'],axis=1)

# %%
sales_a.head()
# Out:
#             Sales
# Month-Year
# 2019-01-01  54555
# 2019-02-01  54293
# 2019-03-01  58798
# 2019-04-01  53229
# 2019-05-01  50558

# %%
sales_a['Sales'].plot(figsize=(12,6),color=color_pal[2],title='Product A')
# Out:
# <Axes: title={'center': 'Product A'}, xlabel='Month-Year'>

# %%
sales_a['Sales'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Visualization

# %%
sales_b.head()
# Out:
#             Year    Sales  Month No.
# Month-Year
# 2019-01-01  2019   494357          1
# 2019-02-01  2019   837207          2
# 2019-03-01  2019  1278271          3
# 2019-04-01  2019   675985          4
# 2019-05-01  2019   757687          5

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=sales_b, x='Month No.',y='Sales')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=sales_b, x='Year',y='Sales')
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
#sales_b= df.drop(['Product Name','Product Category','Month','Market Size', 'Marketing Expense','Month No.','Year'],axis=1)

# %%
sales_a['quarter'] = sales_a.index.quarter
sales_a['month'] = sales_a.index.month
sales_a['year'] = sales_a.index.year

# %%
# Create lagged values
#lagged_intervals = [1, 3, 6, 12]  # Lagged intervals in months
#for lag in lagged_intervals:
#    sales_b[f'sales_lag_{lag}'] = sales_b['Sales'].shift(lag)

# %%
print(sales_a)
# Out:
#             Sales  quarter  month  year
# Month-Year
# 2019-01-01  54555        1      1  2019
# 2019-02-01  54293        1      2  2019
# 2019-03-01  58798        1      3  2019
# 2019-04-01  53229        2      4  2019
# 2019-05-01  50558        2      5  2019
# 2019-06-01  56326        2      6  2019
# 2019-07-01  50125        3      7  2019
# 2019-08-01  56414        3      8  2019
# 2019-09-01  55658        3      9  2019
# 2019-10-01  56203        4     10  2019
# 2019-11-01  56943        4     11  2019
# 2019-12-01  54800        4     12  2019
# 2020-01-01  52172        1      1  2020
# 2020-02-01  48942        1      2  2020
# 2020-03-01  53422        1      3  2020
# 2020-04-01  48166        2      4  2020
# 2020-05-01  50404        2      5  2020
# 2020-06-01  50709        2      6  2020
# 2020-07-01  51845        3      7  2020
# 2020-08-01  56302        3      8  2020
# 2020-09-01  56527        3      9  2020
# 2020-10-01  55389        4     10  2020
# 2020-11-01  52543        4     11  2020
# 2020-12-01  50325        4     12  2020
# 2021-01-01  49356        1      1  2021
# 2021-02-01  50021        1      2  2021
# 2021-03-01  48118        1      3  2021
# 2021-04-01  47947        2      4  2021
# 2021-05-01  55227        2      5  2021
# 2021-06-01  49167        2      6  2021
# 2021-07-01  53752        3      7  2021
# 2021-08-01  62655        3      8  2021
# 2021-09-01  51256        3      9  2021
# 2021-10-01  53960        4     10  2021
# 2021-11-01  65256        4     11  2021
# 2021-12-01  60727        4     12  2021
# 2022-01-01  56585        1      1  2022
# 2022-02-01  53698        1      2  2022
# 2022-03-01  43442        1      3  2022
# 2022-04-01  52404        2      4  2022
# 2022-05-01  41658        2      5  2022
# 2022-06-01  62172        2      6  2022
# 2022-07-01  51890        3      7  2022
# 2022-08-01  52256        3      8  2022
# 2022-09-01  52959        3      9  2022
# 2022-10-01  52928        4     10  2022
# 2022-11-01  52677        4     11  2022
# 2022-12-01  52648        4     12  2022
# 2023-01-01  63171        1      1  2023
# 2023-02-01  31168        1      2  2023
# 2023-03-01  70380        1      3  2023
# 2023-04-01  53078        2      4  2023
# 2023-05-01  43741        2      5  2023
# 2023-06-01  63919        2      6  2023
# 2023-07-01  54485        3      7  2023
# 2023-08-01  54869        3      8  2023
# 2023-09-01  55607        3      9  2023
# 2023-10-01  55575        4     10  2023
# 2023-11-01  55311        4     11  2023
# 2023-12-01  55281        4     12  2023

# %% [markdown]
# # Train/Test Split

# %%
train= sales_a[:57]
test=sales_a[57:]

# %%
fig,ax=plt.subplots(figsize=(10,4))
train['Sales'].plot(ax=ax,label='Train set',title='Train/Test')
test['Sales'].plot(ax=ax,label='Test set')
plt.legend(['Train','Test'])
plt.show()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 57 entries, 2019-01-01 to 2023-09-01
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Sales    57 non-null     int64
#  1   quarter  57 non-null     int64
#  2   month    57 non-null     int64
#  3   year     57 non-null     int64
# dtypes: int64(4)
# memory usage: 2.2 KB

# %%
#x_train=train[['Month No.','Year','Quarter', 'sales_lag_1', 'sales_lag_3', 'sales_lag_6','sales_lag_12','MA_3','MA_6','MA_12']]
#y_train=train['Sales']
#x_test=test[['Month No.','Year','stationary_target','MA_3','MA_6','MA_12']]
#y_test=test['Sales']

# %%
x_train = train.drop(columns=['Sales'])
y_train=train['Sales']
x_test=test.drop(columns=['Sales'])
y_test=test['Sales']

# %%
from sklearn.model_selection import GridSearchCV


# Define the parameter grid
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.001,0.01, 0.1, 0.2],
    'n_estimators': [100, 500, 1000, 2000],
    'colsample_bytree': [0.7, 0.8, 0.9, 1.0],
    'subsample': [0.7, 0.8, 0.9, 1.0]
}

# Instantiate the XGBoost regressor
regressor = xgb.XGBRegressor(objective='reg:squarederror')

# Instantiate GridSearchCV
grid_search = GridSearchCV(estimator=regressor, param_grid=param_grid, 
                           cv=5, scoring='neg_mean_squared_error', 
                           verbose=2, n_jobs=-1)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Access the best parameters
best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

print("Best parameters:", best_params)
print("Best estimator:", best_estimator)
# Out:
# Fitting 5 folds for each of 768 candidates, totalling 3840 fits
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 100, 'subsample': 0.8}
# Best estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=100,
                       objective='reg:squarederror',
                       max_depth=7,
                       colsample_bytree=0.7,
                       subsample= 0.8,
                       early_stopping_rounds=50,
                       learning_rate=0.01)

reg.fit(x_train, y_train,
        eval_set=[(x_train, y_train), (x_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:53281.00919	validation_1-rmse:54868.11611
# [99]	validation_0-rmse:20802.56226	validation_1-rmse:21857.13369
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
reg.best_iteration
# Out:
# 99

# %%
results = reg.evals_result()

plt.figure(figsize=(10,7))
plt.plot(results["validation_0"]["rmse"], label="Training loss")
plt.plot(results["validation_1"]["rmse"], label="Validation loss")
plt.axvline(99,color='green',ls='--', label="Optimal tree number")
plt.xlabel("Number of trees")
plt.ylabel("Loss")
plt.legend()

# %%
pred=reg.predict(x_test)
sales_a['prediction']=[None]*len(train) + list(pred)

ax = sales_a['Sales'].plot(figsize=(15, 5))
sales_a['prediction'].plot()
plt.legend(['Actual Sales', 'Predictions'])
ax.set_title('Product B: Actual Sales and Prediction')
plt.show()

# %%
mae_xgb= mean_absolute_error(test['Sales'],pred)
mse_xgb=mean_squared_error(test['Sales'], pred)
mape_xgb= mean_absolute_percentage_error(test['Sales'],pred)
rmse_xgb= np.sqrt(mean_squared_error(test['Sales'],pred))

print(f'MAE - XGBoost: {mae_xgb:0.3f}')
print(f'MAPE - XGBoost: {mape_xgb:0.3f}')
print(f'MSE - XGBoost: {mse_xgb:0.3f}')
print(f'RMSE - XGBoost: {rmse_xgb:0.3f}')
# Out:
# MAE - XGBoost: 21856.734
# MAPE - XGBoost: 0.395
# MSE - XGBoost: 477734285.539
# RMSE - XGBoost: 21857.134

# %%
from xgboost import plot_importance

_ = plot_importance(reg, height=0.9)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 3
#       1 from xgboost import plot_importance
# ----> 3 _ = plot_importance(reg, height=0.9)
#
# File ~\anaconda3\lib\site-packages\xgboost\plotting.py:99, in plot_importance(booster, ax, height, xlim, ylim, title, xlabel, ylabel, fmap, importance_type, max_num_features, grid, show_values, values_format, **kwargs)
#      96     raise ValueError("tree must be Booster, XGBModel or dict instance")
#      98 if not importance:
# ---> 99     raise ValueError(
#     100         "Booster.get_score() results in empty.  "
#     101         + "This maybe caused by having all trees as decision dumps."
#     102     )
#     104 tuples = [(k, importance[k]) for k in importance]
#     105 if max_num_features is not None:
#     106     # pylint: disable=invalid-unary-operand-type
#
# ValueError: Booster.get_score() results in empty.  This maybe caused by having all trees as decision dumps.

# %% [markdown]
# # FORECASTING

# %%
x = sales_b.drop(columns=['Sales','prediction'])
y = sales_b['Sales']

# %%
reg_forecast= xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=2000,
                       objective='reg:squarederror',
                       max_depth=3,
                       colsample_bytree=0.7,
                       subsample= 0.8,
                       learning_rate=0.001)

reg_forecast.fit(x, y,
        eval_set=[(x, y)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:1220769.97359
# [100]	validation_0-rmse:1117395.88849
# [200]	validation_0-rmse:1023914.21947
# [300]	validation_0-rmse:939658.01493
# [400]	validation_0-rmse:864228.40475
# [500]	validation_0-rmse:796075.47879
# [600]	validation_0-rmse:735146.52633
# [700]	validation_0-rmse:680507.57019
# [800]	validation_0-rmse:632043.65057
# [900]	validation_0-rmse:588590.89006
# [1000]	validation_0-rmse:549647.47073
# [1100]	validation_0-rmse:515375.00421
# [1200]	validation_0-rmse:484943.95941
# [1300]	validation_0-rmse:457741.47749
# [1400]	validation_0-rmse:433914.78294
# [1500]	validation_0-rmse:413056.56289
# [1600]	validation_0-rmse:394892.48113
# [1700]	validation_0-rmse:378673.94657
# [1800]	validation_0-rmse:364281.67445
# [1900]	validation_0-rmse:351574.58544
# [1999]	validation_0-rmse:340631.24786
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.001, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=2000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
future = pd.date_range(start='2024-01-01', end='2024-12-31', freq='MS')
future_df = pd.DataFrame(index=future)
future_df['isFuture'] = True
sales_b['isFuture'] = False
sales_b_and_future = pd.concat([sales_b, future_df])

# %%
sales_b_and_future['quarter'] = sales_b_and_future.index.quarter
sales_b_and_future['month'] = sales_b_and_future.index.month
sales_b_and_future['year'] = sales_b_and_future.index.year

# %%
sales_b_and_future=sales_b_and_future.drop(columns=['prediction'])

# %%
future_w_features = sales_b_and_future.query('isFuture').copy()
future_w_features=future_w_features.drop(columns=['Sales','isFuture'])

# %%
future_w_features
# Out:
#             quarter  month  year
# 2024-01-01        1      1  2024
# 2024-02-01        1      2  2024
# 2024-03-01        1      3  2024
# 2024-04-01        2      4  2024
# 2024-05-01        2      5  2024
# 2024-06-01        2      6  2024
# 2024-07-01        3      7  2024
# 2024-08-01        3      8  2024
# 2024-09-01        3      9  2024
# 2024-10-01        4     10  2024
# 2024-11-01        4     11  2024
# 2024-12-01        4     12  2024

# %%
future_w_features['pred'] = reg_forecast.predict(future_w_features)

# %%
future_w_features['pred'].plot(figsize=(10, 5),
                               color=color_pal[4],
                               ms=1,
                               lw=1,
                               title='Future Predictions')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(sales_b[['Sales']])
future_w_features['pred'].plot(legend=True, label='Forecast-2024')
plt.title('Product B')
# Out:
# Text(0.5, 1.0, 'Product B')

# %%
# Create an empty DataFrame to store future data
future_data = pd.DataFrame(index=pd.date_range(start='2024-01-01', periods=12, freq='MS'))

# Loop through the last 12 rows of main_data
for i in range(12):
    # Extract lagged values for the current row
    lagged_values = sales_b[['sales_lag_1', 'sales_lag_3', 'sales_lag_6','sales_lag_12']].iloc[-(i + 1)]
    
    # Add the lagged values to future_data
    future_data.loc[future_data.index[i], ['sales_lag_1', 'sales_lag_3', 'sales_lag_6','sales_lag_12']] = lagged_values.values

# Display the future_data DataFrame
print(future_data)
# Out:
#             sales_lag_1  sales_lag_3  sales_lag_6  sales_lag_12
# 2024-01-01    1067615.0    1033615.0    1651940.0     1136218.0
# 2024-02-01    1690948.0    1690948.0     692905.0     1391774.0
# 2024-03-01    1033615.0     929333.0    1589911.0     1802885.0
# 2024-04-01    1690948.0    1651940.0     981026.0     1098441.0
# 2024-05-01     929333.0     692905.0    1767039.0     1798441.0
# 2024-06-01    1651940.0    1589911.0     514369.0      940648.0
# 2024-07-01     692905.0     981026.0    1136218.0     1575105.0
# 2024-08-01    1589911.0    1767039.0    1391774.0      779318.0
# 2024-09-01     981026.0     514369.0    1802885.0     1158736.0
# 2024-10-01    1767039.0    1136218.0    1098441.0     1333941.0
# 2024-11-01     514369.0    1391774.0    1798441.0     1350240.0
# 2024-12-01    1136218.0    1802885.0     940648.0      504283.0

# %%
# Create an empty DataFrame to store future data
future_data = pd.DataFrame(index=pd.date_range(start='2024-01-01', periods=12, freq='MS'))

# Loop through the last 12 rows of main_data
for i in range(12):
    # Extract lagged values for the current row
    lagged_values = sales_b[['sales_lag_1', 'sales_lag_3', 'sales_lag_6','sales_lag_12']].iloc[-(i+1)]
    
    # Add the lagged values to future_data
    future_data.loc[future_data.index[i], ['sales_lag_1', 'sales_lag_3', 'sales_lag_6','sales_lag_12']] = lagged_values.values

# Display the future_data DataFrame
print(future_data)
# Out:
#             sales_lag_1  sales_lag_3  sales_lag_6  sales_lag_12
# 2024-01-01    1067615.0    1033615.0    1651940.0     1136218.0
# 2024-02-01    1690948.0    1690948.0     692905.0     1391774.0
# 2024-03-01    1033615.0     929333.0    1589911.0     1802885.0
# 2024-04-01    1690948.0    1651940.0     981026.0     1098441.0
# 2024-05-01     929333.0     692905.0    1767039.0     1798441.0
# 2024-06-01    1651940.0    1589911.0     514369.0      940648.0
# 2024-07-01     692905.0     981026.0    1136218.0     1575105.0
# 2024-08-01    1589911.0    1767039.0    1391774.0      779318.0
# 2024-09-01     981026.0     514369.0    1802885.0     1158736.0
# 2024-10-01    1767039.0    1136218.0    1098441.0     1333941.0
# 2024-11-01     514369.0    1391774.0    1798441.0     1350240.0
# 2024-12-01    1136218.0    1802885.0     940648.0      504283.0

# %%
sales_b
# Out:
#               Sales  quarter  month  year  sales_lag_1  sales_lag_3  \
# Month-Year
# 2019-01-01   494357        1      1  2019          NaN          NaN
# 2019-02-01   837207        1      2  2019     494357.0          NaN
# 2019-03-01  1278271        1      3  2019     837207.0          NaN
# 2019-04-01   675985        2      4  2019    1278271.0     494357.0
# 2019-05-01   757687        2      5  2019     675985.0     837207.0
# 2019-06-01  1154891        2      6  2019     757687.0    1278271.0
# 2019-07-01   459535        3      7  2019    1154891.0     675985.0
# 2019-08-01  1136386        3      8  2019     459535.0     757687.0
# 2019-09-01   984890        3      9  2019    1136386.0    1154891.0
# 2019-10-01   888942        4     10  2019     984890.0     459535.0
# 2019-11-01  1383258        4     11  2019     888942.0    1136386.0
# 2019-12-01   867962        4     12  2019    1383258.0     984890.0
# 2020-01-01   994941        1      1  2020     867962.0     888942.0
# 2020-02-01  1340112        1      2  2020     994941.0    1383258.0
# 2020-03-01   940807        1      3  2020    1340112.0     867962.0
# 2020-04-01  1016144        2      4  2020     940807.0     994941.0
# 2020-05-01  1312370        2      5  2020    1016144.0    1340112.0
# 2020-06-01   848998        2      6  2020    1312370.0     940807.0
# 2020-07-01  1215806        3      7  2020     848998.0    1016144.0
# 2020-08-01  1243995        3      8  2020    1215806.0    1312370.0
# 2020-09-01  1255719        3      9  2020    1243995.0     848998.0
# 2020-10-01  1075916        4     10  2020    1255719.0    1215806.0
# 2020-11-01  1587525        4     11  2020    1075916.0    1243995.0
# 2020-12-01  1389560        4     12  2020    1587525.0    1255719.0
# 2021-01-01  1158814        1      1  2021    1389560.0    1075916.0
# 2021-02-01   836534        1      2  2021    1158814.0    1587525.0
# 2021-03-01  1599415        1      3  2021     836534.0    1389560.0
# 2021-04-01  1100223        2      4  2021    1599415.0    1158814.0
# 2021-05-01  1318844        2      5  2021    1100223.0     836534.0
# 2021-06-01   593308        2      6  2021    1318844.0    1599415.0
# 2021-07-01  1322511        3      7  2021     593308.0    1100223.0
# 2021-08-01  1494669        3      8  2021    1322511.0    1318844.0
# 2021-09-01   713429        3      9  2021    1494669.0     593308.0
# 2021-10-01  1477523        4     10  2021     713429.0    1322511.0
# 2021-11-01  1246180        4     11  2021    1477523.0    1494669.0
# 2021-12-01  1809541        4     12  2021    1246180.0     713429.0
# 2022-01-01   504283        1      1  2022    1809541.0    1477523.0
# 2022-02-01  1350240        1      2  2022     504283.0    1246180.0
# 2022-03-01  1333941        1      3  2022    1350240.0    1809541.0
# 2022-04-01  1158736        2      4  2022    1333941.0     504283.0
# 2022-05-01   779318        2      5  2022    1158736.0    1350240.0
# 2022-06-01  1575105        2      6  2022     779318.0    1333941.0
# 2022-07-01   940648        3      7  2022    1575105.0    1158736.0
# 2022-08-01  1798441        3      8  2022     940648.0     779318.0
# 2022-09-01  1098441        3      9  2022    1798441.0    1575105.0
# 2022-10-01  1802885        4     10  2022    1098441.0     940648.0
# 2022-11-01  1391774        4     11  2022    1802885.0    1798441.0
# 2022-12-01  1136218        4     12  2022    1391774.0    1098441.0
# 2023-01-01   514369        1      1  2023    1136218.0    1802885.0
# 2023-02-01  1767039        1      2  2023     514369.0    1391774.0
# 2023-03-01   981026        1      3  2023    1767039.0    1136218.0
# 2023-04-01  1589911        2      4  2023     981026.0     514369.0
# 2023-05-01   692905        2      5  2023    1589911.0    1767039.0
# 2023-06-01  1651940        2      6  2023     692905.0     981026.0
# 2023-07-01   929333        3      7  2023    1651940.0    1589911.0
# 2023-08-01  1690948        3      8  2023     929333.0     692905.0
# 2023-09-01  1033615        3      9  2023    1690948.0    1651940.0
# 2023-10-01  1690948        4     10  2023    1033615.0     929333.0
# 2023-11-01  1067615        4     11  2023    1690948.0    1690948.0
# 2023-12-01  1724948        4     12  2023    1067615.0    1033615.0
#
#             sales_lag_6  sales_lag_12    prediction  isFuture
# Month-Year
# 2019-01-01          NaN           NaN           NaN     False
# 2019-02-01          NaN           NaN           NaN     False
# 2019-03-01          NaN           NaN           NaN     False
# 2019-04-01          NaN           NaN           NaN     False
# 2019-05-01          NaN           NaN           NaN     False
# 2019-06-01          NaN           NaN           NaN     False
# 2019-07-01     494357.0           NaN           NaN     False
# 2019-08-01     837207.0           NaN           NaN     False
# 2019-09-01    1278271.0           NaN           NaN     False
# 2019-10-01     675985.0           NaN           NaN     False
# 2019-11-01     757687.0           NaN           NaN     False
# 2019-12-01    1154891.0           NaN           NaN     False
# 2020-01-01     459535.0      494357.0           NaN     False
# 2020-02-01    1136386.0      837207.0           NaN     False
# 2020-03-01     984890.0     1278271.0           NaN     False
# 2020-04-01     888942.0      675985.0           NaN     False
# 2020-05-01    1383258.0      757687.0           NaN     False
# 2020-06-01     867962.0     1154891.0           NaN     False
# 2020-07-01     994941.0      459535.0           NaN     False
# 2020-08-01    1340112.0     1136386.0           NaN     False
# 2020-09-01     940807.0      984890.0           NaN     False
# 2020-10-01    1016144.0      888942.0           NaN     False
# 2020-11-01    1312370.0     1383258.0           NaN     False
# 2020-12-01     848998.0      867962.0           NaN     False
# 2021-01-01    1215806.0      994941.0           NaN     False
# 2021-02-01    1243995.0     1340112.0           NaN     False
# 2021-03-01    1255719.0      940807.0           NaN     False
# 2021-04-01    1075916.0     1016144.0           NaN     False
# 2021-05-01    1587525.0     1312370.0           NaN     False
# 2021-06-01    1389560.0      848998.0           NaN     False
# 2021-07-01    1158814.0     1215806.0           NaN     False
# 2021-08-01     836534.0     1243995.0           NaN     False
# 2021-09-01    1599415.0     1255719.0           NaN     False
# 2021-10-01    1100223.0     1075916.0           NaN     False
# 2021-11-01    1318844.0     1587525.0           NaN     False
# 2021-12-01     593308.0     1389560.0           NaN     False
# 2022-01-01    1322511.0     1158814.0           NaN     False
# 2022-02-01    1494669.0      836534.0           NaN     False
# 2022-03-01     713429.0     1599415.0           NaN     False
# 2022-04-01    1477523.0     1100223.0           NaN     False
# 2022-05-01    1246180.0     1318844.0           NaN     False
# 2022-06-01    1809541.0      593308.0           NaN     False
# 2022-07-01     504283.0     1322511.0           NaN     False
# 2022-08-01    1350240.0     1494669.0           NaN     False
# 2022-09-01    1333941.0      713429.0           NaN     False
# 2022-10-01    1158736.0     1477523.0           NaN     False
# 2022-11-01     779318.0     1246180.0           NaN     False
# 2022-12-01    1575105.0     1809541.0           NaN     False
# 2023-01-01     940648.0      504283.0  1.034310e+06     False
# 2023-02-01    1798441.0     1350240.0  1.178267e+06     False
# 2023-03-01    1098441.0     1333941.0  9.670722e+05     False
# 2023-04-01    1802885.0     1158736.0  1.241044e+06     False
# 2023-05-01    1391774.0      779318.0  7.866433e+05     False
# 2023-06-01    1136218.0     1575105.0  1.487998e+06     False
# 2023-07-01     514369.0      940648.0  1.016639e+06     False
# 2023-08-01    1767039.0     1798441.0  1.495219e+06     False
# 2023-09-01     981026.0     1098441.0  1.115683e+06     False
# 2023-10-01    1589911.0     1802885.0  1.671840e+06     False
# 2023-11-01     692905.0     1391774.0  1.430021e+06     False
# 2023-12-01    1651940.0     1136218.0  1.403416e+06     False
