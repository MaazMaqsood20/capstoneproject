# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.metrics import mean_squared_error,mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score
color_pal=sns.color_palette()

# %%
df=pd.read_csv('product c.csv', parse_dates=['Month-Year'], index_col='Month-Year')

# %%
sales_c= df.drop(['Product Name','Product Category','Month'],axis=1)

# %%
sales_c
# Out:
#             Year    Sales  Market Size  Marketing Expense  Month No.
# Month-Year
# 2019-01-01  2019   496334      1002744            1578266          1
# 2019-02-01  2019   306455       619142             974480          2
# 2019-03-01  2019   476270       962208            1514466          3
# 2019-04-01  2019   628463      1269687            1998416          4
# 2019-05-01  2019   366750       740950            1166209          5
# 2019-06-01  2019   352324       711811            1120336          6
# 2019-07-01  2019   657300      1327952            2090113          7
# 2019-08-01  2019   429552       867822            1365910          8
# 2019-09-01  2019   499906      1009971            1589625          9
# 2019-10-01  2019   844520      1107516            1743167         10
# 2019-11-01  2019   548192      1627136            2561020         11
# 2019-12-01  2019   805391      1706188            2685444         12
# 2020-01-01  2020   486322       706776              90832          1
# 2020-02-01  2020   642661       933992             120032          2
# 2020-03-01  2020   955368      1388452             178437          3
# 2020-04-01  2020   477644       694168              89211          4
# 2020-05-01  2020   647027       940339             120847          5
# 2020-06-01  2020   644756       937036             120423          6
# 2020-07-01  2020   985263      1431902             184021          7
# 2020-08-01  2020   654235       950812             122194          8
# 2020-09-01  2020   962755      1399185             179817          9
# 2020-10-01  2020   627632       819468             105314         10
# 2020-11-01  2020   563861      1787317             229697         11
# 2020-12-01  2020  1229818       912152             117225         12
# 2021-01-01  2021   478264       756313             126271          1
# 2021-02-01  2021   897459      1419207             236946          2
# 2021-03-01  2021   518534       819987             136903          3
# 2021-04-01  2021   962523      1522090             254125          4
# 2021-05-01  2021   585032       925149             154460          5
# 2021-06-01  2021   998609      1579157             263652          6
# 2021-07-01  2021   437516       691875             115513          7
# 2021-08-01  2021   744043      1176600             196442          8
# 2021-09-01  2021  1273588      2013999             336252          9
# 2021-10-01  2021   786419      1553263             259329         10
# 2021-11-01  2021   982234      1839090             307048         11
# 2021-12-01  2021  1162977      1243606             207630         12
# 2022-01-01  2022   670760      1077309             233707          1
# 2022-02-01  2022   376791       605163             131282          2
# 2022-03-01  2022  1229637      1974906             428432          3
# 2022-04-01  2022   627375      1007620             218591          4
# 2022-05-01  2022  1148785      1845062             400262          5
# 2022-06-01  2022   617059       991059             214997          6
# 2022-07-01  2022  1105307      1775228             385113          7
# 2022-08-01  2022   670524      1076920             233625          8
# 2022-09-01  2022  1235742      1984715             430559          9
# 2022-10-01  2022   670524      1413235             306585         10
# 2022-11-01  2022   879924      1426074             309369         11
# 2022-12-01  2022   887916      1076920             233625         12
# 2023-01-01  2023   684175      1198238             333991          1
# 2023-02-01  2023   675038      1182240             329531          2
# 2023-03-01  2023  1185258      2075812             578603          3
# 2023-04-01  2023   639923      1120744             312389          4
# 2023-05-01  2023  1171761      2052183             572015          5
# 2023-06-01  2023   629400      1102308             307252          6
# 2023-07-01  2023  1127413      1974516             550365          7
# 2023-08-01  2023   683935      1197820             333874          8
# 2023-09-01  2023  1258717      2204473             614464          9
# 2023-10-01  2023   683935      1411980             393569         10
# 2023-11-01  2023   806218      1430820             398821         11
# 2023-12-01  2023   816978      1197820             333874         12

# %%
sales_c['Sales'].plot(figsize=(12,6),color=color_pal[2],title='Product C')
# Out:
# <Axes: title={'center': 'Product C'}, xlabel='Month-Year'>

# %%
sales_c['Sales'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Visualization

# %%
sales_c.head()
# Out:
#             Year   Sales  Market Size  Marketing Expense  Month No.
# Month-Year
# 2019-01-01  2019  496334      1002744            1578266          1
# 2019-02-01  2019  306455       619142             974480          2
# 2019-03-01  2019  476270       962208            1514466          3
# 2019-04-01  2019  628463      1269687            1998416          4
# 2019-05-01  2019  366750       740950            1166209          5

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=sales_c, x='Month No.',y='Sales')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=sales_c, x='Year',y='Sales')
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
sales_c= df.drop(['Product Name','Product Category','Month','Month No.','Year'],axis=1)

# %%
sales_c['quarter'] = sales_c.index.quarter
sales_c['month'] = sales_c.index.month
sales_c['year'] = sales_c.index.year

# %%
print(sales_c)
# Out:
#               Sales  Market Size  Marketing Expense  quarter  month  year
# Month-Year
# 2019-01-01   496334      1002744            1578266        1      1  2019
# 2019-02-01   306455       619142             974480        1      2  2019
# 2019-03-01   476270       962208            1514466        1      3  2019
# 2019-04-01   628463      1269687            1998416        2      4  2019
# 2019-05-01   366750       740950            1166209        2      5  2019
# 2019-06-01   352324       711811            1120336        2      6  2019
# 2019-07-01   657300      1327952            2090113        3      7  2019
# 2019-08-01   429552       867822            1365910        3      8  2019
# 2019-09-01   499906      1009971            1589625        3      9  2019
# 2019-10-01   844520      1107516            1743167        4     10  2019
# 2019-11-01   548192      1627136            2561020        4     11  2019
# 2019-12-01   805391      1706188            2685444        4     12  2019
# 2020-01-01   486322       706776              90832        1      1  2020
# 2020-02-01   642661       933992             120032        1      2  2020
# 2020-03-01   955368      1388452             178437        1      3  2020
# 2020-04-01   477644       694168              89211        2      4  2020
# 2020-05-01   647027       940339             120847        2      5  2020
# 2020-06-01   644756       937036             120423        2      6  2020
# 2020-07-01   985263      1431902             184021        3      7  2020
# 2020-08-01   654235       950812             122194        3      8  2020
# 2020-09-01   962755      1399185             179817        3      9  2020
# 2020-10-01   627632       819468             105314        4     10  2020
# 2020-11-01   563861      1787317             229697        4     11  2020
# 2020-12-01  1229818       912152             117225        4     12  2020
# 2021-01-01   478264       756313             126271        1      1  2021
# 2021-02-01   897459      1419207             236946        1      2  2021
# 2021-03-01   518534       819987             136903        1      3  2021
# 2021-04-01   962523      1522090             254125        2      4  2021
# 2021-05-01   585032       925149             154460        2      5  2021
# 2021-06-01   998609      1579157             263652        2      6  2021
# 2021-07-01   437516       691875             115513        3      7  2021
# 2021-08-01   744043      1176600             196442        3      8  2021
# 2021-09-01  1273588      2013999             336252        3      9  2021
# 2021-10-01   786419      1553263             259329        4     10  2021
# 2021-11-01   982234      1839090             307048        4     11  2021
# 2021-12-01  1162977      1243606             207630        4     12  2021
# 2022-01-01   670760      1077309             233707        1      1  2022
# 2022-02-01   376791       605163             131282        1      2  2022
# 2022-03-01  1229637      1974906             428432        1      3  2022
# 2022-04-01   627375      1007620             218591        2      4  2022
# 2022-05-01  1148785      1845062             400262        2      5  2022
# 2022-06-01   617059       991059             214997        2      6  2022
# 2022-07-01  1105307      1775228             385113        3      7  2022
# 2022-08-01   670524      1076920             233625        3      8  2022
# 2022-09-01  1235742      1984715             430559        3      9  2022
# 2022-10-01   670524      1413235             306585        4     10  2022
# 2022-11-01   879924      1426074             309369        4     11  2022
# 2022-12-01   887916      1076920             233625        4     12  2022
# 2023-01-01   684175      1198238             333991        1      1  2023
# 2023-02-01   675038      1182240             329531        1      2  2023
# 2023-03-01  1185258      2075812             578603        1      3  2023
# 2023-04-01   639923      1120744             312389        2      4  2023
# 2023-05-01  1171761      2052183             572015        2      5  2023
# 2023-06-01   629400      1102308             307252        2      6  2023
# 2023-07-01  1127413      1974516             550365        3      7  2023
# 2023-08-01   683935      1197820             333874        3      8  2023
# 2023-09-01  1258717      2204473             614464        3      9  2023
# 2023-10-01   683935      1411980             393569        4     10  2023
# 2023-11-01   806218      1430820             398821        4     11  2023
# 2023-12-01   816978      1197820             333874        4     12  2023

# %% [markdown]
# # Train/Test Split

# %%
train= sales_c[:48]
test=sales_c[48:]

# %%
fig,ax=plt.subplots(figsize=(10,4))
train['Sales'].plot(ax=ax,label='Train set',title='Train/Test')
test['Sales'].plot(ax=ax,label='Test set')
plt.legend(['Train','Test'])
plt.show()

# %%
train.head()
# Out:
#              Sales  Market Size  Marketing Expense  quarter  month  year
# Month-Year
# 2019-01-01  496334      1002744            1578266        1      1  2019
# 2019-02-01  306455       619142             974480        1      2  2019
# 2019-03-01  476270       962208            1514466        1      3  2019
# 2019-04-01  628463      1269687            1998416        2      4  2019
# 2019-05-01  366750       740950            1166209        2      5  2019

# %%
x_train = train.drop(columns=['Sales'])
y_train=train['Sales']
x_test=test.drop(columns=['Sales'])
y_test=test['Sales']

# %%
from sklearn.model_selection import GridSearchCV


# Define the parameter grid
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.001,0.01, 0.1, 0.2],
    'n_estimators': [100, 500, 1000, 2000],
    'colsample_bytree': [0.7, 0.8, 0.9, 1.0],
    'subsample': [0.7, 0.8, 0.9, 1.0]
}

# Instantiate the XGBoost regressor
regressor = xgb.XGBRegressor(objective='reg:squarederror')

# Instantiate GridSearchCV
grid_search = GridSearchCV(estimator=regressor, param_grid=param_grid, 
                           cv=5, scoring='neg_mean_squared_error', 
                           verbose=2, n_jobs=-1)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Access the best parameters
best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

print("Best parameters:", best_params)
print("Best estimator:", best_estimator)
# Out:
# Fitting 5 folds for each of 768 candidates, totalling 3840 fits
# Best parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'subsample': 0.7}
# Best estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=500,
                       objective='reg:squarederror',
                       max_depth=3,
                       colsample_bytree=1.0,
                       subsample= 0.7,
                       early_stopping_rounds=50,
                       learning_rate=0.1)

reg.fit(x_train, y_train,
        eval_set=[(x_train, y_train), (x_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:712934.93505	validation_1-rmse:821490.24856
# [94]	validation_0-rmse:20805.87596	validation_1-rmse:111243.57540
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=1.0, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
reg.best_iteration
# Out:
# 45

# %%
results = reg.evals_result()

plt.figure(figsize=(10,7))
plt.plot(results["validation_0"]["rmse"], label="Training loss")
plt.plot(results["validation_1"]["rmse"], label="Validation loss")
plt.axvline(45,color='green',ls='--', label="Optimal tree number")
plt.xlabel("Number of trees")
plt.ylabel("Loss")
plt.legend()

# %%
pred=reg.predict(x_test)
sales_c['prediction']=[None]*len(train) + list(pred)

ax = sales_c['Sales'].plot(figsize=(15, 5))
sales_c['prediction'].plot()
plt.legend(['Actual Sales', 'Predictions'])
ax.set_title('Product C: Actual Sales and Prediction')
plt.show()

# %%
mae_xgb= mean_absolute_error(test['Sales'],pred)
mse_xgb=mean_squared_error(test['Sales'], pred)
mape_xgb= mean_absolute_percentage_error(test['Sales'],pred)
rmse_xgb= np.sqrt(mean_squared_error(test['Sales'],pred))

print(f'MAE - XGBoost: {mae_xgb:0.3f}')
print(f'MAPE - XGBoost: {mape_xgb:0.3f}')
print(f'MSE - XGBoost: {mse_xgb:0.3f}')
print(f'RMSE - XGBoost: {rmse_xgb:0.3f}')
# Out:
# MAE - XGBoost: 76113.531
# MAPE - XGBoost: 0.098
# MSE - XGBoost: 8217451916.133
# RMSE - XGBoost: 90650.162

# %%
from xgboost import plot_importance

_ = plot_importance(reg, height=0.9)
