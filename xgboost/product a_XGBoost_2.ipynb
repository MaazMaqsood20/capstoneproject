# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.metrics import mean_squared_error,mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score
color_pal=sns.color_palette()

# %%
df=pd.read_csv('product a.csv', parse_dates=['Month-Year'], index_col='Month-Year')

# %%
df.head()
# Out:
#            Product Name Product Category  Sales  Market Size  \
# Month-Year
# 2019-01-01    Product A   Pain/Analgesic  54555      2738080
# 2019-02-01    Product A   Pain/Analgesic  54293      4637013
# 2019-03-01    Product A   Pain/Analgesic  58798      7079920
# 2019-04-01    Product A   Pain/Analgesic  53229      3744057
# 2019-05-01    Product A   Pain/Analgesic  50558      4196578
#
#             Marketing Expense
# Month-Year
# 2019-01-01             177316
# 2019-02-01             300290
# 2019-03-01             458491
# 2019-04-01             242463
# 2019-05-01             271768

# %%
sales_a= df.drop(['Product Name','Product Category'],axis=1)

# %%
sales_a
# Out:
#             Sales  Market Size  Marketing Expense
# Month-Year
# 2019-01-01  54555      2738080             177316
# 2019-02-01  54293      4637013             300290
# 2019-03-01  58798      7079920             458491
# 2019-04-01  53229      3744057             242463
# 2019-05-01  50558      4196578             271768
# 2019-06-01  56326      6396559             414237
# 2019-07-01  50125      2545212             164826
# 2019-08-01  56414      6294066             407600
# 2019-09-01  55658      5454980             353261
# 2019-10-01  56203      4923556             318846
# 2019-11-01  56943      7661409             496148
# 2019-12-01  54800      4807354             311321
# 2020-01-01  52172      4003955             103835
# 2020-02-01  48942      5393032             139858
# 2020-03-01  53422      3786103              98185
# 2020-04-01  48166      4089283             106047
# 2020-05-01  50404      5281390             136962
# 2020-06-01  50709      3416635              88604
# 2020-07-01  51845      4892786             126885
# 2020-08-01  56302      5006227             129827
# 2020-09-01  56527      5053408             131050
# 2020-10-01  55389      4329824             112285
# 2020-11-01  52543      6388700             165678
# 2020-12-01  50325      5592026             145018
# 2021-01-01  49356      5319884             261622
# 2021-02-01  50021      3840360             188862
# 2021-03-01  48118      7342595             361096
# 2021-04-01  47947      5050904             248394
# 2021-05-01  55227      6054549             297752
# 2021-06-01  49167      2723758             133950
# 2021-07-01  53752      6071384             298580
# 2021-08-01  62655      6861727             337448
# 2021-09-01  51256      3275210             161069
# 2021-10-01  53960      6783013             333577
# 2021-11-01  65256      5720963             281347
# 2021-12-01  60727      8307241             408535
# 2022-01-01  56585      2974493             139767
# 2022-02-01  53698      7964336             374233
# 2022-03-01  43442      7868197             369716
# 2022-04-01  52404      6834757             321156
# 2022-05-01  41658      4596776             215996
# 2022-06-01  62172      9290693             436557
# 2022-07-01  51890      5548374             260710
# 2022-08-01  52256     10608031             498457
# 2022-09-01  52959      6479110             304444
# 2022-10-01  52928     10634244             499688
# 2022-11-01  52677      8209322             385745
# 2022-12-01  52648      6701936             314915
# 2023-01-01  63171      2955148             236101
# 2023-02-01  31168     10151977             811092
# 2023-03-01  70380      5636182             450302
# 2023-04-01  53078      9134343             729788
# 2023-05-01  43741      3980872             318051
# 2023-06-01  63919      9490711             758260
# 2023-07-01  54485      5339196             426575
# 2023-08-01  54869      9714819             776165
# 2023-09-01  55607      5938316             474441
# 2023-10-01  55575      9714819             776165
# 2023-11-01  55311      6133652             490048
# 2023-12-01  55281      9910156             791771

# %%
sales_a['Sales'].plot(figsize=(12,6),color=color_pal[2],title='Product A')
# Out:
# <Axes: title={'center': 'Product A'}, xlabel='Month-Year'>

# %%
sales_a['Sales'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Visualization

# %%
sales_b.head()
# Out:
#             Year    Sales  Market Size  Marketing Expense  Month No.
# Month-Year
# 2019-01-01  2019   494357      2738080             177316          1
# 2019-02-01  2019   837207      4637013             300290          2
# 2019-03-01  2019  1278271      7079920             458491          3
# 2019-04-01  2019   675985      3744057             242463          4
# 2019-05-01  2019   757687      4196578             271768          5

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=sales_b, x='Month No.',y='Sales')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=sales_b, x='Year',y='Sales')
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
sales_a['quarter'] = sales_a.index.quarter
sales_a['month'] = sales_a.index.month
sales_a['year'] = sales_a.index.year

# %%
print(sales_a)
# Out:
#             Sales  Market Size  Marketing Expense  quarter  month  year
# Month-Year
# 2019-01-01  54555      2738080             177316        1      1  2019
# 2019-02-01  54293      4637013             300290        1      2  2019
# 2019-03-01  58798      7079920             458491        1      3  2019
# 2019-04-01  53229      3744057             242463        2      4  2019
# 2019-05-01  50558      4196578             271768        2      5  2019
# 2019-06-01  56326      6396559             414237        2      6  2019
# 2019-07-01  50125      2545212             164826        3      7  2019
# 2019-08-01  56414      6294066             407600        3      8  2019
# 2019-09-01  55658      5454980             353261        3      9  2019
# 2019-10-01  56203      4923556             318846        4     10  2019
# 2019-11-01  56943      7661409             496148        4     11  2019
# 2019-12-01  54800      4807354             311321        4     12  2019
# 2020-01-01  52172      4003955             103835        1      1  2020
# 2020-02-01  48942      5393032             139858        1      2  2020
# 2020-03-01  53422      3786103              98185        1      3  2020
# 2020-04-01  48166      4089283             106047        2      4  2020
# 2020-05-01  50404      5281390             136962        2      5  2020
# 2020-06-01  50709      3416635              88604        2      6  2020
# 2020-07-01  51845      4892786             126885        3      7  2020
# 2020-08-01  56302      5006227             129827        3      8  2020
# 2020-09-01  56527      5053408             131050        3      9  2020
# 2020-10-01  55389      4329824             112285        4     10  2020
# 2020-11-01  52543      6388700             165678        4     11  2020
# 2020-12-01  50325      5592026             145018        4     12  2020
# 2021-01-01  49356      5319884             261622        1      1  2021
# 2021-02-01  50021      3840360             188862        1      2  2021
# 2021-03-01  48118      7342595             361096        1      3  2021
# 2021-04-01  47947      5050904             248394        2      4  2021
# 2021-05-01  55227      6054549             297752        2      5  2021
# 2021-06-01  49167      2723758             133950        2      6  2021
# 2021-07-01  53752      6071384             298580        3      7  2021
# 2021-08-01  62655      6861727             337448        3      8  2021
# 2021-09-01  51256      3275210             161069        3      9  2021
# 2021-10-01  53960      6783013             333577        4     10  2021
# 2021-11-01  65256      5720963             281347        4     11  2021
# 2021-12-01  60727      8307241             408535        4     12  2021
# 2022-01-01  56585      2974493             139767        1      1  2022
# 2022-02-01  53698      7964336             374233        1      2  2022
# 2022-03-01  43442      7868197             369716        1      3  2022
# 2022-04-01  52404      6834757             321156        2      4  2022
# 2022-05-01  41658      4596776             215996        2      5  2022
# 2022-06-01  62172      9290693             436557        2      6  2022
# 2022-07-01  51890      5548374             260710        3      7  2022
# 2022-08-01  52256     10608031             498457        3      8  2022
# 2022-09-01  52959      6479110             304444        3      9  2022
# 2022-10-01  52928     10634244             499688        4     10  2022
# 2022-11-01  52677      8209322             385745        4     11  2022
# 2022-12-01  52648      6701936             314915        4     12  2022
# 2023-01-01  63171      2955148             236101        1      1  2023
# 2023-02-01  31168     10151977             811092        1      2  2023
# 2023-03-01  70380      5636182             450302        1      3  2023
# 2023-04-01  53078      9134343             729788        2      4  2023
# 2023-05-01  43741      3980872             318051        2      5  2023
# 2023-06-01  63919      9490711             758260        2      6  2023
# 2023-07-01  54485      5339196             426575        3      7  2023
# 2023-08-01  54869      9714819             776165        3      8  2023
# 2023-09-01  55607      5938316             474441        3      9  2023
# 2023-10-01  55575      9714819             776165        4     10  2023
# 2023-11-01  55311      6133652             490048        4     11  2023
# 2023-12-01  55281      9910156             791771        4     12  2023

# %% [markdown]
# # Train/Test Split

# %%
train= sales_a[:48]
test=sales_a[48:]

# %%
fig,ax=plt.subplots(figsize=(10,4))
train['Sales'].plot(ax=ax,label='Train set',title='Train/Test')
test['Sales'].plot(ax=ax,label='Test set')
plt.legend(['Train','Test'])
plt.show()

# %%
train.head()
# Out:
#             Sales  Market Size  Marketing Expense  quarter  month  year
# Month-Year
# 2019-01-01  54555      2738080             177316        1      1  2019
# 2019-02-01  54293      4637013             300290        1      2  2019
# 2019-03-01  58798      7079920             458491        1      3  2019
# 2019-04-01  53229      3744057             242463        2      4  2019
# 2019-05-01  50558      4196578             271768        2      5  2019

# %%
x_train = train.drop(columns=['Sales'])
y_train=train['Sales']
x_test=test.drop(columns=['Sales'])
y_test=test['Sales']

# %%
from sklearn.model_selection import GridSearchCV


# Define the parameter grid
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.001,0.01, 0.1, 0.2],
    'n_estimators': [100, 500, 1000, 2000],
    'colsample_bytree': [0.7, 0.8, 0.9, 1.0],
    'subsample': [0.7, 0.8, 0.9, 1.0]
}

# Instantiate the XGBoost regressor
regressor = xgb.XGBRegressor(objective='reg:squarederror')

# Instantiate GridSearchCV
grid_search = GridSearchCV(estimator=regressor, param_grid=param_grid, 
                           cv=5, scoring='neg_mean_squared_error', 
                           verbose=2, n_jobs=-1)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Access the best parameters
best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

print("Best parameters:", best_params)
print("Best estimator:", best_estimator)
# Out:
# Fitting 5 folds for each of 768 candidates, totalling 3840 fits
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.001, 'max_depth': 7, 'n_estimators': 1000, 'subsample': 0.7}
# Best estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.001, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=1000,
                       objective='reg:squarederror',
                       max_depth=7,
                       colsample_bytree= 0.7,
                       subsample= 0.7,
                       early_stopping_rounds=50,
                       learning_rate=0.001)

reg.fit(x_train, y_train,
        eval_set=[(x_train, y_train), (x_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:53405.43748	validation_1-rmse:55480.76894
# [100]	validation_0-rmse:48493.38146	validation_1-rmse:50630.25083
# [200]	validation_0-rmse:44040.18186	validation_1-rmse:46243.95940
# [300]	validation_0-rmse:39990.54100	validation_1-rmse:42267.18096
# [400]	validation_0-rmse:36334.59042	validation_1-rmse:38689.83544
# [500]	validation_0-rmse:33012.83542	validation_1-rmse:35453.21693
# [600]	validation_0-rmse:30010.05049	validation_1-rmse:32541.93479
# [700]	validation_0-rmse:27284.98138	validation_1-rmse:29915.29322
# [800]	validation_0-rmse:24827.34880	validation_1-rmse:27562.49947
# [900]	validation_0-rmse:22606.15947	validation_1-rmse:25452.73093
# [999]	validation_0-rmse:20609.17264	validation_1-rmse:23572.95169
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.001, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
reg.best_iteration
# Out:
# 999

# %%
results = reg.evals_result()

plt.figure(figsize=(10,7))
plt.plot(results["validation_0"]["rmse"], label="Training loss")
plt.plot(results["validation_1"]["rmse"], label="Validation loss")
plt.axvline(999,color='green',ls='--', label="Optimal tree number")
plt.xlabel("Number of trees")
plt.ylabel("Loss")
plt.legend()

# %%
pred=reg.predict(x_test)
sales_a['prediction']=[None]*len(train) + list(pred)

ax = sales_a['Sales'].plot(figsize=(15, 5))
sales_a['prediction'].plot()
plt.legend(['Actual Sales', 'Predictions'])
ax.set_title('Actual Sales and Prediction')
plt.show()

# %%
mae_xgb= mean_absolute_error(test['Sales'],pred)
mse_xgb=mean_squared_error(test['Sales'], pred)
mape_xgb= mean_absolute_percentage_error(test['Sales'],pred)
rmse_xgb= np.sqrt(mean_squared_error(test['Sales'],pred))

print(f'MAE - XGBoost: {mae_xgb:0.3f}')
print(f'MAPE - XGBoost: {mape_xgb:0.3f}')
print(f'MSE - XGBoost: {mse_xgb:0.3f}')
print(f'RMSE - XGBoost: {rmse_xgb:0.3f}')
# Out:
# MAE - XGBoost: 21905.304
# MAPE - XGBoost: 0.380
# MSE - XGBoost: 555684055.791
# RMSE - XGBoost: 23572.952
