# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.metrics import mean_squared_error,mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score
color_pal=sns.color_palette()

# %%
df=pd.read_csv('product h.csv', parse_dates=['Month-Year'], index_col='Month-Year')

# %%
df.head()
# Out:
#            Product Name               Product Category     Month  Year  Sales  \
# Month-Year
# 2019-01-01    Product H  Anti Biotic Upper Respiratory   January  2019  62686
# 2019-02-01    Product H  Anti Biotic Upper Respiratory  February  2019  74426
# 2019-03-01    Product H  Anti Biotic Upper Respiratory     March  2019  91347
# 2019-04-01    Product H  Anti Biotic Upper Respiratory     April  2019  60600
# 2019-05-01    Product H  Anti Biotic Upper Respiratory       May  2019  37374
#
#             Market Size  Marketing Expense  Month No.
# Month-Year
# 2019-01-01       142038             447509          1
# 2019-02-01       168635             531319          2
# 2019-03-01       206976             652116          3
# 2019-04-01       137309             432617          4
# 2019-05-01        84683             266809          5

# %%
sales_h= df.drop(['Product Name','Product Category','Month','Market Size', 'Marketing Expense'],axis=1)

# %%
sales_h.head()
# Out:
#             Year  Sales  Month No.
# Month-Year
# 2019-01-01  2019  62686          1
# 2019-02-01  2019  74426          2
# 2019-03-01  2019  91347          3
# 2019-04-01  2019  60600          4
# 2019-05-01  2019  37374          5

# %%
sales_h['Sales'].plot(figsize=(12,6),color=color_pal[2],title='Product H')
# Out:
# <Axes: title={'center': 'Product H'}, xlabel='Month-Year'>

# %%
sales_h['Sales'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Visualization

# %%
sales_h.head()
# Out:
#             Year  Sales  Month No.
# Month-Year
# 2019-01-01  2019  62686          1
# 2019-02-01  2019  74426          2
# 2019-03-01  2019  91347          3
# 2019-04-01  2019  60600          4
# 2019-05-01  2019  37374          5

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=sales_h, x='Month No.',y='Sales')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=sales_h, x='Year',y='Sales')
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
sales_h = df.drop(['Product Name','Product Category','Month','Market Size', 'Marketing Expense','Month No.','Year'],axis=1)

# %%
sales_h['quarter'] = sales_h.index.quarter
sales_h['month'] = sales_h.index.month
sales_h['year'] = sales_h.index.year

# %%
# Create lagged values
lagged_intervals = [6, 7, 8]  # Lagged intervals in months
for lag in lagged_intervals:
    sales_h[f'sales_lag_{lag}'] = sales_h['Sales'].shift(lag)

# %%
print(sales_h)
# Out:
#              Sales  quarter  month  year  sales_lag_6  sales_lag_7  \
# Month-Year
# 2019-01-01   62686        1      1  2019          NaN          NaN
# 2019-02-01   74426        1      2  2019          NaN          NaN
# 2019-03-01   91347        1      3  2019          NaN          NaN
# 2019-04-01   60600        2      4  2019          NaN          NaN
# 2019-05-01   37374        2      5  2019          NaN          NaN
# 2019-06-01   30737        2      6  2019          NaN          NaN
# 2019-07-01   29683        3      7  2019      62686.0          NaN
# 2019-08-01   34788        3      8  2019      74426.0      62686.0
# 2019-09-01   43408        3      9  2019      91347.0      74426.0
# 2019-10-01   64323        4     10  2019      60600.0      91347.0
# 2019-11-01   94574        4     11  2019      37374.0      60600.0
# 2019-12-01  109171        4     12  2019      30737.0      37374.0
# 2020-01-01  108329        1      1  2020      29683.0      30737.0
# 2020-02-01   84031        1      2  2020      34788.0      29683.0
# 2020-03-01   70140        1      3  2020      43408.0      34788.0
# 2020-04-01   49066        2      4  2020      64323.0      43408.0
# 2020-05-01   40363        2      5  2020      94574.0      64323.0
# 2020-06-01   31950        2      6  2020     109171.0      94574.0
# 2020-07-01   26500        3      7  2020     108329.0     109171.0
# 2020-08-01   32716        3      8  2020      84031.0     108329.0
# 2020-09-01   46216        3      9  2020      70140.0      84031.0
# 2020-10-01   64406        4     10  2020      49066.0      70140.0
# 2020-11-01  115693        4     11  2020      40363.0      49066.0
# 2020-12-01  139498        4     12  2020      31950.0      40363.0
# 2021-01-01   81038        1      1  2021      26500.0      31950.0
# 2021-02-01   77930        1      2  2021      32716.0      26500.0
# 2021-03-01   67706        1      3  2021      46216.0      32716.0
# 2021-04-01   49801        2      4  2021      64406.0      46216.0
# 2021-05-01   40984        2      5  2021     115693.0      64406.0
# 2021-06-01   20298        2      6  2021     139498.0     115693.0
# 2021-07-01   39907        3      7  2021      81038.0     139498.0
# 2021-08-01   34366        3      8  2021      77930.0      81038.0
# 2021-09-01   41168        3      9  2021      67706.0      77930.0
# 2021-10-01  104512        4     10  2021      49801.0      67706.0
# 2021-11-01  107132        4     11  2021      40984.0      49801.0
# 2021-12-01  132203        4     12  2021      20298.0      40984.0
# 2022-01-01   65638        1      1  2022      39907.0      20298.0
# 2022-02-01  119304        1      2  2022      34366.0      39907.0
# 2022-03-01   70494        1      3  2022      41168.0      34366.0
# 2022-04-01   56667        2      4  2022     104512.0      41168.0
# 2022-05-01   50000        2      5  2022     107132.0     104512.0
# 2022-06-01   40000        2      6  2022     132203.0     107132.0
# 2022-07-01   39633        3      7  2022      65638.0     132203.0
# 2022-08-01   45189        3      8  2022     119304.0      65638.0
# 2022-09-01   48868        3      9  2022      70494.0     119304.0
# 2022-10-01   78522        4     10  2022      56667.0      70494.0
# 2022-11-01  106300        4     11  2022      50000.0      56667.0
# 2022-12-01  122964        4     12  2022      40000.0      50000.0
# 2023-01-01   70232        1      1  2023      39633.0      40000.0
# 2023-02-01   90139        1      2  2023      45189.0      39633.0
# 2023-03-01   85600        1      3  2023      48868.0      45189.0
# 2023-04-01   60633        2      4  2023      78522.0      48868.0
# 2023-05-01   53500        2      5  2023     106300.0      78522.0
# 2023-06-01   42800        2      6  2023     122964.0     106300.0
# 2023-07-01   42408        3      7  2023      70232.0     122964.0
# 2023-08-01   48352        3      8  2023      90139.0      70232.0
# 2023-09-01   52288        3      9  2023      85600.0      90139.0
# 2023-10-01   84019        4     10  2023      60633.0      85600.0
# 2023-11-01  113741        4     11  2023      53500.0      60633.0
# 2023-12-01  131572        4     12  2023      42800.0      53500.0
#
#             sales_lag_8
# Month-Year
# 2019-01-01          NaN
# 2019-02-01          NaN
# 2019-03-01          NaN
# 2019-04-01          NaN
# 2019-05-01          NaN
# 2019-06-01          NaN
# 2019-07-01          NaN
# 2019-08-01          NaN
# 2019-09-01      62686.0
# 2019-10-01      74426.0
# 2019-11-01      91347.0
# 2019-12-01      60600.0
# 2020-01-01      37374.0
# 2020-02-01      30737.0
# 2020-03-01      29683.0
# 2020-04-01      34788.0
# 2020-05-01      43408.0
# 2020-06-01      64323.0
# 2020-07-01      94574.0
# 2020-08-01     109171.0
# 2020-09-01     108329.0
# 2020-10-01      84031.0
# 2020-11-01      70140.0
# 2020-12-01      49066.0
# 2021-01-01      40363.0
# 2021-02-01      31950.0
# 2021-03-01      26500.0
# 2021-04-01      32716.0
# 2021-05-01      46216.0
# 2021-06-01      64406.0
# 2021-07-01     115693.0
# 2021-08-01     139498.0
# 2021-09-01      81038.0
# 2021-10-01      77930.0
# 2021-11-01      67706.0
# 2021-12-01      49801.0
# 2022-01-01      40984.0
# 2022-02-01      20298.0
# 2022-03-01      39907.0
# 2022-04-01      34366.0
# 2022-05-01      41168.0
# 2022-06-01     104512.0
# 2022-07-01     107132.0
# 2022-08-01     132203.0
# 2022-09-01      65638.0
# 2022-10-01     119304.0
# 2022-11-01      70494.0
# 2022-12-01      56667.0
# 2023-01-01      50000.0
# 2023-02-01      40000.0
# 2023-03-01      39633.0
# 2023-04-01      45189.0
# 2023-05-01      48868.0
# 2023-06-01      78522.0
# 2023-07-01     106300.0
# 2023-08-01     122964.0
# 2023-09-01      70232.0
# 2023-10-01      90139.0
# 2023-11-01      85600.0
# 2023-12-01      60633.0

# %% [markdown]
# # Train/Test Split

# %%
train= sales_h[:54]
test=sales_h[54:]

# %%
fig,ax=plt.subplots(figsize=(10,4))
train['Sales'].plot(ax=ax,label='Train set',title='Train/Test')
test['Sales'].plot(ax=ax,label='Test set')
plt.legend(['Train','Test'])
plt.show()

# %%
len(train)
# Out:
# 54

# %%
x_train = train.drop(columns=['Sales'])
y_train=train['Sales']
x_test=test.drop(columns=['Sales'])
y_test=test['Sales']

# %%
from sklearn.model_selection import GridSearchCV


# Define the parameter grid
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.001,0.01, 0.1, 0.2],
    'n_estimators': [100, 500, 1000, 2000],
    'colsample_bytree': [0.7, 0.8, 0.9, 1.0],
    'subsample': [0.7, 0.8, 0.9, 1.0]
}

# Instantiate the XGBoost regressor
regressor = xgb.XGBRegressor(objective='reg:squarederror')

# Instantiate GridSearchCV
grid_search = GridSearchCV(estimator=regressor, param_grid=param_grid, 
                           cv=5, scoring='neg_mean_squared_error', 
                           verbose=2, n_jobs=-1)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Access the best parameters
best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

print("Best parameters:", best_params)
print("Best estimator:", best_estimator)
# Out:
# Fitting 5 folds for each of 768 candidates, totalling 3840 fits
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'subsample': 0.7}
# Best estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=500,
                       objective='reg:squarederror',
                       max_depth=5,
                       colsample_bytree=0.7,
                       subsample= 0.7,
                       early_stopping_rounds=50,
                       learning_rate=0.01)

reg.fit(x_train, y_train,
        eval_set=[(x_train, y_train), (x_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:72214.94346	validation_1-rmse:85176.77693
# [100]	validation_0-rmse:31653.76329	validation_1-rmse:43783.83318
# [200]	validation_0-rmse:15695.12344	validation_1-rmse:26975.98916
# [300]	validation_0-rmse:8719.46229	validation_1-rmse:19678.37335
# [400]	validation_0-rmse:5439.96051	validation_1-rmse:16535.04414
# [499]	validation_0-rmse:3825.85909	validation_1-rmse:15130.58086
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
reg.best_iteration
# Out:
# 499

# %%
results = reg.evals_result()

plt.figure(figsize=(10,7))
plt.plot(results["validation_0"]["rmse"], label="Training loss")
plt.plot(results["validation_1"]["rmse"], label="Validation loss")
plt.axvline(499,color='green',ls='--', label="Optimal tree number")
plt.xlabel("Number of trees")
plt.ylabel("Loss")
plt.legend()

# %%
pred=reg.predict(x_test)
sales_h['prediction']=[None]*len(train) + list(pred)

ax = sales_h['Sales'].plot(figsize=(15, 5))
sales_h['prediction'].plot()
plt.legend(['Actual Sales', 'Predictions'])
ax.set_title('Product H: Actual Sales and Prediction')
plt.show()

# %%
mae_xgb= mean_absolute_error(test['Sales'],pred)
mse_xgb=mean_squared_error(test['Sales'], pred)
mape_xgb= mean_absolute_percentage_error(test['Sales'],pred)
rmse_xgb= np.sqrt(mean_squared_error(test['Sales'],pred))

print(f'MAE - XGBoost: {mae_xgb:0.3f}')
print(f'MAPE - XGBoost: {mape_xgb:0.3f}')
print(f'MSE - XGBoost: {mse_xgb:0.3f}')
print(f'RMSE - XGBoost: {rmse_xgb:0.3f}')
# Out:
# MAE - XGBoost: 11414.186
# MAPE - XGBoost: 0.116
# MSE - XGBoost: 228934474.172
# RMSE - XGBoost: 15130.581

# %%
from xgboost import plot_importance

_ = plot_importance(reg, height=0.9)
