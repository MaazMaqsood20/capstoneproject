# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.metrics import mean_squared_error,mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score
color_pal=sns.color_palette()

# %%
df=pd.read_csv('product k.csv', parse_dates=['Month-Year'], index_col='Month-Year')

# %%
df.head()
# Out:
#            Product Name Product Category     Month  Year   Sales  Market Size  \
# Month-Year
# 2019-01-01    Product K     Multivitamin   January  2019  505010       797644
# 2019-02-01    Product K     Multivitamin  February  2019  521132       823109
# 2019-03-01    Product K     Multivitamin     March  2019  580897       917505
# 2019-04-01    Product K     Multivitamin     April  2019  612559       967514
# 2019-05-01    Product K     Multivitamin       May  2019  550697       869805
#
#             Marketing Expense  Month No.
# Month-Year
# 2019-01-01            8355561          1
# 2019-02-01            8622305          2
# 2019-03-01            9611137          3
# 2019-04-01           10134996          4
# 2019-05-01            9111468          5

# %%
sales_k= df.drop(['Product Name','Product Category','Month'],axis=1)

# %%
sales_k.head()
# Out:
#             Year   Sales  Market Size  Marketing Expense  Month No.
# Month-Year
# 2019-01-01  2019  505010       797644            8355561          1
# 2019-02-01  2019  521132       823109            8622305          2
# 2019-03-01  2019  580897       917505            9611137          3
# 2019-04-01  2019  612559       967514           10134996          4
# 2019-05-01  2019  550697       869805            9111468          5

# %%
sales_k['Sales'].plot(figsize=(12,6),color=color_pal[2],title='Product K')
# Out:
# <Axes: title={'center': 'Product K'}, xlabel='Month-Year'>

# %%
sales_k['Sales'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Visualization

# %%
sales_k.head()
# Out:
#             Year   Sales  Market Size  Marketing Expense  Month No.
# Month-Year
# 2019-01-01  2019  505010       797644            8355561          1
# 2019-02-01  2019  521132       823109            8622305          2
# 2019-03-01  2019  580897       917505            9611137          3
# 2019-04-01  2019  612559       967514           10134996          4
# 2019-05-01  2019  550697       869805            9111468          5

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=sales_k, x='Month No.',y='Sales')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=sales_k, x='Year',y='Sales')
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
sales_k= df.drop(['Product Name','Product Category','Month','Month No.','Year'],axis=1)

# %%
sales_k['quarter'] = sales_k.index.quarter
sales_k['month'] = sales_k.index.month
sales_k['year'] = sales_k.index.year

# %%
# Create lagged values
lagged_intervals = [3,4,5]  # Lagged intervals in months
for lag in lagged_intervals:
    sales_k[f'sales_lag_{lag}'] = sales_k['Sales'].shift(lag)

# %%
print(sales_k)
# Out:
#               Sales  Market Size  Marketing Expense  quarter  month  year  \
# Month-Year
# 2019-01-01   505010       797644            8355561        1      1  2019
# 2019-02-01   521132       823109            8622305        1      2  2019
# 2019-03-01   580897       917505            9611137        1      3  2019
# 2019-04-01   612559       967514           10134996        2      4  2019
# 2019-05-01   550697       869805            9111468        2      5  2019
# 2019-06-01   552137       872080            9135293        2      6  2019
# 2019-07-01   489712       773482            8102450        3      7  2019
# 2019-08-01   597098       943094            9879188        3      8  2019
# 2019-09-01   621078       980970           10275945        3      9  2019
# 2019-10-01   543258      1178924           12349572        4     10  2019
# 2019-11-01   746408       849037            8893913        4     11  2019
# 2019-12-01   537548       858056            8988387        4     12  2019
# 2020-01-01   312081       698684            1207157        1      1  2020
# 2020-02-01   455033      1018723            1760108        1      2  2020
# 2020-03-01   784102      1755439            3032976        1      3  2020
# 2020-04-01   359512       804872            1390624        2      4  2020
# 2020-05-01   438162       980952            1694850        2      5  2020
# 2020-06-01   951340      2129850            3679868        2      6  2020
# 2020-07-01   225570       505004             872525        3      7  2020
# 2020-08-01   402391       900869            1556484        3      8  2020
# 2020-09-01   769842      1723514            2977817        3      9  2020
# 2020-10-01   327210      1686108            2913189        4     10  2020
# 2020-11-01   753134      1273614            2200498        4     11  2020
# 2020-12-01   568885       732554            1265677        4     12  2020
# 2021-01-01   243900       627841            1453471        1      1  2021
# 2021-02-01   378867       975269            2257778        1      2  2021
# 2021-03-01   806927      2077169            4808712        1      3  2021
# 2021-04-01   266371       685685            1587382        2      4  2021
# 2021-05-01   790707      2035416            4712052        2      5  2021
# 2021-06-01   301207       775359            1794980        2      6  2021
# 2021-07-01   733971      1889368            4373946        3      7  2021
# 2021-08-01   317170       816450            1890108        3      8  2021
# 2021-09-01   768197      1977472            4577908        3      9  2021
# 2021-10-01   327569      1918518            4441429        4     10  2021
# 2021-11-01   745295      1520695            3520456        4     11  2021
# 2021-12-01   590751       843219            1952079        4     12  2021
# 2022-01-01   230200       558353            1575680        1      1  2022
# 2022-02-01   380866       923795            2606964        1      2  2022
# 2022-03-01  1003679      2434437            6870014        1      3  2022
# 2022-04-01   226939       550444            1553359        2      4  2022
# 2022-05-01   826087      2003685            5654427        2      5  2022
# 2022-06-01   236473       573568            1618618        2      6  2022
# 2022-07-01   784789      1903516            5371749        3      7  2022
# 2022-08-01   329037       798084            2252203        3      8  2022
# 2022-09-01   819358      1987364            5608368        3      9  2022
# 2022-10-01   330845      1889075            5330995        4     10  2022
# 2022-11-01   778835       999733            2821262        4     11  2022
# 2022-12-01   412174       802469            2264579        4     12  2022
# 2023-01-01   234804       558252            2201850        1      1  2023
# 2023-02-01   405296       963600            3800621        1      2  2023
# 2023-03-01   820679      1951182            7695831        1      3  2023
# 2023-04-01   320174       761221            3002398        2      4  2023
# 2023-05-01   842609      2003321            7901477        2      5  2023
# 2023-06-01   316593       752707            2968817        2      6  2023
# 2023-07-01   800485      1903171            7506464        3      7  2023
# 2023-08-01   335618       797939            3147222        3      8  2023
# 2023-09-01   835745      1987002            7837111        3      9  2023
# 2023-10-01   337462      1888732            7449515        4     10  2023
# 2023-11-01   794412       999551            3942416        4     11  2023
# 2023-12-01   420417       802323            3164514        4     12  2023
#
#             sales_lag_3  sales_lag_4  sales_lag_5
# Month-Year
# 2019-01-01          NaN          NaN          NaN
# 2019-02-01          NaN          NaN          NaN
# 2019-03-01          NaN          NaN          NaN
# 2019-04-01     505010.0          NaN          NaN
# 2019-05-01     521132.0     505010.0          NaN
# 2019-06-01     580897.0     521132.0     505010.0
# 2019-07-01     612559.0     580897.0     521132.0
# 2019-08-01     550697.0     612559.0     580897.0
# 2019-09-01     552137.0     550697.0     612559.0
# 2019-10-01     489712.0     552137.0     550697.0
# 2019-11-01     597098.0     489712.0     552137.0
# 2019-12-01     621078.0     597098.0     489712.0
# 2020-01-01     543258.0     621078.0     597098.0
# 2020-02-01     746408.0     543258.0     621078.0
# 2020-03-01     537548.0     746408.0     543258.0
# 2020-04-01     312081.0     537548.0     746408.0
# 2020-05-01     455033.0     312081.0     537548.0
# 2020-06-01     784102.0     455033.0     312081.0
# 2020-07-01     359512.0     784102.0     455033.0
# 2020-08-01     438162.0     359512.0     784102.0
# 2020-09-01     951340.0     438162.0     359512.0
# 2020-10-01     225570.0     951340.0     438162.0
# 2020-11-01     402391.0     225570.0     951340.0
# 2020-12-01     769842.0     402391.0     225570.0
# 2021-01-01     327210.0     769842.0     402391.0
# 2021-02-01     753134.0     327210.0     769842.0
# 2021-03-01     568885.0     753134.0     327210.0
# 2021-04-01     243900.0     568885.0     753134.0
# 2021-05-01     378867.0     243900.0     568885.0
# 2021-06-01     806927.0     378867.0     243900.0
# 2021-07-01     266371.0     806927.0     378867.0
# 2021-08-01     790707.0     266371.0     806927.0
# 2021-09-01     301207.0     790707.0     266371.0
# 2021-10-01     733971.0     301207.0     790707.0
# 2021-11-01     317170.0     733971.0     301207.0
# 2021-12-01     768197.0     317170.0     733971.0
# 2022-01-01     327569.0     768197.0     317170.0
# 2022-02-01     745295.0     327569.0     768197.0
# 2022-03-01     590751.0     745295.0     327569.0
# 2022-04-01     230200.0     590751.0     745295.0
# 2022-05-01     380866.0     230200.0     590751.0
# 2022-06-01    1003679.0     380866.0     230200.0
# 2022-07-01     226939.0    1003679.0     380866.0
# 2022-08-01     826087.0     226939.0    1003679.0
# 2022-09-01     236473.0     826087.0     226939.0
# 2022-10-01     784789.0     236473.0     826087.0
# 2022-11-01     329037.0     784789.0     236473.0
# 2022-12-01     819358.0     329037.0     784789.0
# 2023-01-01     330845.0     819358.0     329037.0
# 2023-02-01     778835.0     330845.0     819358.0
# 2023-03-01     412174.0     778835.0     330845.0
# 2023-04-01     234804.0     412174.0     778835.0
# 2023-05-01     405296.0     234804.0     412174.0
# 2023-06-01     820679.0     405296.0     234804.0
# 2023-07-01     320174.0     820679.0     405296.0
# 2023-08-01     842609.0     320174.0     820679.0
# 2023-09-01     316593.0     842609.0     320174.0
# 2023-10-01     800485.0     316593.0     842609.0
# 2023-11-01     335618.0     800485.0     316593.0
# 2023-12-01     835745.0     335618.0     800485.0

# %% [markdown]
# # Train/Test Split

# %%
train= sales_k[:57]
test=sales_k[57:]

# %%
fig,ax=plt.subplots(figsize=(10,4))
train['Sales'].plot(ax=ax,label='Train set',title='Train/Test')
test['Sales'].plot(ax=ax,label='Test set')
plt.legend(['Train','Test'])
plt.show()

# %%
len(train)
# Out:
# 57

# %%
x_train = train.drop(columns=['Sales'])
y_train=train['Sales']
x_test=test.drop(columns=['Sales'])
y_test=test['Sales']

# %%
from sklearn.model_selection import GridSearchCV


# Define the parameter grid
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.001,0.01, 0.1, 0.2],
    'n_estimators': [100, 500, 1000, 2000],
    'colsample_bytree': [0.7, 0.8, 0.9, 1.0],
    'subsample': [0.7, 0.8, 0.9, 1.0]
}

# Instantiate the XGBoost regressor
regressor = xgb.XGBRegressor(objective='reg:squarederror')

# Instantiate GridSearchCV
grid_search = GridSearchCV(estimator=regressor, param_grid=param_grid, 
                           cv=5, scoring='neg_mean_squared_error', 
                           verbose=2, n_jobs=-1)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Access the best parameters
best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

print("Best parameters:", best_params)
print("Best estimator:", best_estimator)
# Out:
# Fitting 5 folds for each of 768 candidates, totalling 3840 fits
# Best parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 2000, 'subsample': 0.8}
# Best estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=2000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=2000,
                       objective='reg:squarederror',
                       max_depth=3,
                       colsample_bytree=0.8,
                       subsample= 0.8,
                       early_stopping_rounds=50,
                       learning_rate=0.01)

reg.fit(x_train, y_train,
        eval_set=[(x_train, y_train), (x_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:577304.86541	validation_1-rmse:549696.91528
# [100]	validation_0-rmse:242594.33256	validation_1-rmse:237460.00958
# [200]	validation_0-rmse:112095.56447	validation_1-rmse:113424.20789
# [300]	validation_0-rmse:61094.92680	validation_1-rmse:66553.63487
# [400]	validation_0-rmse:38924.80454	validation_1-rmse:44634.05635
# [500]	validation_0-rmse:27799.13354	validation_1-rmse:36423.72999
# [600]	validation_0-rmse:21490.44089	validation_1-rmse:33155.47183
# [700]	validation_0-rmse:17025.26793	validation_1-rmse:30870.66923
# [800]	validation_0-rmse:13758.07498	validation_1-rmse:29013.55049
# [900]	validation_0-rmse:11154.45510	validation_1-rmse:28668.18873
# [913]	validation_0-rmse:10877.68879	validation_1-rmse:28777.14519
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=2000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
reg.best_iteration
# Out:
# 863

# %%
results = reg.evals_result()

plt.figure(figsize=(10,7))
plt.plot(results["validation_0"]["rmse"], label="Training loss")
plt.plot(results["validation_1"]["rmse"], label="Validation loss")
plt.axvline(863,color='green',ls='--', label="Optimal tree number")
plt.xlabel("Number of trees")
plt.ylabel("Loss")
plt.legend()

# %%
pred=reg.predict(x_test)
sales_k['prediction']=[None]*len(train) + list(pred)

ax = sales_k['Sales'].plot(figsize=(15, 5))
sales_k['prediction'].plot()
plt.legend(['Actual Sales', 'Predictions'])
ax.set_title('Product K: Actual Sales and Prediction')
plt.show()

# %%
mae_xgb= mean_absolute_error(test['Sales'],pred)
mse_xgb=mean_squared_error(test['Sales'], pred)
mape_xgb= mean_absolute_percentage_error(test['Sales'],pred)
rmse_xgb= np.sqrt(mean_squared_error(test['Sales'],pred))

print(f'MAE - XGBoost: {mae_xgb:0.3f}')
print(f'MAPE - XGBoost: {mape_xgb:0.3f}')
print(f'MSE - XGBoost: {mse_xgb:0.3f}')
print(f'RMSE - XGBoost: {rmse_xgb:0.3f}')
# Out:
# MAE - XGBoost: 27633.938
# MAPE - XGBoost: 0.056
# MSE - XGBoost: 817997428.491
# RMSE - XGBoost: 28600.654

# %%
sales_k[['Sales','prediction']].tail(3)
# Out:
#              Sales   prediction
# Month-Year
# 2023-10-01  337462  360587.5625
# 2023-11-01  794412  756381.3750
# 2023-12-01  420417  398671.3750

# %%
from xgboost import plot_importance

_ = plot_importance(reg, height=0.9)
