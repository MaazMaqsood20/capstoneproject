# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.metrics import mean_squared_error,mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score
color_pal=sns.color_palette()

# %%
df=pd.read_csv('product c.csv', parse_dates=['Month-Year'], index_col='Month-Year')

# %%
sales_c= df.drop(['Product Name','Product Category','Month','Market Size', 'Marketing Expense'],axis=1)

# %%
sales_c
# Out:
#             Year    Sales  Month No.
# Month-Year
# 2019-01-01  2019   496334          1
# 2019-02-01  2019   306455          2
# 2019-03-01  2019   476270          3
# 2019-04-01  2019   628463          4
# 2019-05-01  2019   366750          5
# 2019-06-01  2019   352324          6
# 2019-07-01  2019   657300          7
# 2019-08-01  2019   429552          8
# 2019-09-01  2019   499906          9
# 2019-10-01  2019   844520         10
# 2019-11-01  2019   548192         11
# 2019-12-01  2019   805391         12
# 2020-01-01  2020   486322          1
# 2020-02-01  2020   642661          2
# 2020-03-01  2020   955368          3
# 2020-04-01  2020   477644          4
# 2020-05-01  2020   647027          5
# 2020-06-01  2020   644756          6
# 2020-07-01  2020   985263          7
# 2020-08-01  2020   654235          8
# 2020-09-01  2020   962755          9
# 2020-10-01  2020   627632         10
# 2020-11-01  2020   563861         11
# 2020-12-01  2020  1229818         12
# 2021-01-01  2021   478264          1
# 2021-02-01  2021   897459          2
# 2021-03-01  2021   518534          3
# 2021-04-01  2021   962523          4
# 2021-05-01  2021   585032          5
# 2021-06-01  2021   998609          6
# 2021-07-01  2021   437516          7
# 2021-08-01  2021   744043          8
# 2021-09-01  2021  1273588          9
# 2021-10-01  2021   786419         10
# 2021-11-01  2021   982234         11
# 2021-12-01  2021  1162977         12
# 2022-01-01  2022   670760          1
# 2022-02-01  2022   376791          2
# 2022-03-01  2022  1229637          3
# 2022-04-01  2022   627375          4
# 2022-05-01  2022  1148785          5
# 2022-06-01  2022   617059          6
# 2022-07-01  2022  1105307          7
# 2022-08-01  2022   670524          8
# 2022-09-01  2022  1235742          9
# 2022-10-01  2022   670524         10
# 2022-11-01  2022   879924         11
# 2022-12-01  2022   887916         12
# 2023-01-01  2023   684175          1
# 2023-02-01  2023   675038          2
# 2023-03-01  2023  1185258          3
# 2023-04-01  2023   639923          4
# 2023-05-01  2023  1171761          5
# 2023-06-01  2023   629400          6
# 2023-07-01  2023  1127413          7
# 2023-08-01  2023   683935          8
# 2023-09-01  2023  1258717          9
# 2023-10-01  2023   683935         10
# 2023-11-01  2023   806218         11
# 2023-12-01  2023   816978         12

# %%
sales_c['Sales'].plot(figsize=(12,6),color=color_pal[2],title='Product C')
# Out:
# <Axes: title={'center': 'Product C'}, xlabel='Month-Year'>

# %%
sales_c['Sales'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Visualization

# %%
sales_c.head()
# Out:
#             Year   Sales  Month No.
# Month-Year
# 2019-01-01  2019  496334          1
# 2019-02-01  2019  306455          2
# 2019-03-01  2019  476270          3
# 2019-04-01  2019  628463          4
# 2019-05-01  2019  366750          5

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=sales_c, x='Month No.',y='Sales')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=sales_c, x='Year',y='Sales')
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
sales_c=df.drop(['Product Name','Product Category','Month','Market Size', 'Marketing Expense','Month No.','Year'],axis=1)

# %%
sales_c['quarter'] = sales_c.index.quarter
sales_c['month'] = sales_c.index.month
sales_c['year'] = sales_c.index.year

# %%
# Create lagged values
lagged_intervals = [6, 7, 8]  # Lagged intervals in months
for lag in lagged_intervals:
    sales_c[f'sales_lag_{lag}'] = sales_c['Sales'].shift(lag)

# %%
print(sales_c)
# Out:
#               Sales  quarter  month  year  sales_lag_6  sales_lag_7  \
# Month-Year
# 2019-01-01   496334        1      1  2019          NaN          NaN
# 2019-02-01   306455        1      2  2019          NaN          NaN
# 2019-03-01   476270        1      3  2019          NaN          NaN
# 2019-04-01   628463        2      4  2019          NaN          NaN
# 2019-05-01   366750        2      5  2019          NaN          NaN
# 2019-06-01   352324        2      6  2019          NaN          NaN
# 2019-07-01   657300        3      7  2019     496334.0          NaN
# 2019-08-01   429552        3      8  2019     306455.0     496334.0
# 2019-09-01   499906        3      9  2019     476270.0     306455.0
# 2019-10-01   844520        4     10  2019     628463.0     476270.0
# 2019-11-01   548192        4     11  2019     366750.0     628463.0
# 2019-12-01   805391        4     12  2019     352324.0     366750.0
# 2020-01-01   486322        1      1  2020     657300.0     352324.0
# 2020-02-01   642661        1      2  2020     429552.0     657300.0
# 2020-03-01   955368        1      3  2020     499906.0     429552.0
# 2020-04-01   477644        2      4  2020     844520.0     499906.0
# 2020-05-01   647027        2      5  2020     548192.0     844520.0
# 2020-06-01   644756        2      6  2020     805391.0     548192.0
# 2020-07-01   985263        3      7  2020     486322.0     805391.0
# 2020-08-01   654235        3      8  2020     642661.0     486322.0
# 2020-09-01   962755        3      9  2020     955368.0     642661.0
# 2020-10-01   627632        4     10  2020     477644.0     955368.0
# 2020-11-01   563861        4     11  2020     647027.0     477644.0
# 2020-12-01  1229818        4     12  2020     644756.0     647027.0
# 2021-01-01   478264        1      1  2021     985263.0     644756.0
# 2021-02-01   897459        1      2  2021     654235.0     985263.0
# 2021-03-01   518534        1      3  2021     962755.0     654235.0
# 2021-04-01   962523        2      4  2021     627632.0     962755.0
# 2021-05-01   585032        2      5  2021     563861.0     627632.0
# 2021-06-01   998609        2      6  2021    1229818.0     563861.0
# 2021-07-01   437516        3      7  2021     478264.0    1229818.0
# 2021-08-01   744043        3      8  2021     897459.0     478264.0
# 2021-09-01  1273588        3      9  2021     518534.0     897459.0
# 2021-10-01   786419        4     10  2021     962523.0     518534.0
# 2021-11-01   982234        4     11  2021     585032.0     962523.0
# 2021-12-01  1162977        4     12  2021     998609.0     585032.0
# 2022-01-01   670760        1      1  2022     437516.0     998609.0
# 2022-02-01   376791        1      2  2022     744043.0     437516.0
# 2022-03-01  1229637        1      3  2022    1273588.0     744043.0
# 2022-04-01   627375        2      4  2022     786419.0    1273588.0
# 2022-05-01  1148785        2      5  2022     982234.0     786419.0
# 2022-06-01   617059        2      6  2022    1162977.0     982234.0
# 2022-07-01  1105307        3      7  2022     670760.0    1162977.0
# 2022-08-01   670524        3      8  2022     376791.0     670760.0
# 2022-09-01  1235742        3      9  2022    1229637.0     376791.0
# 2022-10-01   670524        4     10  2022     627375.0    1229637.0
# 2022-11-01   879924        4     11  2022    1148785.0     627375.0
# 2022-12-01   887916        4     12  2022     617059.0    1148785.0
# 2023-01-01   684175        1      1  2023    1105307.0     617059.0
# 2023-02-01   675038        1      2  2023     670524.0    1105307.0
# 2023-03-01  1185258        1      3  2023    1235742.0     670524.0
# 2023-04-01   639923        2      4  2023     670524.0    1235742.0
# 2023-05-01  1171761        2      5  2023     879924.0     670524.0
# 2023-06-01   629400        2      6  2023     887916.0     879924.0
# 2023-07-01  1127413        3      7  2023     684175.0     887916.0
# 2023-08-01   683935        3      8  2023     675038.0     684175.0
# 2023-09-01  1258717        3      9  2023    1185258.0     675038.0
# 2023-10-01   683935        4     10  2023     639923.0    1185258.0
# 2023-11-01   806218        4     11  2023    1171761.0     639923.0
# 2023-12-01   816978        4     12  2023     629400.0    1171761.0
#
#             sales_lag_8
# Month-Year
# 2019-01-01          NaN
# 2019-02-01          NaN
# 2019-03-01          NaN
# 2019-04-01          NaN
# 2019-05-01          NaN
# 2019-06-01          NaN
# 2019-07-01          NaN
# 2019-08-01          NaN
# 2019-09-01     496334.0
# 2019-10-01     306455.0
# 2019-11-01     476270.0
# 2019-12-01     628463.0
# 2020-01-01     366750.0
# 2020-02-01     352324.0
# 2020-03-01     657300.0
# 2020-04-01     429552.0
# 2020-05-01     499906.0
# 2020-06-01     844520.0
# 2020-07-01     548192.0
# 2020-08-01     805391.0
# 2020-09-01     486322.0
# 2020-10-01     642661.0
# 2020-11-01     955368.0
# 2020-12-01     477644.0
# 2021-01-01     647027.0
# 2021-02-01     644756.0
# 2021-03-01     985263.0
# 2021-04-01     654235.0
# 2021-05-01     962755.0
# 2021-06-01     627632.0
# 2021-07-01     563861.0
# 2021-08-01    1229818.0
# 2021-09-01     478264.0
# 2021-10-01     897459.0
# 2021-11-01     518534.0
# 2021-12-01     962523.0
# 2022-01-01     585032.0
# 2022-02-01     998609.0
# 2022-03-01     437516.0
# 2022-04-01     744043.0
# 2022-05-01    1273588.0
# 2022-06-01     786419.0
# 2022-07-01     982234.0
# 2022-08-01    1162977.0
# 2022-09-01     670760.0
# 2022-10-01     376791.0
# 2022-11-01    1229637.0
# 2022-12-01     627375.0
# 2023-01-01    1148785.0
# 2023-02-01     617059.0
# 2023-03-01    1105307.0
# 2023-04-01     670524.0
# 2023-05-01    1235742.0
# 2023-06-01     670524.0
# 2023-07-01     879924.0
# 2023-08-01     887916.0
# 2023-09-01     684175.0
# 2023-10-01     675038.0
# 2023-11-01    1185258.0
# 2023-12-01     639923.0

# %% [markdown]
# # Train/Test Split

# %%
train= sales_c[:54]
test=sales_c[54:]

# %%
fig,ax=plt.subplots(figsize=(10,4))
train['Sales'].plot(ax=ax,label='Train set',title='Train/Test')
test['Sales'].plot(ax=ax,label='Test set')
plt.legend(['Train','Test'])
plt.show()

# %%
train.head()
# Out:
#              Sales  quarter  month  year  sales_lag_6  sales_lag_7  \
# Month-Year
# 2019-01-01  496334        1      1  2019          NaN          NaN
# 2019-02-01  306455        1      2  2019          NaN          NaN
# 2019-03-01  476270        1      3  2019          NaN          NaN
# 2019-04-01  628463        2      4  2019          NaN          NaN
# 2019-05-01  366750        2      5  2019          NaN          NaN
#
#             sales_lag_8
# Month-Year
# 2019-01-01          NaN
# 2019-02-01          NaN
# 2019-03-01          NaN
# 2019-04-01          NaN
# 2019-05-01          NaN

# %%
x_train = train.drop(columns=['Sales'])
y_train=train['Sales']
x_test=test.drop(columns=['Sales'])
y_test=test['Sales']

# %%
from sklearn.model_selection import GridSearchCV


# Define the parameter grid
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.001,0.01, 0.1, 0.2],
    'n_estimators': [100, 500, 1000, 2000],
    'colsample_bytree': [0.7, 0.8, 0.9, 1.0],
    'subsample': [0.7, 0.8, 0.9, 1.0]
}

# Instantiate the XGBoost regressor
regressor = xgb.XGBRegressor(objective='reg:squarederror')

# Instantiate GridSearchCV
grid_search = GridSearchCV(estimator=regressor, param_grid=param_grid, 
                           cv=5, scoring='neg_mean_squared_error', 
                           verbose=2, n_jobs=-1)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Access the best parameters
best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

print("Best parameters:", best_params)
print("Best estimator:", best_estimator)
# Out:
# Fitting 5 folds for each of 768 candidates, totalling 3840 fits
# Best parameters: {'colsample_bytree': 0.9, 'learning_rate': 0.001, 'max_depth': 7, 'n_estimators': 500, 'subsample': 1.0}
# Best estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.001, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=500,
                       objective='reg:squarederror',
                       max_depth=7,
                       colsample_bytree=0.9,
                       subsample= 1.0,
                       early_stopping_rounds=50,
                       learning_rate=0.001)

reg.fit(x_train, y_train,
        eval_set=[(x_train, y_train), (x_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:789420.18463	validation_1-rmse:921929.80173
# [100]	validation_0-rmse:722688.30070	validation_1-rmse:845725.46319
# [200]	validation_0-rmse:662504.60786	validation_1-rmse:777096.48971
# [300]	validation_0-rmse:608224.65336	validation_1-rmse:714369.83479
# [400]	validation_0-rmse:559276.15247	validation_1-rmse:657284.54500
# [499]	validation_0-rmse:515577.69730	validation_1-rmse:605301.89038
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.001, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
reg.best_iteration
# Out:
# 499

# %%
results = reg.evals_result()

plt.figure(figsize=(10,7))
plt.plot(results["validation_0"]["rmse"], label="Training loss")
plt.plot(results["validation_1"]["rmse"], label="Validation loss")
plt.axvline(499,color='green',ls='--', label="Optimal tree number")
plt.xlabel("Number of trees")
plt.ylabel("Loss")
plt.legend()

# %%
pred=reg.predict(x_test)
sales_c['prediction']=[None]*len(train) + list(pred)

ax = sales_c['Sales'].plot(figsize=(15, 5))
sales_c['prediction'].plot()
plt.legend(['Actual Sales', 'Predictions'])
ax.set_title('Product C: Actual Sales and Prediction')
plt.show()

# %%
mae_xgb= mean_absolute_error(test['Sales'],pred)
mse_xgb=mean_squared_error(test['Sales'], pred)
mape_xgb= mean_absolute_percentage_error(test['Sales'],pred)
rmse_xgb= np.sqrt(mean_squared_error(test['Sales'],pred))

print(f'MAE - XGBoost: {mae_xgb:0.3f}')
print(f'MAPE - XGBoost: {mape_xgb:0.3f}')
print(f'MSE - XGBoost: {mse_xgb:0.3f}')
print(f'RMSE - XGBoost: {rmse_xgb:0.3f}')
# Out:
# MAE - XGBoost: 564059.458
# MAPE - XGBoost: 0.609
# MSE - XGBoost: 366390367987.516
# RMSE - XGBoost: 605301.882

# %%
from xgboost import plot_importance

_ = plot_importance(reg, height=0.9)
