# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.metrics import mean_squared_error,mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score
color_pal=sns.color_palette()

# %%
df=pd.read_csv('product e.csv', parse_dates=['Month-Year'], index_col='Month-Year')

# %%
df.head()
# Out:
#            Product Name         Product Category     Month  Year  Sales  \
# Month-Year
# 2019-01-01    Product E  Anti Biotic Respiratory   January  2019  57650
# 2019-02-01    Product E  Anti Biotic Respiratory  February  2019  66035
# 2019-03-01    Product E  Anti Biotic Respiratory     March  2019  88208
# 2019-04-01    Product E  Anti Biotic Respiratory     April  2019  74712
# 2019-05-01    Product E  Anti Biotic Respiratory       May  2019  61172
#
#             Market Size  Marketing Expense  Month No.
# Month-Year
# 2019-01-01       303130            2978499          1
# 2019-02-01       347219            3411712          2
# 2019-03-01       463807            4557285          3
# 2019-04-01       392844            3860011          4
# 2019-05-01       321649            3160464          5

# %%
sales_e= df.drop(['Product Name','Product Category','Month','Market Size', 'Marketing Expense'],axis=1)

# %%
sales_e
# Out:
#             Year   Sales  Month No.
# Month-Year
# 2019-01-01  2019   57650          1
# 2019-02-01  2019   66035          2
# 2019-03-01  2019   88208          3
# 2019-04-01  2019   74712          4
# 2019-05-01  2019   61172          5
# 2019-06-01  2019   48721          6
# 2019-07-01  2019   51556          7
# 2019-08-01  2019   70726          8
# 2019-09-01  2019   70502          9
# 2019-10-01  2019   85353         10
# 2019-11-01  2019  100056         11
# 2019-12-01  2019   92839         12
# 2020-01-01  2020  107545          1
# 2020-02-01  2020   93962          2
# 2020-03-01  2020   76159          3
# 2020-04-01  2020   62855          4
# 2020-05-01  2020   64042          5
# 2020-06-01  2020   57547          6
# 2020-07-01  2020   54213          7
# 2020-08-01  2020   71457          8
# 2020-09-01  2020   89345          9
# 2020-10-01  2020   92665         10
# 2020-11-01  2020  136850         11
# 2020-12-01  2020  128031         12
# 2021-01-01  2021   55925          1
# 2021-02-01  2021   71334          2
# 2021-03-01  2021   81457          3
# 2021-04-01  2021   66872          4
# 2021-05-01  2021   62928          5
# 2021-06-01  2021   54928          6
# 2021-07-01  2021   48096          7
# 2021-08-01  2021   69002          8
# 2021-09-01  2021  116735          9
# 2021-10-01  2021   59081         10
# 2021-11-01  2021  173454         11
# 2021-12-01  2021   85253         12
# 2022-01-01  2022   67875          1
# 2022-02-01  2022  126411          2
# 2022-03-01  2022   46889          3
# 2022-04-01  2022   70909          4
# 2022-05-01  2022   65455          5
# 2022-06-01  2022   63687          6
# 2022-07-01  2022   61818          7
# 2022-08-01  2022   80036          8
# 2022-09-01  2022   95134          9
# 2022-10-01  2022  106073         10
# 2022-11-01  2022  117303         11
# 2022-12-01  2022  112046         12
# 2023-01-01  2023   71268          1
# 2023-02-01  2023   97965          2
# 2023-03-01  2023   91393          3
# 2023-04-01  2023   76364          4
# 2023-05-01  2023   71591          5
# 2023-06-01  2023   73457          6
# 2023-07-01  2023   64909          7
# 2023-08-01  2023   81175          8
# 2023-09-01  2023   96096          9
# 2023-10-01  2023  107582         10
# 2023-11-01  2023  119374         11
# 2023-12-01  2023  113854         12

# %%
sales_e['Sales'].plot(figsize=(12,6),color=color_pal[2],title='Product E')
# Out:
# <Axes: title={'center': 'Product E'}, xlabel='Month-Year'>

# %%
sales_e['Sales'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Visualization

# %%
sales_e.head()
# Out:
#             Year  Sales  Month No.
# Month-Year
# 2019-01-01  2019  57650          1
# 2019-02-01  2019  66035          2
# 2019-03-01  2019  88208          3
# 2019-04-01  2019  74712          4
# 2019-05-01  2019  61172          5

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=sales_e, x='Month No.',y='Sales')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=sales_e, x='Year',y='Sales')
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
sales_e =df.drop(['Product Name','Product Category','Month','Market Size', 'Marketing Expense','Month No.','Year'],axis=1)

# %%
sales_e['quarter'] = sales_e.index.quarter
sales_e['month'] = sales_e.index.month
sales_e['year'] = sales_e.index.year

# %%
# Create lagged values
lagged_intervals = [6, 7, 8]  # Lagged intervals in months
for lag in lagged_intervals:
    sales_e[f'sales_lag_{lag}'] = sales_e['Sales'].shift(lag)

# %%
print(sales_e)
# Out:
#              Sales  quarter  month  year  sales_lag_6  sales_lag_7  \
# Month-Year
# 2019-01-01   57650        1      1  2019          NaN          NaN
# 2019-02-01   66035        1      2  2019          NaN          NaN
# 2019-03-01   88208        1      3  2019          NaN          NaN
# 2019-04-01   74712        2      4  2019          NaN          NaN
# 2019-05-01   61172        2      5  2019          NaN          NaN
# 2019-06-01   48721        2      6  2019          NaN          NaN
# 2019-07-01   51556        3      7  2019      57650.0          NaN
# 2019-08-01   70726        3      8  2019      66035.0      57650.0
# 2019-09-01   70502        3      9  2019      88208.0      66035.0
# 2019-10-01   85353        4     10  2019      74712.0      88208.0
# 2019-11-01  100056        4     11  2019      61172.0      74712.0
# 2019-12-01   92839        4     12  2019      48721.0      61172.0
# 2020-01-01  107545        1      1  2020      51556.0      48721.0
# 2020-02-01   93962        1      2  2020      70726.0      51556.0
# 2020-03-01   76159        1      3  2020      70502.0      70726.0
# 2020-04-01   62855        2      4  2020      85353.0      70502.0
# 2020-05-01   64042        2      5  2020     100056.0      85353.0
# 2020-06-01   57547        2      6  2020      92839.0     100056.0
# 2020-07-01   54213        3      7  2020     107545.0      92839.0
# 2020-08-01   71457        3      8  2020      93962.0     107545.0
# 2020-09-01   89345        3      9  2020      76159.0      93962.0
# 2020-10-01   92665        4     10  2020      62855.0      76159.0
# 2020-11-01  136850        4     11  2020      64042.0      62855.0
# 2020-12-01  128031        4     12  2020      57547.0      64042.0
# 2021-01-01   55925        1      1  2021      54213.0      57547.0
# 2021-02-01   71334        1      2  2021      71457.0      54213.0
# 2021-03-01   81457        1      3  2021      89345.0      71457.0
# 2021-04-01   66872        2      4  2021      92665.0      89345.0
# 2021-05-01   62928        2      5  2021     136850.0      92665.0
# 2021-06-01   54928        2      6  2021     128031.0     136850.0
# 2021-07-01   48096        3      7  2021      55925.0     128031.0
# 2021-08-01   69002        3      8  2021      71334.0      55925.0
# 2021-09-01  116735        3      9  2021      81457.0      71334.0
# 2021-10-01   59081        4     10  2021      66872.0      81457.0
# 2021-11-01  173454        4     11  2021      62928.0      66872.0
# 2021-12-01   85253        4     12  2021      54928.0      62928.0
# 2022-01-01   67875        1      1  2022      48096.0      54928.0
# 2022-02-01  126411        1      2  2022      69002.0      48096.0
# 2022-03-01   46889        1      3  2022     116735.0      69002.0
# 2022-04-01   70909        2      4  2022      59081.0     116735.0
# 2022-05-01   65455        2      5  2022     173454.0      59081.0
# 2022-06-01   63687        2      6  2022      85253.0     173454.0
# 2022-07-01   61818        3      7  2022      67875.0      85253.0
# 2022-08-01   80036        3      8  2022     126411.0      67875.0
# 2022-09-01   95134        3      9  2022      46889.0     126411.0
# 2022-10-01  106073        4     10  2022      70909.0      46889.0
# 2022-11-01  117303        4     11  2022      65455.0      70909.0
# 2022-12-01  112046        4     12  2022      63687.0      65455.0
# 2023-01-01   71268        1      1  2023      61818.0      63687.0
# 2023-02-01   97965        1      2  2023      80036.0      61818.0
# 2023-03-01   91393        1      3  2023      95134.0      80036.0
# 2023-04-01   76364        2      4  2023     106073.0      95134.0
# 2023-05-01   71591        2      5  2023     117303.0     106073.0
# 2023-06-01   73457        2      6  2023     112046.0     117303.0
# 2023-07-01   64909        3      7  2023      71268.0     112046.0
# 2023-08-01   81175        3      8  2023      97965.0      71268.0
# 2023-09-01   96096        3      9  2023      91393.0      97965.0
# 2023-10-01  107582        4     10  2023      76364.0      91393.0
# 2023-11-01  119374        4     11  2023      71591.0      76364.0
# 2023-12-01  113854        4     12  2023      73457.0      71591.0
#
#             sales_lag_8
# Month-Year
# 2019-01-01          NaN
# 2019-02-01          NaN
# 2019-03-01          NaN
# 2019-04-01          NaN
# 2019-05-01          NaN
# 2019-06-01          NaN
# 2019-07-01          NaN
# 2019-08-01          NaN
# 2019-09-01      57650.0
# 2019-10-01      66035.0
# 2019-11-01      88208.0
# 2019-12-01      74712.0
# 2020-01-01      61172.0
# 2020-02-01      48721.0
# 2020-03-01      51556.0
# 2020-04-01      70726.0
# 2020-05-01      70502.0
# 2020-06-01      85353.0
# 2020-07-01     100056.0
# 2020-08-01      92839.0
# 2020-09-01     107545.0
# 2020-10-01      93962.0
# 2020-11-01      76159.0
# 2020-12-01      62855.0
# 2021-01-01      64042.0
# 2021-02-01      57547.0
# 2021-03-01      54213.0
# 2021-04-01      71457.0
# 2021-05-01      89345.0
# 2021-06-01      92665.0
# 2021-07-01     136850.0
# 2021-08-01     128031.0
# 2021-09-01      55925.0
# 2021-10-01      71334.0
# 2021-11-01      81457.0
# 2021-12-01      66872.0
# 2022-01-01      62928.0
# 2022-02-01      54928.0
# 2022-03-01      48096.0
# 2022-04-01      69002.0
# 2022-05-01     116735.0
# 2022-06-01      59081.0
# 2022-07-01     173454.0
# 2022-08-01      85253.0
# 2022-09-01      67875.0
# 2022-10-01     126411.0
# 2022-11-01      46889.0
# 2022-12-01      70909.0
# 2023-01-01      65455.0
# 2023-02-01      63687.0
# 2023-03-01      61818.0
# 2023-04-01      80036.0
# 2023-05-01      95134.0
# 2023-06-01     106073.0
# 2023-07-01     117303.0
# 2023-08-01     112046.0
# 2023-09-01      71268.0
# 2023-10-01      97965.0
# 2023-11-01      91393.0
# 2023-12-01      76364.0

# %% [markdown]
# # Train/Test Split

# %%
train= sales_e[:54]
test=sales_e[54:]

# %%
fig,ax=plt.subplots(figsize=(10,4))
train['Sales'].plot(ax=ax,label='Train set',title='Train/Test')
test['Sales'].plot(ax=ax,label='Test set')
plt.legend(['Train','Test'])
plt.show()

# %%
len(train)
# Out:
# 54

# %%
x_train = train.drop(columns=['Sales'])
y_train=train['Sales']
x_test=test.drop(columns=['Sales'])
y_test=test['Sales']

# %%
from sklearn.model_selection import GridSearchCV


# Define the parameter grid
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.001,0.01, 0.1, 0.2],
    'n_estimators': [100, 500, 1000, 2000],
    'colsample_bytree': [0.7, 0.8, 0.9, 1.0],
    'subsample': [0.7, 0.8, 0.9, 1.0]
}

# Instantiate the XGBoost regressor
regressor = xgb.XGBRegressor(objective='reg:squarederror')

# Instantiate GridSearchCV
grid_search = GridSearchCV(estimator=regressor, param_grid=param_grid, 
                           cv=5, scoring='neg_mean_squared_error', 
                           verbose=2, n_jobs=-1)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Access the best parameters
best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

print("Best parameters:", best_params)
print("Best estimator:", best_estimator)
# Out:
# Fitting 5 folds for each of 768 candidates, totalling 3840 fits
# Best parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.001, 'max_depth': 7, 'n_estimators': 2000, 'subsample': 0.7}
# Best estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.001, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=2000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=2000,
                       objective='reg:squarederror',
                       max_depth=7,
                       colsample_bytree=1.0,
                       subsample= 0.7,
                       early_stopping_rounds=50,
                       learning_rate=0.001)

reg.fit(x_train, y_train,
        eval_set=[(x_train, y_train), (x_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:84165.57976	validation_1-rmse:98926.77879
# [100]	validation_0-rmse:77055.21679	validation_1-rmse:91168.63414
# [200]	validation_0-rmse:70620.77984	validation_1-rmse:84059.12687
# [300]	validation_0-rmse:64799.17709	validation_1-rmse:77632.68920
# [400]	validation_0-rmse:59502.73539	validation_1-rmse:71685.87282
# [500]	validation_0-rmse:54727.64893	validation_1-rmse:66306.65037
# [600]	validation_0-rmse:50427.65115	validation_1-rmse:61393.33506
# [700]	validation_0-rmse:46526.97878	validation_1-rmse:57033.84941
# [800]	validation_0-rmse:43039.52349	validation_1-rmse:53069.22131
# [900]	validation_0-rmse:39877.16141	validation_1-rmse:49478.34586
# [1000]	validation_0-rmse:36974.74426	validation_1-rmse:46125.87069
# [1100]	validation_0-rmse:34365.41899	validation_1-rmse:43148.38089
# [1200]	validation_0-rmse:31961.40305	validation_1-rmse:40490.19180
# [1300]	validation_0-rmse:29789.68536	validation_1-rmse:37962.80843
# [1400]	validation_0-rmse:27782.86648	validation_1-rmse:35670.27723
# [1500]	validation_0-rmse:25964.86387	validation_1-rmse:33689.41590
# [1600]	validation_0-rmse:24318.61906	validation_1-rmse:31807.08598
# [1700]	validation_0-rmse:22838.93051	validation_1-rmse:30096.96530
# [1800]	validation_0-rmse:21454.96587	validation_1-rmse:28493.20200
# [1900]	validation_0-rmse:20184.98076	validation_1-rmse:27152.70020
# [1999]	validation_0-rmse:19020.13216	validation_1-rmse:25933.51931
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=1.0, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.001, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=2000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
reg.best_iteration
# Out:
# 1999

# %%
results = reg.evals_result()

plt.figure(figsize=(10,7))
plt.plot(results["validation_0"]["rmse"], label="Training loss")
plt.plot(results["validation_1"]["rmse"], label="Validation loss")
plt.axvline(1999,color='green',ls='--', label="Optimal tree number")
plt.xlabel("Number of trees")
plt.ylabel("Loss")
plt.legend()

# %%
pred=reg.predict(x_test)
sales_e['prediction']=[None]*len(train) + list(pred)

ax = sales_e['Sales'].plot(figsize=(15, 5))
sales_e['prediction'].plot()
plt.legend(['Actual Sales', 'Predictions'])
ax.set_title('Product E: Actual Sales and Prediction')
plt.show()

# %%
mae_xgb= mean_absolute_error(test['Sales'],pred)
mse_xgb=mean_squared_error(test['Sales'], pred)
mape_xgb= mean_absolute_percentage_error(test['Sales'],pred)
rmse_xgb= np.sqrt(mean_squared_error(test['Sales'],pred))

print(f'MAE - XGBoost: {mae_xgb:0.3f}')
print(f'MAPE - XGBoost: {mape_xgb:0.3f}')
print(f'MSE - XGBoost: {mse_xgb:0.3f}')
print(f'RMSE - XGBoost: {rmse_xgb:0.3f}')
# Out:
# MAE - XGBoost: 23784.601
# MAPE - XGBoost: 0.235
# MSE - XGBoost: 672547429.614
# RMSE - XGBoost: 25933.519

# %%
from xgboost import plot_importance

_ = plot_importance(reg, height=0.9)
