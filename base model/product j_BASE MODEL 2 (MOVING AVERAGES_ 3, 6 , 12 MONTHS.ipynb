# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
color_pal=sns.color_palette()
from sklearn.metrics import mean_squared_error,mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score

# %%
df=pd.read_csv('product j_basemodel.csv', parse_dates=['Month-Year'], index_col='Month-Year')

# %%
sales_j= df.drop(['Product Name','Product Category','Month','Year', 'SMA_12months','SMA_6months','SMA_3months'],axis=1)

# %%
sales_j.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 60 entries, 2019-01-01 to 2023-12-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sales   60 non-null     int64
# dtypes: int64(1)
# memory usage: 960.0 bytes

# %%
sales_j.head()
# Out:
#             Sales
# Month-Year
# 2019-01-01  63722
# 2019-02-01  76987
# 2019-03-01  99645
# 2019-04-01  68529
# 2019-05-01  45119

# %%
sales_j['Sales'].plot(figsize=(12,6),color=color_pal[2],title='Product J')
# Out:
# <Axes: title={'center': 'Product J'}, xlabel='Month-Year'>

# %%
train_12= sales_j[:48]
test_12= sales_j[48:]

# %%
y_hat_sma = sales_j.copy()
ma_window = 12
y_hat_sma['sma_forecast'] = sales_j['Sales'].rolling(ma_window).mean().shift()
y_hat_sma['sma_forecast'][len(train_12):] = y_hat_sma['sma_forecast'][len(train_12)]
# Out:
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_37976\676760935.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_hat_sma['sma_forecast'][len(train_12):] = y_hat_sma['sma_forecast'][len(train_12)]

# %%
plt.figure(figsize=(20,5))
plt.grid()
plt.plot(train_12['Sales'], label='Train')
plt.plot(test_12['Sales'], label='Test')
plt.plot(y_hat_sma['sma_forecast'], label='Simple moving average forecast')
plt.legend(loc='best')
plt.title('Simple Moving Average Method')
plt.show()

# %%
y_hat_sma
# Out:
#              Sales  sma_forecast
# Month-Year
# 2019-01-01   63722           NaN
# 2019-02-01   76987           NaN
# 2019-03-01   99645           NaN
# 2019-04-01   68529           NaN
# 2019-05-01   45119           NaN
# 2019-06-01   39059           NaN
# 2019-07-01   36898           NaN
# 2019-08-01   45234           NaN
# 2019-09-01   56459           NaN
# 2019-10-01   77083           NaN
# 2019-11-01  114215           NaN
# 2019-12-01  119071           NaN
# 2020-01-01   95295  70168.416667
# 2020-02-01   96986  72799.500000
# 2020-03-01   77407  74466.083333
# 2020-04-01   63779  72612.916667
# 2020-05-01   50431  72217.083333
# 2020-06-01   40167  72659.750000
# 2020-07-01   34720  72752.083333
# 2020-08-01   45719  72570.583333
# 2020-09-01   64151  72611.000000
# 2020-10-01   83553  73252.000000
# 2020-11-01  138920  73791.166667
# 2020-12-01  158353  75849.916667
# 2021-01-01   77227  79123.416667
# 2021-02-01   81017  77617.750000
# 2021-03-01   72249  76287.000000
# 2021-04-01   54222  75857.166667
# 2021-05-01   26385  75060.750000
# 2021-06-01   53939  73056.916667
# 2021-07-01   40514  74204.583333
# 2021-08-01   44419  74687.416667
# 2021-09-01   54372  74579.083333
# 2021-10-01  122831  73764.166667
# 2021-11-01  121337  77037.333333
# 2021-12-01  159370  75572.083333
# 2022-01-01   53125  75656.833333
# 2022-02-01  114209  73648.333333
# 2022-03-01   42559  76414.333333
# 2022-04-01   63333  73940.166667
# 2022-05-01   50000  74699.416667
# 2022-06-01   44000  76667.333333
# 2022-07-01   43854  75839.083333
# 2022-08-01   52662  76117.416667
# 2022-09-01   71396  76804.333333
# 2022-10-01   89343  78223.000000
# 2022-11-01  121770  75432.333333
# 2022-12-01  133417  75468.416667
# 2023-01-01   56843  73305.666667
# 2023-02-01   94268  73305.666667
# 2023-03-01   86135  73305.666667
# 2023-04-01   67767  73305.666667
# 2023-05-01   53500  73305.666667
# 2023-06-01   47080  73305.666667
# 2023-07-01   46924  73305.666667
# 2023-08-01   56348  73305.666667
# 2023-09-01   76393  73305.666667
# 2023-10-01   95597  73305.666667
# 2023-11-01  130293  73305.666667
# 2023-12-01  142757  73305.666667

# %%
pred_12= y_hat_sma['sma_forecast'].iloc[48:]

# %%
pred_12
# Out:
# Month-Year
# 2023-01-01    73305.666667
# 2023-02-01    73305.666667
# 2023-03-01    73305.666667
# 2023-04-01    73305.666667
# 2023-05-01    73305.666667
# 2023-06-01    73305.666667
# 2023-07-01    73305.666667
# 2023-08-01    73305.666667
# 2023-09-01    73305.666667
# 2023-10-01    73305.666667
# 2023-11-01    73305.666667
# 2023-12-01    73305.666667
# Name: sma_forecast, dtype: float64

# %%
mae_12= mean_absolute_error(test_12,pred_12)
mse_12=mean_squared_error(test_12,pred_12)
mape_12= mean_absolute_percentage_error(test_12,pred_12)
rmse_12= np.sqrt(mean_squared_error(test_12,pred_12))

print(f'MAE - Simple Moving Averages_12 months: {mae_12:0.3f}')
print(f'MAPE - Simple Moving Averages_12 months: {mape_12:0.3f}')
print(f'MSE - Simple Moving Averages_12 months: {mse_12:0.3f}')
print(f'RMSE - Simple Moving Averages_12 months: {rmse_12:0.3f}')
# Out:
# MAE - Simple Moving Averages_12 months: 24748.417
# MAPE - Simple Moving Averages_12 months: 0.311
# MSE - Simple Moving Averages_12 months: 962232607.083
# RMSE - Simple Moving Averages_12 months: 31019.874

# %%
train_6= sales_j[:54]
test_6= sales_j[54:]

# %%
y_hat_sma_6 = sales_j.copy()
ma_window_6 = 6
y_hat_sma_6['sma_forecast'] = sales_j['Sales'].rolling(ma_window_6).mean().shift()
y_hat_sma_6['sma_forecast'][len(train_6):] = y_hat_sma_6['sma_forecast'][len(train_6)]
# Out:
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_37976\1162127183.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_hat_sma_6['sma_forecast'][len(train_6):] = y_hat_sma_6['sma_forecast'][len(train_6)]

# %%
plt.figure(figsize=(20,5))
plt.grid()
plt.plot(train_6['Sales'], label='Train')
plt.plot(test_6['Sales'], label='Test')
plt.plot(y_hat_sma_6['sma_forecast'], label='Simple moving average forecast')
plt.legend(loc='best')
plt.title('Simple Moving Average Method')
plt.show()

# %%
y_hat_sma_6
# Out:
#              Sales   sma_forecast
# Month-Year
# 2019-01-01   63722            NaN
# 2019-02-01   76987            NaN
# 2019-03-01   99645            NaN
# 2019-04-01   68529            NaN
# 2019-05-01   45119            NaN
# 2019-06-01   39059            NaN
# 2019-07-01   36898   65510.166667
# 2019-08-01   45234   61039.500000
# 2019-09-01   56459   55747.333333
# 2019-10-01   77083   48549.666667
# 2019-11-01  114215   49975.333333
# 2019-12-01  119071   61491.333333
# 2020-01-01   95295   74826.666667
# 2020-02-01   96986   84559.500000
# 2020-03-01   77407   93184.833333
# 2020-04-01   63779   96676.166667
# 2020-05-01   50431   94458.833333
# 2020-06-01   40167   83828.166667
# 2020-07-01   34720   70677.500000
# 2020-08-01   45719   60581.666667
# 2020-09-01   64151   52037.166667
# 2020-10-01   83553   49827.833333
# 2020-11-01  138920   53123.500000
# 2020-12-01  158353   67871.666667
# 2021-01-01   77227   87569.333333
# 2021-02-01   81017   94653.833333
# 2021-03-01   72249  100536.833333
# 2021-04-01   54222  101886.500000
# 2021-05-01   26385   96998.000000
# 2021-06-01   53939   78242.166667
# 2021-07-01   40514   60839.833333
# 2021-08-01   44419   54721.000000
# 2021-09-01   54372   48621.333333
# 2021-10-01  122831   45641.833333
# 2021-11-01  121337   57076.666667
# 2021-12-01  159370   72902.000000
# 2022-01-01   53125   90473.833333
# 2022-02-01  114209   92575.666667
# 2022-03-01   42559  104207.333333
# 2022-04-01   63333  102238.500000
# 2022-05-01   50000   92322.166667
# 2022-06-01   44000   80432.666667
# 2022-07-01   43854   61204.333333
# 2022-08-01   52662   59659.166667
# 2022-09-01   71396   49401.333333
# 2022-10-01   89343   54207.500000
# 2022-11-01  121770   58542.500000
# 2022-12-01  133417   70504.166667
# 2023-01-01   56843   85407.000000
# 2023-02-01   94268   87571.833333
# 2023-03-01   86135   94506.166667
# 2023-04-01   67767   96962.666667
# 2023-05-01   53500   93366.666667
# 2023-06-01   47080   81988.333333
# 2023-07-01   46924   67598.833333
# 2023-08-01   56348   67598.833333
# 2023-09-01   76393   67598.833333
# 2023-10-01   95597   67598.833333
# 2023-11-01  130293   67598.833333
# 2023-12-01  142757   67598.833333

# %%
pred_6= y_hat_sma_6['sma_forecast'].iloc[54:]

# %%
pred_6
# Out:
# Month-Year
# 2023-07-01    67598.833333
# 2023-08-01    67598.833333
# 2023-09-01    67598.833333
# 2023-10-01    67598.833333
# 2023-11-01    67598.833333
# 2023-12-01    67598.833333
# Name: sma_forecast, dtype: float64

# %%
mae_6= mean_absolute_error(test_6,pred_6)
mse_6=mean_squared_error(test_6,pred_6)
mape_6= mean_absolute_percentage_error(test_6,pred_6)
rmse_6= np.sqrt(mean_squared_error(test_6,pred_6))

print(f'MAE - Simple Moving Averages_6 months: {mae_6:0.3f}')
print(f'MAPE - Simple Moving Averages_6 months: {mape_6:0.3f}')
print(f'MSE - Simple Moving Averages_6 months: {mse_6:0.3f}')
print(f'RMSE - Simple Moving Averages_6 months: {rmse_6:0.3f}')
# Out:
# MAE - Simple Moving Averages_6 months: 34428.389
# MAPE - Simple Moving Averages_6 months: 0.343
# MSE - Simple Moving Averages_6 months: 1832428873.139
# RMSE - Simple Moving Averages_6 months: 42806.879

# %%
train_3= sales_j[:57]
test_3= sales_j[57:]

# %%
y_hat_sma_3 = sales_j.copy()
ma_window_3 = 3
y_hat_sma_3['sma_forecast'] = sales_j['Sales'].rolling(ma_window_3).mean().shift()
y_hat_sma_3['sma_forecast'][len(train_3):] = y_hat_sma_3['sma_forecast'][len(train_3)]
# Out:
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_37976\4071238731.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_hat_sma_3['sma_forecast'][len(train_3):] = y_hat_sma_3['sma_forecast'][len(train_3)]

# %%
plt.figure(figsize=(20,5))
plt.grid()
plt.plot(train_3['Sales'], label='Train')
plt.plot(test_3['Sales'], label='Test')
plt.plot(y_hat_sma_3['sma_forecast'], label='Simple moving average forecast')
plt.legend(loc='best')
plt.title('Simple Moving Average Method')
plt.show()

# %%
y_hat_sma_3
# Out:
#              Sales   sma_forecast
# Month-Year
# 2019-01-01   63722            NaN
# 2019-02-01   76987            NaN
# 2019-03-01   99645            NaN
# 2019-04-01   68529   80118.000000
# 2019-05-01   45119   81720.333333
# 2019-06-01   39059   71097.666667
# 2019-07-01   36898   50902.333333
# 2019-08-01   45234   40358.666667
# 2019-09-01   56459   40397.000000
# 2019-10-01   77083   46197.000000
# 2019-11-01  114215   59592.000000
# 2019-12-01  119071   82585.666667
# 2020-01-01   95295  103456.333333
# 2020-02-01   96986  109527.000000
# 2020-03-01   77407  103784.000000
# 2020-04-01   63779   89896.000000
# 2020-05-01   50431   79390.666667
# 2020-06-01   40167   63872.333333
# 2020-07-01   34720   51459.000000
# 2020-08-01   45719   41772.666667
# 2020-09-01   64151   40202.000000
# 2020-10-01   83553   48196.666667
# 2020-11-01  138920   64474.333333
# 2020-12-01  158353   95541.333333
# 2021-01-01   77227  126942.000000
# 2021-02-01   81017  124833.333333
# 2021-03-01   72249  105532.333333
# 2021-04-01   54222   76831.000000
# 2021-05-01   26385   69162.666667
# 2021-06-01   53939   50952.000000
# 2021-07-01   40514   44848.666667
# 2021-08-01   44419   40279.333333
# 2021-09-01   54372   46290.666667
# 2021-10-01  122831   46435.000000
# 2021-11-01  121337   73874.000000
# 2021-12-01  159370   99513.333333
# 2022-01-01   53125  134512.666667
# 2022-02-01  114209  111277.333333
# 2022-03-01   42559  108901.333333
# 2022-04-01   63333   69964.333333
# 2022-05-01   50000   73367.000000
# 2022-06-01   44000   51964.000000
# 2022-07-01   43854   52444.333333
# 2022-08-01   52662   45951.333333
# 2022-09-01   71396   46838.666667
# 2022-10-01   89343   55970.666667
# 2022-11-01  121770   71133.666667
# 2022-12-01  133417   94169.666667
# 2023-01-01   56843  114843.333333
# 2023-02-01   94268  104010.000000
# 2023-03-01   86135   94842.666667
# 2023-04-01   67767   79082.000000
# 2023-05-01   53500   82723.333333
# 2023-06-01   47080   69134.000000
# 2023-07-01   46924   56115.666667
# 2023-08-01   56348   49168.000000
# 2023-09-01   76393   50117.333333
# 2023-10-01   95597   59888.333333
# 2023-11-01  130293   59888.333333
# 2023-12-01  142757   59888.333333

# %%
pred_3= y_hat_sma_3['sma_forecast'].iloc[57:]

# %%
pred_3
# Out:
# Month-Year
# 2023-10-01    59888.333333
# 2023-11-01    59888.333333
# 2023-12-01    59888.333333
# Name: sma_forecast, dtype: float64

# %%
mae_3= mean_absolute_error(test_3,pred_3)
mse_3=mean_squared_error(test_3,pred_3)
mape_3= mean_absolute_percentage_error(test_3,pred_3)
rmse_3= np.sqrt(mean_squared_error(test_3,pred_3))

print(f'MAE - Simple Moving Averages_3 months: {mae_3:0.3f}')
print(f'MAPE - Simple Moving Averages_3 months: {mape_3:0.3f}')
print(f'MSE - Simple Moving Averages_3 months: {mse_3:0.3f}')
print(f'RMSE - Simple Moving Averages_3 months: {rmse_3:0.3f}')
# Out:
# MAE - Simple Moving Averages_3 months: 62994.000
# MAPE - Simple Moving Averages_3 months: 0.498
# MSE - Simple Moving Averages_3 months: 4366380626.222
# RMSE - Simple Moving Averages_3 months: 66078.594
