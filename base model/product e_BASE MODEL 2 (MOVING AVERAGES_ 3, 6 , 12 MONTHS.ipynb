# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
color_pal=sns.color_palette()
from sklearn.metrics import mean_squared_error,mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score

# %%
df=pd.read_csv('product e_basemodel.csv', parse_dates=['Month-Year'], index_col='Month-Year')

# %%
sales_e= df.drop(['Product Name','Product Category','Month','Year', 'SMA_12months','SMA_6months','SMA_3months'],axis=1)

# %%
sales_e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 60 entries, 2019-01-01 to 2023-12-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sales   60 non-null     int64
# dtypes: int64(1)
# memory usage: 960.0 bytes

# %%
sales_e.head()
# Out:
#             Sales
# Month-Year
# 2019-01-01  57650
# 2019-02-01  66035
# 2019-03-01  88208
# 2019-04-01  74712
# 2019-05-01  61172

# %%
sales_e['Sales'].plot(figsize=(12,6),color=color_pal[2],title='Product E')
# Out:
# <Axes: title={'center': 'Product E'}, xlabel='Month-Year'>

# %%
train_12= sales_e[:48]
test_12= sales_e[48:]

# %%
y_hat_sma = sales_e.copy()
ma_window = 12
y_hat_sma['sma_forecast'] = sales_e['Sales'].rolling(ma_window).mean().shift()
y_hat_sma['sma_forecast'][len(train_12):] = y_hat_sma['sma_forecast'][len(train_12)]
# Out:
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_74424\2295711430.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_hat_sma['sma_forecast'][len(train_12):] = y_hat_sma['sma_forecast'][len(train_12)]

# %%
plt.figure(figsize=(20,5))
plt.grid()
plt.plot(train_12['Sales'], label='Train')
plt.plot(test_12['Sales'], label='Test')
plt.plot(y_hat_sma['sma_forecast'], label='Simple moving average forecast')
plt.legend(loc='best')
plt.title('Simple Moving Average Method')
plt.show()

# %%
y_hat_sma
# Out:
#              Sales  sma_forecast
# Month-Year
# 2019-01-01   57650           NaN
# 2019-02-01   66035           NaN
# 2019-03-01   88208           NaN
# 2019-04-01   74712           NaN
# 2019-05-01   61172           NaN
# 2019-06-01   48721           NaN
# 2019-07-01   51556           NaN
# 2019-08-01   70726           NaN
# 2019-09-01   70502           NaN
# 2019-10-01   85353           NaN
# 2019-11-01  100056           NaN
# 2019-12-01   92839           NaN
# 2020-01-01  107545  72294.166667
# 2020-02-01   93962  76452.083333
# 2020-03-01   76159  78779.333333
# 2020-04-01   62855  77775.250000
# 2020-05-01   64042  76787.166667
# 2020-06-01   57547  77026.333333
# 2020-07-01   54213  77761.833333
# 2020-08-01   71457  77983.250000
# 2020-09-01   89345  78044.166667
# 2020-10-01   92665  79614.416667
# 2020-11-01  136850  80223.750000
# 2020-12-01  128031  83289.916667
# 2021-01-01   55925  86222.583333
# 2021-02-01   71334  81920.916667
# 2021-03-01   81457  80035.250000
# 2021-04-01   66872  80476.750000
# 2021-05-01   62928  80811.500000
# 2021-06-01   54928  80718.666667
# 2021-07-01   48096  80500.416667
# 2021-08-01   69002  79990.666667
# 2021-09-01  116735  79786.083333
# 2021-10-01   59081  82068.583333
# 2021-11-01  173454  79269.916667
# 2021-12-01   85253  82320.250000
# 2022-01-01   67875  78755.416667
# 2022-02-01  126411  79751.250000
# 2022-03-01   46889  84341.000000
# 2022-04-01   70909  81460.333333
# 2022-05-01   65455  81796.750000
# 2022-06-01   63687  82007.333333
# 2022-07-01   61818  82737.250000
# 2022-08-01   80036  83880.750000
# 2022-09-01   95134  84800.250000
# 2022-10-01  106073  83000.166667
# 2022-11-01  117303  86916.166667
# 2022-12-01  112046  82236.916667
# 2023-01-01   71268  84469.666667
# 2023-02-01   97965  84469.666667
# 2023-03-01   91393  84469.666667
# 2023-04-01   76364  84469.666667
# 2023-05-01   71591  84469.666667
# 2023-06-01   73457  84469.666667
# 2023-07-01   64909  84469.666667
# 2023-08-01   81175  84469.666667
# 2023-09-01   96096  84469.666667
# 2023-10-01  107582  84469.666667
# 2023-11-01  119374  84469.666667
# 2023-12-01  113854  84469.666667

# %%
pred_12= y_hat_sma['sma_forecast'].iloc[48:]

# %%
pred_12
# Out:
# Month-Year
# 2023-01-01    84469.666667
# 2023-02-01    84469.666667
# 2023-03-01    84469.666667
# 2023-04-01    84469.666667
# 2023-05-01    84469.666667
# 2023-06-01    84469.666667
# 2023-07-01    84469.666667
# 2023-08-01    84469.666667
# 2023-09-01    84469.666667
# 2023-10-01    84469.666667
# 2023-11-01    84469.666667
# 2023-12-01    84469.666667
# Name: sma_forecast, dtype: float64

# %%
mae_12= mean_absolute_error(test_12,pred_12)
mse_12=mean_squared_error(test_12,pred_12)
mape_12= mean_absolute_percentage_error(test_12,pred_12)
rmse_12= np.sqrt(mean_squared_error(test_12,pred_12))

print(f'MAE - Simple Moving Averages_12 months: {mae_12:0.3f}')
print(f'MAPE - Simple Moving Averages_12 months: {mape_12:0.3f}')
print(f'MSE - Simple Moving Averages_12 months: {mse_12:0.3f}')
print(f'RMSE - Simple Moving Averages_12 months: {rmse_12:0.3f}')
# Out:
# MAE - Simple Moving Averages_12 months: 15625.000
# MAPE - Simple Moving Averages_12 months: 0.172
# MSE - Simple Moving Averages_12 months: 325146575.167
# RMSE - Simple Moving Averages_12 months: 18031.821

# %%
train_6= sales_e[:54]
test_6= sales_e[54:]

# %%
y_hat_sma_6 = sales_e.copy()
ma_window_6 = 6
y_hat_sma_6['sma_forecast'] = sales_e['Sales'].rolling(ma_window_6).mean().shift()
y_hat_sma_6['sma_forecast'][len(train_6):] = y_hat_sma_6['sma_forecast'][len(train_6)]
# Out:
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_74424\2272960607.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_hat_sma_6['sma_forecast'][len(train_6):] = y_hat_sma_6['sma_forecast'][len(train_6)]

# %%
plt.figure(figsize=(20,5))
plt.grid()
plt.plot(train_6['Sales'], label='Train')
plt.plot(test_6['Sales'], label='Test')
plt.plot(y_hat_sma_6['sma_forecast'], label='Simple moving average forecast')
plt.legend(loc='best')
plt.title('Simple Moving Average Method')
plt.show()

# %%
y_hat_sma_6
# Out:
#              Sales   sma_forecast
# Month-Year
# 2019-01-01   57650            NaN
# 2019-02-01   66035            NaN
# 2019-03-01   88208            NaN
# 2019-04-01   74712            NaN
# 2019-05-01   61172            NaN
# 2019-06-01   48721            NaN
# 2019-07-01   51556   66083.000000
# 2019-08-01   70726   65067.333333
# 2019-09-01   70502   65849.166667
# 2019-10-01   85353   62898.166667
# 2019-11-01  100056   64671.666667
# 2019-12-01   92839   71152.333333
# 2020-01-01  107545   78505.333333
# 2020-02-01   93962   87836.833333
# 2020-03-01   76159   91709.500000
# 2020-04-01   62855   92652.333333
# 2020-05-01   64042   88902.666667
# 2020-06-01   57547   82900.333333
# 2020-07-01   54213   77018.333333
# 2020-08-01   71457   68129.666667
# 2020-09-01   89345   64378.833333
# 2020-10-01   92665   66576.500000
# 2020-11-01  136850   71544.833333
# 2020-12-01  128031   83679.500000
# 2021-01-01   55925   95426.833333
# 2021-02-01   71334   95712.166667
# 2021-03-01   81457   95691.666667
# 2021-04-01   66872   94377.000000
# 2021-05-01   62928   90078.166667
# 2021-06-01   54928   77757.833333
# 2021-07-01   48096   65574.000000
# 2021-08-01   69002   64269.166667
# 2021-09-01  116735   63880.500000
# 2021-10-01   59081   69760.166667
# 2021-11-01  173454   68461.666667
# 2021-12-01   85253   86882.666667
# 2022-01-01   67875   91936.833333
# 2022-02-01  126411   95233.333333
# 2022-03-01   46889  104801.500000
# 2022-04-01   70909   93160.500000
# 2022-05-01   65455   95131.833333
# 2022-06-01   63687   77132.000000
# 2022-07-01   61818   73537.666667
# 2022-08-01   80036   72528.166667
# 2022-09-01   95134   64799.000000
# 2022-10-01  106073   72839.833333
# 2022-11-01  117303   78700.500000
# 2022-12-01  112046   87341.833333
# 2023-01-01   71268   95401.666667
# 2023-02-01   97965   96976.666667
# 2023-03-01   91393   99964.833333
# 2023-04-01   76364   99341.333333
# 2023-05-01   71591   94389.833333
# 2023-06-01   73457   86771.166667
# 2023-07-01   64909   80339.666667
# 2023-08-01   81175   80339.666667
# 2023-09-01   96096   80339.666667
# 2023-10-01  107582   80339.666667
# 2023-11-01  119374   80339.666667
# 2023-12-01  113854   80339.666667

# %%
pred_6= y_hat_sma_6['sma_forecast'].iloc[54:]

# %%
pred_6
# Out:
# Month-Year
# 2023-07-01    80339.666667
# 2023-08-01    80339.666667
# 2023-09-01    80339.666667
# 2023-10-01    80339.666667
# 2023-11-01    80339.666667
# 2023-12-01    80339.666667
# Name: sma_forecast, dtype: float64

# %%
mae_6= mean_absolute_error(test_6,pred_6)
mse_6=mean_squared_error(test_6,pred_6)
mape_6= mean_absolute_percentage_error(test_6,pred_6)
rmse_6= np.sqrt(mean_squared_error(test_6,pred_6))

print(f'MAE - Simple Moving Averages_6 months: {mae_6:0.3f}')
print(f'MAPE - Simple Moving Averages_6 months: {mape_6:0.3f}')
print(f'MSE - Simple Moving Averages_6 months: {mse_6:0.3f}')
print(f'RMSE - Simple Moving Averages_6 months: {rmse_6:0.3f}')
# Out:
# MAE - Simple Moving Averages_6 months: 21968.889
# MAPE - Simple Moving Averages_6 months: 0.214
# MSE - Simple Moving Averages_6 months: 646016623.111
# RMSE - Simple Moving Averages_6 months: 25416.857

# %%
train_3= sales_e[:57]
test_3= sales_e[57:]

# %%
y_hat_sma_3 = sales_e.copy()
ma_window_3 = 3
y_hat_sma_3['sma_forecast'] = sales_e['Sales'].rolling(ma_window_3).mean().shift()
y_hat_sma_3['sma_forecast'][len(train_3):] = y_hat_sma_3['sma_forecast'][len(train_3)]
# Out:
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_74424\360494967.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_hat_sma_3['sma_forecast'][len(train_3):] = y_hat_sma_3['sma_forecast'][len(train_3)]

# %%
plt.figure(figsize=(20,5))
plt.grid()
plt.plot(train_3['Sales'], label='Train')
plt.plot(test_3['Sales'], label='Test')
plt.plot(y_hat_sma_3['sma_forecast'], label='Simple moving average forecast')
plt.legend(loc='best')
plt.title('Simple Moving Average Method')
plt.show()

# %%
y_hat_sma_3
# Out:
#              Sales   sma_forecast
# Month-Year
# 2019-01-01   57650            NaN
# 2019-02-01   66035            NaN
# 2019-03-01   88208            NaN
# 2019-04-01   74712   70631.000000
# 2019-05-01   61172   76318.333333
# 2019-06-01   48721   74697.333333
# 2019-07-01   51556   61535.000000
# 2019-08-01   70726   53816.333333
# 2019-09-01   70502   57001.000000
# 2019-10-01   85353   64261.333333
# 2019-11-01  100056   75527.000000
# 2019-12-01   92839   85303.666667
# 2020-01-01  107545   92749.333333
# 2020-02-01   93962  100146.666667
# 2020-03-01   76159   98115.333333
# 2020-04-01   62855   92555.333333
# 2020-05-01   64042   77658.666667
# 2020-06-01   57547   67685.333333
# 2020-07-01   54213   61481.333333
# 2020-08-01   71457   58600.666667
# 2020-09-01   89345   61072.333333
# 2020-10-01   92665   71671.666667
# 2020-11-01  136850   84489.000000
# 2020-12-01  128031  106286.666667
# 2021-01-01   55925  119182.000000
# 2021-02-01   71334  106935.333333
# 2021-03-01   81457   85096.666667
# 2021-04-01   66872   69572.000000
# 2021-05-01   62928   73221.000000
# 2021-06-01   54928   70419.000000
# 2021-07-01   48096   61576.000000
# 2021-08-01   69002   55317.333333
# 2021-09-01  116735   57342.000000
# 2021-10-01   59081   77944.333333
# 2021-11-01  173454   81606.000000
# 2021-12-01   85253  116423.333333
# 2022-01-01   67875  105929.333333
# 2022-02-01  126411  108860.666667
# 2022-03-01   46889   93179.666667
# 2022-04-01   70909   80391.666667
# 2022-05-01   65455   81403.000000
# 2022-06-01   63687   61084.333333
# 2022-07-01   61818   66683.666667
# 2022-08-01   80036   63653.333333
# 2022-09-01   95134   68513.666667
# 2022-10-01  106073   78996.000000
# 2022-11-01  117303   93747.666667
# 2022-12-01  112046  106170.000000
# 2023-01-01   71268  111807.333333
# 2023-02-01   97965  100205.666667
# 2023-03-01   91393   93759.666667
# 2023-04-01   76364   86875.333333
# 2023-05-01   71591   88574.000000
# 2023-06-01   73457   79782.666667
# 2023-07-01   64909   73804.000000
# 2023-08-01   81175   69985.666667
# 2023-09-01   96096   73180.333333
# 2023-10-01  107582   80726.666667
# 2023-11-01  119374   80726.666667
# 2023-12-01  113854   80726.666667

# %%
pred_3= y_hat_sma_3['sma_forecast'].iloc[57:]

# %%
pred_3
# Out:
# Month-Year
# 2023-10-01    80726.666667
# 2023-11-01    80726.666667
# 2023-12-01    80726.666667
# Name: sma_forecast, dtype: float64

# %%
mae_3= mean_absolute_error(test_3,pred_3)
mse_3=mean_squared_error(test_3,pred_3)
mape_3= mean_absolute_percentage_error(test_3,pred_3)
rmse_3= np.sqrt(mean_squared_error(test_3,pred_3))

print(f'MAE - Simple Moving Averages_3 months: {mae_3:0.3f}')
print(f'MAPE - Simple Moving Averages_3 months: {mape_3:0.3f}')
print(f'MSE - Simple Moving Averages_3 months: {mse_3:0.3f}')
print(f'RMSE - Simple Moving Averages_3 months: {rmse_3:0.3f}')
# Out:
# MAE - Simple Moving Averages_3 months: 32876.667
# MAPE - Simple Moving Averages_3 months: 0.288
# MSE - Simple Moving Averages_3 months: 1104081838.667
# RMSE - Simple Moving Averages_3 months: 33227.727
