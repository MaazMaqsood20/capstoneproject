# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
color_pal=sns.color_palette()
from sklearn.metrics import mean_squared_error,mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score

# %%
df=pd.read_csv('product i_basemodel.csv', parse_dates=['Month-Year'], index_col='Month-Year')

# %%
sales_i= df.drop(['Product Name','Product Category','Month','Year', 'SMA_12months','SMA_6months','SMA_3months'],axis=1)

# %%
sales_i.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 60 entries, 2019-01-01 to 2023-12-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sales   60 non-null     int64
# dtypes: int64(1)
# memory usage: 960.0 bytes

# %%
sales_i.head()
# Out:
#             Sales
# Month-Year
# 2019-01-01  50833
# 2019-02-01  65670
# 2019-03-01  89667
# 2019-04-01  60960
# 2019-05-01  43410

# %%
sales_i['Sales'].plot(figsize=(12,6),color=color_pal[2],title='Product I')
# Out:
# <Axes: title={'center': 'Product I'}, xlabel='Month-Year'>

# %%
train_12= sales_i[:48]
test_12= sales_i[48:]

# %%
y_hat_sma = sales_i.copy()
ma_window = 12
y_hat_sma['sma_forecast'] = sales_i['Sales'].rolling(ma_window).mean().shift()
y_hat_sma['sma_forecast'][len(train_12):] = y_hat_sma['sma_forecast'][len(train_12)]
# Out:
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_9716\2995619851.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_hat_sma['sma_forecast'][len(train_12):] = y_hat_sma['sma_forecast'][len(train_12)]

# %%
plt.figure(figsize=(20,5))
plt.grid()
plt.plot(train_12['Sales'], label='Train')
plt.plot(test_12['Sales'], label='Test')
plt.plot(y_hat_sma['sma_forecast'], label='Simple moving average forecast')
plt.legend(loc='best')
plt.title('Simple Moving Average Method')
plt.show()

# %%
y_hat_sma
# Out:
#              Sales   sma_forecast
# Month-Year
# 2019-01-01   50833            NaN
# 2019-02-01   65670            NaN
# 2019-03-01   89667            NaN
# 2019-04-01   60960            NaN
# 2019-05-01   43410            NaN
# 2019-06-01   38023            NaN
# 2019-07-01   39097            NaN
# 2019-08-01   54870            NaN
# 2019-09-01   66773            NaN
# 2019-10-01   98947            NaN
# 2019-11-01  100673            NaN
# 2019-12-01  170203            NaN
# 2020-01-01   94973   73260.500000
# 2020-02-01   88203   76938.833333
# 2020-03-01  108733   78816.583333
# 2020-04-01   81477   80405.416667
# 2020-05-01   66500   82115.166667
# 2020-06-01   56360   84039.333333
# 2020-07-01   46957   85567.416667
# 2020-08-01   71783   86222.416667
# 2020-09-01  100290   87631.833333
# 2020-10-01  121583   90424.916667
# 2020-11-01  157893   92311.250000
# 2020-12-01  233413   97079.583333
# 2021-01-01   91570  102347.083333
# 2021-02-01   98827  102063.500000
# 2021-03-01   82020  102948.833333
# 2021-04-01   50287  100722.750000
# 2021-05-01   23230   98123.583333
# 2021-06-01   49363   94517.750000
# 2021-07-01   68397   93934.666667
# 2021-08-01   66043   95721.333333
# 2021-09-01   74643   95243.000000
# 2021-10-01  168593   93105.750000
# 2021-11-01  180740   97023.250000
# 2021-12-01  218833   98927.166667
# 2022-01-01   60660   97712.166667
# 2022-02-01  135380   95136.333333
# 2022-03-01   95395   98182.416667
# 2022-04-01   71153   99297.000000
# 2022-05-01   70000  101035.833333
# 2022-06-01   56559  104933.333333
# 2022-07-01   60000  105533.000000
# 2022-08-01   84467  104833.250000
# 2022-09-01  110956  106368.583333
# 2022-10-01  134868  109394.666667
# 2022-11-01  166657  106584.250000
# 2022-12-01  180888  105410.666667
# 2023-01-01   64906  102248.583333
# 2023-02-01  122096  102248.583333
# 2023-03-01   95682  102248.583333
# 2023-04-01   76134  102248.583333
# 2023-05-01   74900  102248.583333
# 2023-06-01   60518  102248.583333
# 2023-07-01   64200  102248.583333
# 2023-08-01   88953  102248.583333
# 2023-09-01  117297  102248.583333
# 2023-10-01  142882  102248.583333
# 2023-11-01  176896  102248.583333
# 2023-12-01  192123  102248.583333

# %%
pred_12= y_hat_sma['sma_forecast'].iloc[48:]

# %%
pred_12
# Out:
# Month-Year
# 2023-01-01    102248.583333
# 2023-02-01    102248.583333
# 2023-03-01    102248.583333
# 2023-04-01    102248.583333
# 2023-05-01    102248.583333
# 2023-06-01    102248.583333
# 2023-07-01    102248.583333
# 2023-08-01    102248.583333
# 2023-09-01    102248.583333
# 2023-10-01    102248.583333
# 2023-11-01    102248.583333
# 2023-12-01    102248.583333
# Name: sma_forecast, dtype: float64

# %%
mae_12= mean_absolute_error(test_12,pred_12)
mse_12=mean_squared_error(test_12,pred_12)
mape_12= mean_absolute_percentage_error(test_12,pred_12)
rmse_12= np.sqrt(mean_squared_error(test_12,pred_12))

print(f'MAE - Simple Moving Averages_12 months: {mae_12:0.3f}')
print(f'MAPE - Simple Moving Averages_12 months: {mape_12:0.3f}')
print(f'MSE - Simple Moving Averages_12 months: {mse_12:0.3f}')
print(f'RMSE - Simple Moving Averages_12 months: {rmse_12:0.3f}')
# Out:
# MAE - Simple Moving Averages_12 months: 35874.847
# MAPE - Simple Moving Averages_12 months: 0.354
# MSE - Simple Moving Averages_12 months: 1846209230.299
# RMSE - Simple Moving Averages_12 months: 42967.537

# %%
train_6= sales_i[:54]
test_6= sales_i[54:]

# %%
y_hat_sma_6 = sales_i.copy()
ma_window_6 = 6
y_hat_sma_6['sma_forecast'] = sales_i['Sales'].rolling(ma_window_6).mean().shift()
y_hat_sma_6['sma_forecast'][len(train_6):] = y_hat_sma_6['sma_forecast'][len(train_6)]
# Out:
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_9716\687162135.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_hat_sma_6['sma_forecast'][len(train_6):] = y_hat_sma_6['sma_forecast'][len(train_6)]

# %%
plt.figure(figsize=(20,5))
plt.grid()
plt.plot(train_6['Sales'], label='Train')
plt.plot(test_6['Sales'], label='Test')
plt.plot(y_hat_sma_6['sma_forecast'], label='Simple moving average forecast')
plt.legend(loc='best')
plt.title('Simple Moving Average Method')
plt.show()

# %%
y_hat_sma_6
# Out:
#              Sales   sma_forecast
# Month-Year
# 2019-01-01   50833            NaN
# 2019-02-01   65670            NaN
# 2019-03-01   89667            NaN
# 2019-04-01   60960            NaN
# 2019-05-01   43410            NaN
# 2019-06-01   38023            NaN
# 2019-07-01   39097   58093.833333
# 2019-08-01   54870   56137.833333
# 2019-09-01   66773   54337.833333
# 2019-10-01   98947   50522.166667
# 2019-11-01  100673   56853.333333
# 2019-12-01  170203   66397.166667
# 2020-01-01   94973   88427.166667
# 2020-02-01   88203   97739.833333
# 2020-03-01  108733  103295.333333
# 2020-04-01   81477  110288.666667
# 2020-05-01   66500  107377.000000
# 2020-06-01   56360  101681.500000
# 2020-07-01   46957   82707.666667
# 2020-08-01   71783   74705.000000
# 2020-09-01  100290   71968.333333
# 2020-10-01  121583   70561.166667
# 2020-11-01  157893   77245.500000
# 2020-12-01  233413   92477.666667
# 2021-01-01   91570  121986.500000
# 2021-02-01   98827  129422.000000
# 2021-03-01   82020  133929.333333
# 2021-04-01   50287  130884.333333
# 2021-05-01   23230  119001.666667
# 2021-06-01   49363   96557.833333
# 2021-07-01   68397   65882.833333
# 2021-08-01   66043   62020.666667
# 2021-09-01   74643   56556.666667
# 2021-10-01  168593   55327.166667
# 2021-11-01  180740   75044.833333
# 2021-12-01  218833  101296.500000
# 2022-01-01   60660  129541.500000
# 2022-02-01  135380  128252.000000
# 2022-03-01   95395  139808.166667
# 2022-04-01   71153  143266.833333
# 2022-05-01   70000  127026.833333
# 2022-06-01   56559  108570.166667
# 2022-07-01   60000   81524.500000
# 2022-08-01   84467   81414.500000
# 2022-09-01  110956   72929.000000
# 2022-10-01  134868   75522.500000
# 2022-11-01  166657   86141.666667
# 2022-12-01  180888  102251.166667
# 2023-01-01   64906  122972.666667
# 2023-02-01  122096  123790.333333
# 2023-03-01   95682  130061.833333
# 2023-04-01   76134  127516.166667
# 2023-05-01   74900  117727.166667
# 2023-06-01   60518  102434.333333
# 2023-07-01   64200   82372.666667
# 2023-08-01   88953   82372.666667
# 2023-09-01  117297   82372.666667
# 2023-10-01  142882   82372.666667
# 2023-11-01  176896   82372.666667
# 2023-12-01  192123   82372.666667

# %%
pred_6= y_hat_sma_6['sma_forecast'].iloc[54:]

# %%
pred_6
# Out:
# Month-Year
# 2023-07-01    82372.666667
# 2023-08-01    82372.666667
# 2023-09-01    82372.666667
# 2023-10-01    82372.666667
# 2023-11-01    82372.666667
# 2023-12-01    82372.666667
# Name: sma_forecast, dtype: float64

# %%
mae_6= mean_absolute_error(test_6,pred_6)
mse_6=mean_squared_error(test_6,pred_6)
mape_6= mean_absolute_percentage_error(test_6,pred_6)
rmse_6= np.sqrt(mean_squared_error(test_6,pred_6))

print(f'MAE - Simple Moving Averages_6 months: {mae_6:0.3f}')
print(f'MAPE - Simple Moving Averages_6 months: {mape_6:0.3f}')
print(f'MSE - Simple Moving Averages_6 months: {mse_6:0.3f}')
print(f'RMSE - Simple Moving Averages_6 months: {rmse_6:0.3f}')
# Out:
# MAE - Simple Moving Averages_6 months: 54076.722
# MAPE - Simple Moving Averages_6 months: 0.364
# MSE - Simple Moving Averages_6 months: 4372405215.167
# RMSE - Simple Moving Averages_6 months: 66124.165

# %%
train_3= sales_i[:57]
test_3= sales_i[57:]

# %%
y_hat_sma_3 = sales_i.copy()
ma_window_3 = 3
y_hat_sma_3['sma_forecast'] = sales_i['Sales'].rolling(ma_window_3).mean().shift()
y_hat_sma_3['sma_forecast'][len(train_3):] = y_hat_sma_3['sma_forecast'][len(train_3)]
# Out:
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_9716\2039006292.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_hat_sma_3['sma_forecast'][len(train_3):] = y_hat_sma_3['sma_forecast'][len(train_3)]

# %%
plt.figure(figsize=(20,5))
plt.grid()
plt.plot(train_3['Sales'], label='Train')
plt.plot(test_3['Sales'], label='Test')
plt.plot(y_hat_sma_3['sma_forecast'], label='Simple moving average forecast')
plt.legend(loc='best')
plt.title('Simple Moving Average Method')
plt.show()

# %%
y_hat_sma_3
# Out:
#              Sales   sma_forecast
# Month-Year
# 2019-01-01   50833            NaN
# 2019-02-01   65670            NaN
# 2019-03-01   89667            NaN
# 2019-04-01   60960   68723.333333
# 2019-05-01   43410   72099.000000
# 2019-06-01   38023   64679.000000
# 2019-07-01   39097   47464.333333
# 2019-08-01   54870   40176.666667
# 2019-09-01   66773   43996.666667
# 2019-10-01   98947   53580.000000
# 2019-11-01  100673   73530.000000
# 2019-12-01  170203   88797.666667
# 2020-01-01   94973  123274.333333
# 2020-02-01   88203  121949.666667
# 2020-03-01  108733  117793.000000
# 2020-04-01   81477   97303.000000
# 2020-05-01   66500   92804.333333
# 2020-06-01   56360   85570.000000
# 2020-07-01   46957   68112.333333
# 2020-08-01   71783   56605.666667
# 2020-09-01  100290   58366.666667
# 2020-10-01  121583   73010.000000
# 2020-11-01  157893   97885.333333
# 2020-12-01  233413  126588.666667
# 2021-01-01   91570  170963.000000
# 2021-02-01   98827  160958.666667
# 2021-03-01   82020  141270.000000
# 2021-04-01   50287   90805.666667
# 2021-05-01   23230   77044.666667
# 2021-06-01   49363   51845.666667
# 2021-07-01   68397   40960.000000
# 2021-08-01   66043   46996.666667
# 2021-09-01   74643   61267.666667
# 2021-10-01  168593   69694.333333
# 2021-11-01  180740  103093.000000
# 2021-12-01  218833  141325.333333
# 2022-01-01   60660  189388.666667
# 2022-02-01  135380  153411.000000
# 2022-03-01   95395  138291.000000
# 2022-04-01   71153   97145.000000
# 2022-05-01   70000  100642.666667
# 2022-06-01   56559   78849.333333
# 2022-07-01   60000   65904.000000
# 2022-08-01   84467   62186.333333
# 2022-09-01  110956   67008.666667
# 2022-10-01  134868   85141.000000
# 2022-11-01  166657  110097.000000
# 2022-12-01  180888  137493.666667
# 2023-01-01   64906  160804.333333
# 2023-02-01  122096  137483.666667
# 2023-03-01   95682  122630.000000
# 2023-04-01   76134   94228.000000
# 2023-05-01   74900   97970.666667
# 2023-06-01   60518   82238.666667
# 2023-07-01   64200   70517.333333
# 2023-08-01   88953   66539.333333
# 2023-09-01  117297   71223.666667
# 2023-10-01  142882   90150.000000
# 2023-11-01  176896   90150.000000
# 2023-12-01  192123   90150.000000

# %%
pred_3= y_hat_sma_3['sma_forecast'].iloc[57:]

# %%
pred_3
# Out:
# Month-Year
# 2023-10-01    90150.0
# 2023-11-01    90150.0
# 2023-12-01    90150.0
# Name: sma_forecast, dtype: float64

# %%
mae_3= mean_absolute_error(test_3,pred_3)
mse_3=mean_squared_error(test_3,pred_3)
mape_3= mean_absolute_percentage_error(test_3,pred_3)
rmse_3= np.sqrt(mean_squared_error(test_3,pred_3))

print(f'MAE - Simple Moving Averages_3 months: {mae_3:0.3f}')
print(f'MAPE - Simple Moving Averages_3 months: {mape_3:0.3f}')
print(f'MSE - Simple Moving Averages_3 months: {mse_3:0.3f}')
print(f'RMSE - Simple Moving Averages_3 months: {rmse_3:0.3f}')
# Out:
# MAE - Simple Moving Averages_3 months: 80483.667
# MAPE - Simple Moving Averages_3 months: 0.463
# MSE - Simple Moving Averages_3 months: 6901341689.667
# RMSE - Simple Moving Averages_3 months: 83074.314
