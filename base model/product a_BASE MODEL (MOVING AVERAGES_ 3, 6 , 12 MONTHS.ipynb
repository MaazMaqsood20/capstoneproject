# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
color_pal=sns.color_palette()
from sklearn.metrics import mean_squared_error,mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics import r2_score

# %%
df=pd.read_csv('product a_basemodel.csv', parse_dates=['Month-Year'], index_col='Month-Year')

# %%
sales_a= df.drop(['Product Name','Product Category','Month','Year'],axis=1)

# %%
sales_a.head()
# Out:
#             Sales  SMA_12months  SMA_6months  SMA_3months
# Month-Year
# 2019-01-01  54555           NaN          NaN          NaN
# 2019-02-01  54293           NaN          NaN          NaN
# 2019-03-01  58798           NaN          NaN          NaN
# 2019-04-01  53229           NaN          NaN      55882.0
# 2019-05-01  50558           NaN          NaN      55440.0

# %%
sales_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 60 entries, 2019-01-01 to 2023-12-01
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sales         60 non-null     int64
#  1   SMA_12months  48 non-null     float64
#  2   SMA_6months   54 non-null     float64
#  3   SMA_3months   57 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 2.3 KB

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(sales_a[['Sales']])
plt.title('Product A')
plt.show()

# %%
test_3= sales_a['Sales'].iloc[57:]
test_6=sales_a['Sales'].iloc[54:]
test_12=sales_a['Sales'].iloc[48:]

# %%
pred_3=sales_a['SMA_3months'].iloc[57:]
pred_6=sales_a['SMA_6months'].iloc[54:]
pred_12=sales_a['SMA_12months'].iloc[48:]

# %%
test_3,test_6,test_12
# Out:
# (Month-Year
#  2023-10-01    55575
#  2023-11-01    55311
#  2023-12-01    55281
#  Name: Sales, dtype: int64,
#  Month-Year
#  2023-07-01    54485
#  2023-08-01    54869
#  2023-09-01    55607
#  2023-10-01    55575
#  2023-11-01    55311
#  2023-12-01    55281
#  Name: Sales, dtype: int64,
#  Month-Year
#  2023-01-01    63171
#  2023-02-01    31168
#  2023-03-01    70380
#  2023-04-01    53078
#  2023-05-01    43741
#  2023-06-01    63919
#  2023-07-01    54485
#  2023-08-01    54869
#  2023-09-01    55607
#  2023-10-01    55575
#  2023-11-01    55311
#  2023-12-01    55281
#  Name: Sales, dtype: int64)

# %%
pred_3, pred_6, pred_12
# Out:
# (Month-Year
#  2023-10-01    54987.0
#  2023-11-01    55154.0
#  2023-12-01    55249.0
#  Name: SMA_3months, dtype: float64,
#  Month-Year
#  2023-07-01    54243.0
#  2023-08-01    52755.0
#  2023-09-01    56353.0
#  2023-10-01    54015.0
#  2023-11-01    54171.0
#  2023-12-01    55909.0
#  Name: SMA_6months, dtype: float64,
#  Month-Year
#  2023-01-01    52110.0
#  2023-02-01    51737.0
#  2023-03-01    51573.0
#  2023-04-01    52251.0
#  2023-05-01    52238.0
#  2023-06-01    53120.0
#  2023-07-01    52366.0
#  2023-08-01    52405.0
#  2023-09-01    52418.0
#  2023-10-01    52373.0
#  2023-11-01    52326.0
#  2023-12-01    52297.0
#  Name: SMA_12months, dtype: float64)

# %%
mae_3= mean_absolute_error(test_3,pred_3)
mse_3=mean_squared_error(test_3,pred_3)
mape_3= mean_absolute_percentage_error(test_3,pred_3)
rmse_3= np.sqrt(mean_squared_error(test_3,pred_3))

print(f'MAE - Simple Moving Averages_3 months: {mae_3:0.3f}')
print(f'MAPE - Simple Moving Averages_3 months: {mape_3:0.3f}')
print(f'MSE - Simple Moving Averages_3 months: {mse_3:0.3f}')
print(f'RMSE - Simple Moving Averages_3 months: {rmse_3:0.3f}')
# Out:
# MAE - Simple Moving Averages_3 months: 259.000
# MAPE - Simple Moving Averages_3 months: 0.005
# MSE - Simple Moving Averages_3 months: 123805.667
# RMSE - Simple Moving Averages_3 months: 351.860

# %%
mae_6= mean_absolute_error(test_6,pred_6)
mse_6=mean_squared_error(test_6,pred_6)
mape_6= mean_absolute_percentage_error(test_6,pred_6)
rmse_6= np.sqrt(mean_squared_error(test_6,pred_6))

print(f'MAE - Moving Averages_6 months: {mae_6:0.3f}')
print(f'MAPE - Moving Averages_6 months: {mape_6:0.3f}')
print(f'MSE - Moving Averages_6 months: {mse_6:0.3f}')
print(f'RMSE - Moving Averages_6 months: {rmse_6:0.3f}')
# Out:
# MAE - Moving Averages_6 months: 1071.667
# MAPE - Moving Averages_6 months: 0.019
# MSE - Moving Averages_6 months: 1535276.667
# RMSE - Moving Averages_6 months: 1239.063

# %%
mae_12= mean_absolute_error(test_12,pred_12)
mse_12=mean_squared_error(test_12,pred_12)
mape_12= mean_absolute_percentage_error(test_12,pred_12)
rmse_12= np.sqrt(mean_squared_error(test_12,pred_12))

print(f'MAE - Moving Averages_12 months: {mae_12:0.3f}')
print(f'MAPE - Moving Averages_12 months: {mape_12:0.3f}')
print(f'MSE - Moving Averages_12 months: {mse_12:0.3f}')
print(f'RMSE - Moving Averages_12 months: {rmse_12:0.3f}')
# Out:
# MAE - Moving Averages_12 months: 7291.917
# MAPE - Moving Averages_12 months: 0.149
# MSE - Moving Averages_12 months: 94786044.417
# RMSE - Moving Averages_12 months: 9735.812

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(sales_a['Sales'])
sns.lineplot(pred_3)
plt.title('Product A - SMA 3 Months')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(sales_a['Sales'])
sns.lineplot(pred_6)
plt.title('Product A - SMA 6 Months')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(sales_a['Sales'])
sns.lineplot(pred_12)
plt.title('Product A - SMA 12 Months')
plt.show()

# %%
SALES_A=  df.drop(['Product Name','Product Category','Month','Year', 'SMA_12months','SMA_6months','SMA_3months'],axis=1)

# %%
TRAIN=SALES_A[:48]

# %%
# Calculate the 12-month moving average for the last 12 months
sma_12 = TRAIN.rolling(window=12).mean().iloc[-1]

# %%
# Initialize a list to hold your predictions
predictions = [sma_12]

# %%
# Initialize a list to hold your predictions
predictions = [sma_12]

# Generate predictions for the next 12 months
for i in range(11):
    # Add the most recent prediction to the sales data
    TRAIN= TRAIN.append(predictions[-1])
    
    # Calculate the new moving average and add it to the predictions list
    predictions.append(TRAIN.rolling(window=12).mean().iloc[-1])

# Convert predictions to an array
# Convert predictions to an array
predictions = np.array(predictions)

# Print the predictions
print(predictions)
# Out:
# [[52109.75      ]
#  [51736.8125    ]
#  [51573.38020833]
#  [52250.99522569]
#  [52238.24482784]
#  [53119.93189682]
#  [52365.59288822]
#  [52405.22562891]
#  [52417.66109798]
#  [52372.54952282]
#  [52326.26198305]
#  [52297.03381497]]
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\267905979.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   TRAIN= TRAIN.append(predictions[-1])
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\267905979.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   TRAIN= TRAIN.append(predictions[-1])
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\267905979.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   TRAIN= TRAIN.append(predictions[-1])
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\267905979.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   TRAIN= TRAIN.append(predictions[-1])
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\267905979.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   TRAIN= TRAIN.append(predictions[-1])
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\267905979.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   TRAIN= TRAIN.append(predictions[-1])
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\267905979.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   TRAIN= TRAIN.append(predictions[-1])
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\267905979.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   TRAIN= TRAIN.append(predictions[-1])
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\267905979.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   TRAIN= TRAIN.append(predictions[-1])
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\267905979.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   TRAIN= TRAIN.append(predictions[-1])
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\267905979.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   TRAIN= TRAIN.append(predictions[-1])

# %%
TEST=SALES_A[48:]

# %%
TEST['Predictions']=predictions
# Out:
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\1893014185.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TEST['Predictions']=predictions

# %%
TEST
# Out:
#             Sales   Predictions
# Month-Year
# 2023-01-01  63171  52109.750000
# 2023-02-01  31168  51736.812500
# 2023-03-01  70380  51573.380208
# 2023-04-01  53078  52250.995226
# 2023-05-01  43741  52238.244828
# 2023-06-01  63919  53119.931897
# 2023-07-01  54485  52365.592888
# 2023-08-01  54869  52405.225629
# 2023-09-01  55607  52417.661098
# 2023-10-01  55575  52372.549523
# 2023-11-01  55311  52326.261983
# 2023-12-01  55281  52297.033815

# %%
_mae_12= mean_absolute_error(TEST['Sales'],TEST['Predictions'])
_mse_12=mean_squared_error(TEST['Sales'],TEST['Predictions'])
_mape_12= mean_absolute_percentage_error(TEST['Sales'],TEST['Predictions'])
_rmse_12= np.sqrt(mean_squared_error(TEST['Sales'],TEST['Predictions']))

print(f'MAE - Moving Averages_12 months: {_mae_12:0.3f}')
print(f'MAPE - Moving Averages_12 months: {_mape_12:0.3f}')
print(f'MSE - Moving Averages_12 months: {_mse_12:0.3f}')
print(f'RMSE - Moving Averages_12 months: {_rmse_12:0.3f}')
# Out:
# MAE - Moving Averages_12 months: 7291.973
# MAPE - Moving Averages_12 months: 0.149
# MSE - Moving Averages_12 months: 94785465.270
# RMSE - Moving Averages_12 months: 9735.783

# %%
TRAIN_6=SALES_A[:54]

# %%
# Calculate the 12-month moving average for the last 12 months
sma_6 = TRAIN_6.rolling(window=6).mean().iloc[-1]

# %%
# Initialize a list to hold your predictions
predictions_6 = [sma_6]

# %%
# Generate predictions for the next 12 months
for i in range(5):
    # Add the most recent prediction to the sales data
    TRAIN_6= TRAIN_6.append(predictions_6[-1])
    
    # Calculate the new moving average and add it to the predictions list
    predictions_6.append(TRAIN_6.rolling(window=6).mean().iloc[-1])

# Convert predictions to an array
# Convert predictions to an array
predictions_6 = np.array(predictions_6)

# Print the predictions
print(predictions_6)
# Out:
# [[54242.83333333]
#  [52754.80555556]
#  [56352.60648148]
#  [54014.70756173]
#  [54170.82548868]
#  [55909.1297368 ]]
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\3961750865.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   TRAIN_6= TRAIN_6.append(predictions_6[-1])
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\3961750865.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   TRAIN_6= TRAIN_6.append(predictions_6[-1])
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\3961750865.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   TRAIN_6= TRAIN_6.append(predictions_6[-1])
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\3961750865.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   TRAIN_6= TRAIN_6.append(predictions_6[-1])
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\3961750865.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   TRAIN_6= TRAIN_6.append(predictions_6[-1])

# %%
TEST_6=SALES_A[54:]

# %%
TEST_6['Predictions_6']=predictions_6
# Out:
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\222086592.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TEST_6['Predictions_6']=predictions_6

# %%
TEST_6
# Out:
#             Sales  Predictions_6
# Month-Year
# 2023-07-01  54485   54242.833333
# 2023-08-01  54869   52754.805556
# 2023-09-01  55607   56352.606481
# 2023-10-01  55575   54014.707562
# 2023-11-01  55311   54170.825489
# 2023-12-01  55281   55909.129737

# %%
_mae_6= mean_absolute_error(TEST_6['Sales'],TEST_6['Predictions_6'])
_mse_6=mean_squared_error(TEST_6['Sales'],TEST_6['Predictions_6'])
_mape_6= mean_absolute_percentage_error(TEST_6['Sales'],TEST_6['Predictions_6'])
_rmse_6= np.sqrt(mean_squared_error(TEST_6['Sales'],TEST_6['Predictions_6']))

print(f'MAE - Moving Averages_6 months: {_mae_6:0.3f}')
print(f'MAPE - Moving Averages_6 months: {_mape_6:0.3f}')
print(f'MSE - Moving Averages_6 months: {_mse_6:0.3f}')
print(f'RMSE - Moving Averages_6 months: {_rmse_6:0.3f}')
# Out:
# MAE - Moving Averages_6 months: 1071.761
# MAPE - Moving Averages_6 months: 0.019
# MSE - Moving Averages_6 months: 1535574.874
# RMSE - Moving Averages_6 months: 1239.183

# %%
TRAIN_3=SALES_A[:57]

# %%
# Calculate the 12-month moving average for the last 12 months
sma_3 = TRAIN_3.rolling(window=3).mean().iloc[-1]

# %%
# Initialize a list to hold your predictions
predictions_3 = [sma_3]

# %%
# Generate predictions 
for i in range(2):
    # Add the most recent prediction to the sales data
    TRAIN_3= TRAIN_3.append(predictions_3[-1])
    
    # Calculate the new moving average and add it to the predictions list
    predictions_3.append(TRAIN_3.rolling(window=3).mean().iloc[-1])

# Convert predictions to an array
# Convert predictions to an array
predictions_3 = np.array(predictions_3)

# Print the predictions
print(predictions_3)
# Out:
# [[54987.        ]
#  [55154.33333333]
#  [55249.44444444]]
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\3617957995.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   TRAIN_3= TRAIN_3.append(predictions_3[-1])
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\3617957995.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   TRAIN_3= TRAIN_3.append(predictions_3[-1])

# %%
TEST_3=SALES_A[57:]

# %%
TEST_3['Predictions_3']=predictions_3
# Out:
# C:\Users\Maaz\AppData\Local\Temp\ipykernel_36432\2019305812.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TEST_3['Predictions_3']=predictions_3

# %%
TEST_3
# Out:
#             Sales  Predictions_3
# Month-Year
# 2023-10-01  55575   54987.000000
# 2023-11-01  55311   55154.333333
# 2023-12-01  55281   55249.444444

# %%
_mae_3= mean_absolute_error(TEST_3['Sales'],TEST_3['Predictions_3'])
_mse_3=mean_squared_error(TEST_3['Sales'],TEST_3['Predictions_3'])
_mape_3= mean_absolute_percentage_error(TEST_3['Sales'],TEST_3['Predictions_3'])
_rmse_3= np.sqrt(mean_squared_error(TEST_3['Sales'],TEST_3['Predictions_3']))

print(f'MAE - Simple Moving Averages_3 months: {_mae_3:0.3f}')
print(f'MAPE - Simple Moving Averages_3 months: {_mape_3:0.3f}')
print(f'MSE - Simple Moving Averages_3 months: {_mse_3:0.3f}')
print(f'RMSE - Simple Moving Averages_3 months: {_rmse_3:0.3f}')
# Out:
# MAE - Simple Moving Averages_3 months: 258.741
# MAPE - Simple Moving Averages_3 months: 0.005
# MSE - Simple Moving Averages_3 months: 123761.399
# RMSE - Simple Moving Averages_3 months: 351.797
