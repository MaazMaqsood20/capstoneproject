# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error,mean_absolute_error, mean_absolute_percentage_error
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import warnings
warnings.filterwarnings('ignore')
import itertools

# %%
df=pd.read_csv('product d.csv', parse_dates=['Month-Year'], index_col='Month-Year')

# %%
df.head(15)
# Out:
#            Product Name  Product Category      Month  Year   Sales  \
# Month-Year
# 2019-01-01    Product D  Iron Preparation    January  2019   96684
# 2019-02-01    Product D  Iron Preparation   February  2019   99187
# 2019-03-01    Product D  Iron Preparation      March  2019  113711
# 2019-04-01    Product D  Iron Preparation      April  2019  103982
# 2019-05-01    Product D  Iron Preparation        May  2019  101826
# 2019-06-01    Product D  Iron Preparation       June  2019  106736
# 2019-07-01    Product D  Iron Preparation       July  2019   91567
# 2019-08-01    Product D  Iron Preparation     August  2019   96918
# 2019-09-01    Product D  Iron Preparation  September  2019   89551
# 2019-10-01    Product D  Iron Preparation   October   2019   84104
# 2019-11-01    Product D  Iron Preparation   November  2019   84553
# 2019-12-01    Product D  Iron Preparation   December  2019   99223
# 2020-01-01    Product D  Iron Preparation    January  2020  109216
# 2020-02-01    Product D  Iron Preparation   February  2020  106546
# 2020-03-01    Product D  Iron Preparation      March  2020  124519
#
#             Market Size  Marketing Expense  Month No.
# Month-Year
# 2019-01-01       371027             879515          1
# 2019-02-01       380632             902285          2
# 2019-03-01       436369            1034407          3
# 2019-04-01       399033             945904          4
# 2019-05-01       390760             926291          5
# 2019-06-01       409602             970956          6
# 2019-07-01       351390             832967          7
# 2019-08-01       371925             881644          8
# 2019-09-01       343654             814628          9
# 2019-10-01       324474             769162         10
# 2019-11-01       380771             902612         11
# 2019-12-01       322751             765078         12
# 2020-01-01       400592             345473          1
# 2020-02-01       390799             337027          2
# 2020-03-01       456722             393880          3

# %%
sales_d= df.drop(['Product Name','Product Category','Month','Year','Month No.'],axis=1)

# %%
sales_d.shape
# Out:
# (60, 3)

# %%
sales_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 60 entries, 2019-01-01 to 2023-12-01
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sales              60 non-null     int64
#  1   Market Size        60 non-null     int64
#  2   Marketing Expense  60 non-null     int64
# dtypes: int64(3)
# memory usage: 1.9 KB

# %%
print('Total Sales:', sales_d['Sales'].sum())
print('Total Market Size:',sales_d['Market Size'].sum())
print('Total Marketing Expense:', sales_d['Marketing Expense'].sum())
# Out:
# Total Sales: 7173488
# Total Market Size: 22698270
# Total Marketing Expense: 20113818

# %%
plt.figure(figsize=(12,8))
sns.lineplot(sales_d['Sales'])
plt.title('Product D')
# Out:
# Text(0.5, 1.0, 'Product D')

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def adf_test(series):
    result=adfuller(series)
    print('ADF Statistics: {}'.format(result[0]))
    print('p- value: {}'.format(result[1]))
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adf_test(sales_d['Sales'])
# Out:
# ADF Statistics: -2.3249460487083105
# p- value: 0.16404854202961083
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
sales_d_diff= sales_d['Sales'].diff().dropna()

# %%
sales_d_diff.plot(figsize=(12,8))
plt.title('Product D - First Difference')
# Out:
# Text(0.5, 1.0, 'Product D - First Difference')

# %%
# Plot ACF and PACF
plt.figure(figsize=(12, 6))
plt.subplot(211)
plot_acf(sales_d_diff, lags=20, ax=plt.gca())
plt.title('Autocorrelation Function (ACF) - 1st Difference')

plt.subplot(212)
plot_pacf(sales_d_diff, lags=20, ax=plt.gca())
plt.title('Partial Autocorrelation Function (PACF) - 1st Difference')

plt.tight_layout()
plt.show()

# %%
adf_test(sales_d_diff)
# Out:
# ADF Statistics: -4.6011480666771325
# p- value: 0.00012854172822943823
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
train= sales_d[:48]
test=sales_d[48:]

# %%
len(train)
# Out:
# 48

# %%
#Finding the best value for ARIMA

#import itertools
#p=d=q=range(0,5)
#pdq = list(itertools.product(p,d,q))

#for param in pdq:
#    try:
#        model_arima = ARIMA(train,order=param)
#        model_arima_fit = model_arima.fit()
#       print(param,model_arima_fit.aic)
#    except:
#        continue
    
# The Akaike information criterion (AIC) is an estimator of in-sample prediction error and thereby relative quality of
# statistical models for a given set of data

# It's like the mean squared error in Regression - The smaller the number, the better

# %%
#therefore, the combination p=(0,1,2,3,4,5) d=1 q=(0,1,2,3) must be tested with accuracy metrics and aic

# %%
#param = [(0,1,0),(0,1,1),(0,1,2),(0,1,3),(1,1,0),(1,1,1),(1,1,2),(1,1,3),(2,1,0), (2,1,1), (2,1,2),(2,1,3),(3,1,0),(3,1,1),(3,1,2),(3,1,3),(4,1,0),(4,1,1),(4,1,2),(4,1,3),(5,1,0),(5,1,1),(5,1,2),(5,1,3)]

#for p in param:  # Changed 'x' to 'p'
#    model = ARIMA(train, order=p).fit()
#    pred = model.forecast(steps=len(test))
#    mae = mean_absolute_error(test, pred)
#    mape = np.mean(np.abs((test - pred) / test)) * 100
#    mse=mean_squared_error(test, pred)
#    rmse = np.sqrt(mean_squared_error(test, pred))
#    print(p)
#    print(f'MAE: {mae}')
#    print(f'MSE: {mse}')
#    print(f'RMSE: {rmse}')
#    print('A.I.C:', model.aic)

# %%
order=[]
for p in range(6):
    # Loop over MA order
    for q in range(2):
        # Fit model        
#       model= ARIMA(sales_b, order=(p,1,q))
        model_t = ARIMA(train['Sales'], order=(p,1,q), exog=train[['Market Size','Marketing Expense']])
        model_test=model_t.fit() 
        pred=model_test.predict(start=len(train), end=(len(sales_d)-1), exog=test[['Market Size','Marketing Expense']])
        mae = mean_absolute_error(test['Sales'], pred)
        mape = np.mean(np.abs((test['Sales'] - pred) / test)) * 100
        mse=mean_squared_error(test['Sales'], pred)
        rmse = np.sqrt(mean_squared_error(test['Sales'], pred))
        # Add order and scores to list        
        order.append((p, q, model_test.aic, model_test.bic,mae, mse, rmse))
#Make DataFrame of model order and AIC/BIC scores
order_df = pd.DataFrame(order, columns=['p','q', 'aic', 'bic', 'mae','mse', 'rmse'])

# %%
# Sort by AIC
print(order_df.sort_values('aic'))
# Out:
#     p  q          aic          bic          mae           mse         rmse
# 1   0  1  1024.628097  1032.028687  3980.012603  2.733017e+07  5227.826300
# 3   1  1  1025.637032  1034.887770  3496.147807  2.118641e+07  4602.869806
# 4   2  0  1026.903749  1036.154487  3630.020235  1.661489e+07  4076.136126
# 5   2  1  1027.334916  1038.435802  3461.947579  2.157808e+07  4645.221410
# 2   1  0  1027.833818  1035.234409  4348.762358  2.471953e+07  4971.874091
# 6   3  0  1028.295741  1039.396626  3410.529804  1.624168e+07  4030.096651
# 7   3  1  1029.149436  1042.100469  3444.733432  2.091395e+07  4573.177489
# 8   4  0  1029.791124  1042.742157  3307.990397  1.722433e+07  4150.220499
# 9   4  1  1031.114575  1045.915755  3472.621232  2.126752e+07  4611.671944
# 10  5  0  1031.734965  1046.536146  3312.300490  1.713270e+07  4139.166595
# 11  5  1  1033.103573  1049.754901  3487.141096  2.145644e+07  4632.110117
# 0   0  0  1162.969006  1168.519449  5161.403534  3.507999e+07  5922.836265

# %%
m_arima= ARIMA(train['Sales'], order=(0,1,1), exog=train[['Market Size','Marketing Expense']])
model_arima=m_arima.fit()
print(model_arima.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Sales   No. Observations:                   48
# Model:                 ARIMA(0, 1, 1)   Log Likelihood                -508.314
# Date:                Thu, 09 May 2024   AIC                           1024.628
# Time:                        16:47:13   BIC                           1032.029
# Sample:                    01-01-2019   HQIC                          1027.413
#                          - 12-01-2022
# Covariance Type:                  opg
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Market Size           0.1718      0.035      4.955      0.000       0.104       0.240
# Marketing Expense    -0.0042      0.021     -0.199      0.843      -0.046       0.038
# ma.L1                -0.6367      0.094     -6.785      0.000      -0.821      -0.453
# sigma2             1.496e+08   2.93e-10    5.1e+17      0.000     1.5e+08     1.5e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               296.70
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.44   Skew:                             2.40
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.33
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.41e+33. Standard errors may be unstable.

# %%
residuals= model_arima.resid[1:]
fig,ax=plt.subplots(1,2, figsize=(14, 6))
residuals.plot(title='Residuals',ax=ax[0])
residuals.plot(title='Density',kind='kde',ax=ax[1])
plt.show()

# %%
# Plot ACF and PACF
plt.figure(figsize=(12, 6))
plt.subplot(211)
plot_acf(residuals, lags=20, ax=plt.gca())
plt.title('Autocorrelation Function (ACF)- Residuals')

plt.subplot(212)
plot_pacf(residuals, lags=20, ax=plt.gca())
plt.title('Partial Autocorrelation Function (PACF) - Residuals')

plt.tight_layout()
plt.show()

# %%
# Create the 4 diagostics plots
model_arima.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
#pred_in_sample = model_arima.get_prediction(start=len(train), end=(len(sales_b)-1))
#sales_b['Forecast_ARIMA_p']=[None]*len(train) + list(pred)

# %%
#plt.figure(figsize=(12, 8))
#sns.lineplot(sales_b[['Sales','Forecast_ARIMA_p']])
#plt.title('Product B')
#plt.show()

# %%
pred=model_arima.predict(start=len(train), end=(len(sales_d)-1), exog=test[['Market Size','Marketing Expense']], dynamic = True)
sales_d['Forecast_ARIMAX']=[None]*len(train) + list(pred)
#sales_b.plot()

# %%
#pred=model_arima.forecast(steps= len(test))
#sales_b['Forecast_ARIMA']=[None]*len(train) + list(pred)
#sales_b.plot()

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(sales_d[['Sales','Forecast_ARIMAX']])
plt.title('Product D')
plt.show()

# %%
mae_arimax= mean_absolute_error(test['Sales'],pred)
mse_arimax=mean_squared_error(test['Sales'], pred)
mape_arimax= mean_absolute_percentage_error(test['Sales'],pred)
rmse_arimax= np.sqrt(mean_squared_error(test['Sales'],pred))

print(f'MAE - ARIMAX: {mae_arimax}')
print(f'MAPE - ARIMAX: {mape_arimax}')
print(f'MSE - ARIMAX: {mse_arimax}')
print(f'RMSE - ARIMAX: {rmse_arimax}')
# Out:
# MAE - ARIMAX: 3980.012602816149
# MAPE - ARIMAX: 0.031241808602117848
# MSE - ARIMAX: 27330167.818840727
# RMSE - ARIMAX: 5227.826299604906

# %% [markdown]
# # SARIMA

# %%
import statsmodels.api as sm

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Perform seasonal decomposition
decomposition = seasonal_decompose(sales_d['Sales'], model='additive', period=12)

# Plot the decomposition
#fig = decomposition.plot(figsize=(12,8))
#plt.show()
# Create a new figure with the specified size
plt.figure(figsize=(12, 8))
plt.suptitle('Seasonal Decomposition of Product D - Sales')

# Plot each component separately
plt.subplot(411)
plt.plot(decomposition.observed, label='Observed')
plt.legend()

plt.subplot(412)
plt.plot(decomposition.trend, label='Trend')
plt.legend()

plt.subplot(413)
plt.plot(decomposition.seasonal, label='Seasonal')
plt.legend()

plt.subplot(414)
plt.plot(decomposition.resid, label='Residual')
plt.legend()

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
# Plot ACF and PACF
plt.figure(figsize=(12, 6))
plt.subplot(211)
plot_acf(sales_d['Sales'], lags=24, ax=plt.gca())
plt.title('Autocorrelation Function (ACF) - Original Data')

plt.subplot(212)
plot_pacf(sales_d['Sales'], lags=24, ax=plt.gca())
plt.title('Partial Autocorrelation Function (PACF) - Original Data')

plt.tight_layout()
plt.show()

# %%
order_SARIMAX=[]
# Loop over P order
for P in range(5):
    # Loop over Q order
    for Q in range(4):
        # Fit model
        model_s = sm.tsa.statespace.SARIMAX(train['Sales'], order=(0, 1, 1), seasonal_order=(P, 0, Q, 12),exog=train[['Market Size','Marketing Expense']])
        model_test_s = model_s.fit() 
        pred = model_test_s.predict(start=48, end=59, dynamic=True, exog=test[['Market Size','Marketing Expense']])
        mae = mean_absolute_error(test['Sales'], pred)
        mse = mean_squared_error(test['Sales'], pred)
        # Add order and scores to list        
        order_SARIMAX.append((P, Q, model_test_s.aic, model_test_s.bic, mae, mse))

# Make DataFrame of model order and scores
order_SARIMAX_df = pd.DataFrame(order_SARIMAX, columns=['P', 'Q', 'aic', 'bic', 'mae', 'mse'])

# %%
# Sort by AIC
print(order_SARIMAX_df.sort_values('aic'))
# Out:
#     P  Q          aic          bic           mae           mse
# 2   0  2  1020.555299  1031.656184   6448.728729  6.787979e+07
# 12  3  0  1020.911364  1033.862398   4711.841668  5.125663e+07
# 8   2  0  1021.296280  1032.397166  12524.063564  2.071854e+08
# 6   1  2  1021.401548  1034.352581   6595.703759  6.687218e+07
# 9   2  1  1021.615414  1034.566447  10138.232963  1.436905e+08
# 3   0  3  1021.885576  1034.836609   4795.103371  4.191467e+07
# 16  4  0  1022.840231  1037.641412   5539.886828  6.014439e+07
# 13  3  1  1022.842005  1037.643185   5504.980882  6.018581e+07
# 7   1  3  1022.988295  1037.789476   7580.535458  8.898714e+07
# 10  2  2  1023.081217  1037.882398   8063.151849  9.727515e+07
# 0   0  0  1024.628097  1032.028687   3980.012603  2.733017e+07
# 4   1  0  1024.795461  1034.046200   4405.821716  2.734955e+07
# 14  3  2  1024.840289  1041.491617   5555.042753  6.038012e+07
# 17  4  1  1024.840630  1041.491958   5547.754255  6.046014e+07
# 5   1  1  1024.899799  1036.000685  11048.131711  1.325774e+08
# 11  2  3  1025.179755  1041.831083   8037.486008  9.901825e+07
# 1   0  1  1025.595210  1034.845948   3940.251349  2.515040e+07
# 18  4  2  1026.840242  1045.341718   5536.467253  6.010953e+07
# 15  3  3  1026.841910  1045.343386   5499.944210  5.995141e+07
# 19  4  3  1028.840219  1049.191842   5538.072002  6.012368e+07

# %%
sarima=sm.tsa.statespace.SARIMAX(train['Sales'],order=(0, 1, 1),seasonal_order=(0,0,2,12),exog=train[['Market Size','Marketing Expense']])
sarima_model=sarima.fit()
print(sarima_model.summary())
# Out:
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                   Sales   No. Observations:                   48
# Model:             SARIMAX(0, 1, 1)x(0, 0, [1, 2], 12)   Log Likelihood                -504.278
# Date:                                 Thu, 09 May 2024   AIC                           1020.555
# Time:                                         16:49:40   BIC                           1031.656
# Sample:                                     01-01-2019   HQIC                          1024.733
#                                           - 12-01-2022
# Covariance Type:                                   opg
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Market Size           0.1476      0.050      2.947      0.003       0.049       0.246
# Marketing Expense     0.0074      0.024      0.308      0.758      -0.040       0.054
# ma.L1                -0.6784      0.223     -3.042      0.002      -1.115      -0.241
# ma.S.L12              0.2532      0.182      1.393      0.164      -0.103       0.609
# ma.S.L24              0.4525      0.388      1.166      0.243      -0.308       1.213
# sigma2             1.496e+08   1.91e-09   7.82e+16      0.000     1.5e+08     1.5e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):               129.61
# Prob(Q):                              0.81   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.82   Skew:                             1.73
# Prob(H) (two-sided):                  0.05   Kurtosis:                        10.36
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.23e+32. Standard errors may be unstable.

# %%
sarima_model.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
forecast_test_sarima=sarima_model.predict(start=48, end=59, dynamic=True, exog=test[['Market Size','Marketing Expense']])

# %%
sales_d['Forecast_SARIMAX']=[None]*len(train)+ list(forecast_test_sarima)
#sales_b[['Sales','Forecast_SARIMA']].plot(figsize=(12,8))

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(sales_d[['Sales','Forecast_SARIMAX']])
plt.title('Product D')
# Out:
# Text(0.5, 1.0, 'Product D')

# %%
mae_sarimax= mean_absolute_error(test['Sales'],forecast_test_sarima)
mape_sarimax= mean_absolute_percentage_error(test['Sales'],forecast_test_sarima)
mse_sarimax=mean_squared_error(test['Sales'], forecast_test_sarima)
rmse_sarimax= np.sqrt(mean_squared_error(test['Sales'],forecast_test_sarima))

print(f'MAE - SARIMAX: {round(mae_sarimax,3)}')
print(f'MAPE - SARIMAX: {round(mape_sarimax,3)}')
print(f'MSE - SARIMAX: {round(mse_sarimax,3)}')
print(f'RMSE - SARIMAX: {round(rmse_sarimax,3)}')
# Out:
# MAE - SARIMAX: 6448.729
# MAPE - SARIMAX: 0.049
# MSE - SARIMAX: 67879787.846
# RMSE - SARIMAX: 8238.919

# %% [markdown]
# # AUTO-ARIMA

# %%
import pmdarima as pm

# %%
auto_arima= pm.auto_arima(train['Sales'], start_p=0, d=1, start_q=0, max_p=5,max_q=3,
                          start_P=0, D=0, start_Q=0, max_P=5 ,max_Q=4 ,  
                          stepwise=False, trace=True,
                          seasonal=True,m=12, exogenous=train[['Market Size','Marketing Expense']])
auto_arima
# Out:
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=1029.162, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=1029.090, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,2)[12] intercept   : AIC=1027.011, Time=0.18 sec
#  ARIMA(0,1,0)(0,0,3)[12] intercept   : AIC=1027.058, Time=0.35 sec
#  ARIMA(0,1,0)(0,0,4)[12] intercept   : AIC=1029.046, Time=1.98 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=1028.486, Time=0.06 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=1030.154, Time=0.23 sec
#  ARIMA(0,1,0)(1,0,2)[12] intercept   : AIC=1027.163, Time=0.37 sec
#  ARIMA(0,1,0)(1,0,3)[12] intercept   : AIC=1029.057, Time=0.76 sec
#  ARIMA(0,1,0)(1,0,4)[12] intercept   : AIC=1030.954, Time=7.30 sec
#  ARIMA(0,1,0)(2,0,0)[12] intercept   : AIC=1029.052, Time=0.31 sec
#  ARIMA(0,1,0)(2,0,1)[12] intercept   : AIC=1028.040, Time=0.37 sec
#  ARIMA(0,1,0)(2,0,2)[12] intercept   : AIC=1029.119, Time=0.57 sec
#  ARIMA(0,1,0)(2,0,3)[12] intercept   : AIC=1031.051, Time=1.28 sec
#  ARIMA(0,1,0)(3,0,0)[12] intercept   : AIC=1026.901, Time=0.42 sec
#  ARIMA(0,1,0)(3,0,1)[12] intercept   : AIC=1028.895, Time=0.48 sec
#  ARIMA(0,1,0)(3,0,2)[12] intercept   : AIC=1030.882, Time=1.20 sec
#  ARIMA(0,1,0)(4,0,0)[12] intercept   : AIC=1028.900, Time=1.69 sec
#  ARIMA(0,1,0)(4,0,1)[12] intercept   : AIC=inf, Time=10.67 sec
#  ARIMA(0,1,0)(5,0,0)[12] intercept   : AIC=1030.899, Time=2.53 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=1029.921, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=1029.928, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,2)[12] intercept   : AIC=1027.199, Time=0.27 sec
#  ARIMA(0,1,1)(0,0,3)[12] intercept   : AIC=1026.127, Time=0.71 sec
#  ARIMA(0,1,1)(0,0,4)[12] intercept   : AIC=1028.118, Time=2.55 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=1029.327, Time=0.13 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=1031.017, Time=0.20 sec
#  ARIMA(0,1,1)(1,0,2)[12] intercept   : AIC=1026.346, Time=0.50 sec
#  ARIMA(0,1,1)(1,0,3)[12] intercept   : AIC=1028.115, Time=0.62 sec
#  ARIMA(0,1,1)(2,0,0)[12] intercept   : AIC=1029.814, Time=0.27 sec
#  ARIMA(0,1,1)(2,0,1)[12] intercept   : AIC=1027.722, Time=0.39 sec
#  ARIMA(0,1,1)(2,0,2)[12] intercept   : AIC=1028.300, Time=0.67 sec
#  ARIMA(0,1,1)(3,0,0)[12] intercept   : AIC=1025.802, Time=0.57 sec
#  ARIMA(0,1,1)(3,0,1)[12] intercept   : AIC=1027.774, Time=1.08 sec
#  ARIMA(0,1,1)(4,0,0)[12] intercept   : AIC=1027.784, Time=2.40 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=1031.781, Time=0.07 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=1031.332, Time=0.13 sec
#  ARIMA(0,1,2)(0,0,2)[12] intercept   : AIC=1027.921, Time=0.40 sec
#  ARIMA(0,1,2)(0,0,3)[12] intercept   : AIC=1026.958, Time=0.91 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=1030.772, Time=0.14 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=1032.699, Time=0.21 sec
#  ARIMA(0,1,2)(1,0,2)[12] intercept   : AIC=1026.804, Time=0.52 sec
#  ARIMA(0,1,2)(2,0,0)[12] intercept   : AIC=1031.361, Time=0.36 sec
#  ARIMA(0,1,2)(2,0,1)[12] intercept   : AIC=1028.310, Time=0.50 sec
#  ARIMA(0,1,2)(3,0,0)[12] intercept   : AIC=1026.867, Time=0.91 sec
#  ARIMA(0,1,3)(0,0,0)[12] intercept   : AIC=1034.389, Time=0.14 sec
#  ARIMA(0,1,3)(0,0,1)[12] intercept   : AIC=1034.120, Time=0.22 sec
#  ARIMA(0,1,3)(0,0,2)[12] intercept   : AIC=1030.685, Time=0.53 sec
#  ARIMA(0,1,3)(1,0,0)[12] intercept   : AIC=1034.142, Time=0.12 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=1036.063, Time=0.23 sec
#  ARIMA(0,1,3)(2,0,0)[12] intercept   : AIC=1035.077, Time=0.81 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=1030.073, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=1030.132, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,2)[12] intercept   : AIC=1027.601, Time=0.25 sec
#  ARIMA(1,1,0)(0,0,3)[12] intercept   : AIC=1026.653, Time=0.55 sec
#  ARIMA(1,1,0)(0,0,4)[12] intercept   : AIC=1028.642, Time=2.08 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=1029.550, Time=0.07 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=1031.239, Time=0.15 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=1026.887, Time=0.41 sec
#  ARIMA(1,1,0)(1,0,3)[12] intercept   : AIC=1028.637, Time=1.21 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=1030.056, Time=0.37 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=1028.177, Time=0.49 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=1028.832, Time=0.61 sec
#  ARIMA(1,1,0)(3,0,0)[12] intercept   : AIC=1026.338, Time=0.65 sec
#  ARIMA(1,1,0)(3,0,1)[12] intercept   : AIC=1028.321, Time=0.97 sec
#  ARIMA(1,1,0)(4,0,0)[12] intercept   : AIC=1028.329, Time=2.35 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=1029.300, Time=0.37 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=1030.560, Time=0.19 sec
#  ARIMA(1,1,1)(0,0,2)[12] intercept   : AIC=1027.894, Time=0.48 sec
#  ARIMA(1,1,1)(0,0,3)[12] intercept   : AIC=1026.729, Time=1.18 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=1030.346, Time=0.27 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=1032.334, Time=0.34 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=1026.172, Time=0.81 sec
#  ARIMA(1,1,1)(2,0,0)[12] intercept   : AIC=1031.070, Time=0.81 sec
#  ARIMA(1,1,1)(2,0,1)[12] intercept   : AIC=1027.659, Time=0.80 sec
#  ARIMA(1,1,1)(3,0,0)[12] intercept   : AIC=1026.858, Time=1.21 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=1032.344, Time=0.17 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=1031.639, Time=0.30 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=1027.922, Time=0.63 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=1030.776, Time=0.32 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=1032.404, Time=0.44 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=1031.004, Time=0.86 sec
#  ARIMA(1,1,3)(0,0,0)[12] intercept   : AIC=1035.114, Time=0.31 sec
#  ARIMA(1,1,3)(0,0,1)[12] intercept   : AIC=1034.198, Time=0.57 sec
#  ARIMA(1,1,3)(1,0,0)[12] intercept   : AIC=1033.457, Time=0.63 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=1032.149, Time=0.07 sec
#  ARIMA(2,1,0)(0,0,1)[12] intercept   : AIC=1031.467, Time=0.10 sec
#  ARIMA(2,1,0)(0,0,2)[12] intercept   : AIC=1027.643, Time=0.33 sec
#  ARIMA(2,1,0)(0,0,3)[12] intercept   : AIC=1026.559, Time=0.71 sec
#  ARIMA(2,1,0)(1,0,0)[12] intercept   : AIC=1030.558, Time=0.12 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=1032.110, Time=0.22 sec
#  ARIMA(2,1,0)(1,0,2)[12] intercept   : AIC=1026.711, Time=0.59 sec
#  ARIMA(2,1,0)(2,0,0)[12] intercept   : AIC=1030.806, Time=0.54 sec
#  ARIMA(2,1,0)(2,0,1)[12] intercept   : AIC=1028.188, Time=0.77 sec
#  ARIMA(2,1,0)(3,0,0)[12] intercept   : AIC=1026.283, Time=0.79 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=1032.362, Time=0.26 sec
#  ARIMA(2,1,1)(0,0,1)[12] intercept   : AIC=1032.322, Time=0.35 sec
#  ARIMA(2,1,1)(0,0,2)[12] intercept   : AIC=1029.253, Time=0.68 sec
#  ARIMA(2,1,1)(1,0,0)[12] intercept   : AIC=1031.996, Time=0.36 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=1032.664, Time=0.97 sec
#  ARIMA(2,1,1)(2,0,0)[12] intercept   : AIC=1032.544, Time=0.92 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=1033.651, Time=0.24 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=1033.119, Time=0.56 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=1032.628, Time=0.70 sec
#  ARIMA(2,1,3)(0,0,0)[12] intercept   : AIC=inf, Time=0.60 sec
#  ARIMA(3,1,0)(0,0,0)[12] intercept   : AIC=1033.881, Time=0.13 sec
#  ARIMA(3,1,0)(0,0,1)[12] intercept   : AIC=1033.291, Time=0.17 sec
#  ARIMA(3,1,0)(0,0,2)[12] intercept   : AIC=1029.628, Time=0.38 sec
#  ARIMA(3,1,0)(1,0,0)[12] intercept   : AIC=1032.421, Time=0.15 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=1034.006, Time=0.25 sec
#  ARIMA(3,1,0)(2,0,0)[12] intercept   : AIC=1032.719, Time=0.69 sec
#  ARIMA(3,1,1)(0,0,0)[12] intercept   : AIC=1033.984, Time=0.26 sec
#  ARIMA(3,1,1)(0,0,1)[12] intercept   : AIC=1034.227, Time=0.47 sec
#  ARIMA(3,1,1)(1,0,0)[12] intercept   : AIC=1033.925, Time=0.48 sec
#  ARIMA(3,1,2)(0,0,0)[12] intercept   : AIC=1035.503, Time=0.33 sec
#  ARIMA(4,1,0)(0,0,0)[12] intercept   : AIC=1035.440, Time=0.11 sec
#  ARIMA(4,1,0)(0,0,1)[12] intercept   : AIC=1035.025, Time=0.13 sec
#  ARIMA(4,1,0)(1,0,0)[12] intercept   : AIC=1034.186, Time=0.20 sec
#  ARIMA(4,1,1)(0,0,0)[12] intercept   : AIC=1035.788, Time=0.33 sec
#  ARIMA(5,1,0)(0,0,0)[12] intercept   : AIC=1037.174, Time=0.11 sec
#
# Best model:  ARIMA(0,1,1)(3,0,0)[12] intercept
# Total fit time: 82.856 seconds
# ARIMA(order=(0, 1, 1), scoring_args={}, seasonal_order=(3, 0, 0, 12),
#       suppress_warnings=True)

# %%
auto_arima.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                   48
# Model:             SARIMAX(0, 1, 1)x(3, 0, [], 12)   Log Likelihood                -506.901
# Date:                             Thu, 09 May 2024   AIC                           1025.802
# Time:                                     16:51:26   BIC                           1036.902
# Sample:                                 01-01-2019   HQIC                          1029.979
#                                       - 12-01-2022
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    668.4297   2260.125      0.296      0.767   -3761.334    5098.193
# ma.L1         -0.1955      0.098     -1.999      0.046      -0.387      -0.004
# ar.S.L12       0.2002      0.206      0.972      0.331      -0.203       0.604
# ar.S.L24       0.2098      0.164      1.282      0.200      -0.111       0.530
# ar.S.L36      -0.3044      0.153     -1.984      0.047      -0.605      -0.004
# sigma2      1.648e+08      0.006   2.98e+10      0.000    1.65e+08    1.65e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.64   Jarque-Bera (JB):                11.69
# Prob(Q):                              0.42   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.25   Skew:                             0.51
# Prob(H) (two-sided):                  0.12   Kurtosis:                         5.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number  7e+26. Standard errors may be unstable.
# """

# %%
auto_arima.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
forecast_test_auto= auto_arima.predict(n_periods=len(test), exogenous=test[['Market Size','Marketing Expense']])
sales_d['Forecast_AUTO ARIMAX']=[None]*len(train)+ list(forecast_test_auto)
#sales_b[['Sales','Forecast_AUTO ARIMA']].plot()

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(sales_d[['Sales','Forecast_AUTO ARIMAX']])
plt.title('Product D')
# Out:
# Text(0.5, 1.0, 'Product D')

# %%
mae_auto_arimax= mean_absolute_error(test['Sales'],forecast_test_auto)
mape_auto_arimax= mean_absolute_percentage_error(test['Sales'],forecast_test_auto)
mse_auto_arimax=mean_squared_error(test['Sales'],forecast_test_auto)
rmse_auto_arimax= np.sqrt(mean_squared_error(test['Sales'],forecast_test_auto))

print(f'MAE - AUTO ARIMAX: {mae_auto_arimax}')
print(f'MAPE - AUTO ARIMAX: {mape_auto_arimax}')
print(f'MSE - AUTO ARIMAX: {mse_auto_arimax}')
print(f'RMSE - AUTO ARIMAX: {rmse_auto_arimax}')
# Out:
# MAE - AUTO ARIMAX: 11068.677390717747
# MAPE - AUTO ARIMAX: 0.08134296105127006
# MSE - AUTO ARIMAX: 166391629.23961398
# RMSE - AUTO ARIMAX: 12899.287935371238

# %%
sales_d.tail(12)
# Out:
#              Sales  Market Size  Marketing Expense  Forecast_ARIMAX  \
# Month-Year
# 2023-01-01  140104       399507              98343    140387.542653
# 2023-02-01  131006       373564              91957    135958.398104
# 2023-03-01  138656       395378              97326    139682.617658
# 2023-04-01  130866       373165              91858    135890.281748
# 2023-05-01  139824       398708              98146    140251.133944
# 2023-06-01  137565       392267              96561    139151.485745
# 2023-07-01  136637       389621              95909    138699.747607
# 2023-08-01  139824       398708              98146    140251.133944
# 2023-09-01  122293       348719              85841    131716.711876
# 2023-10-01  123887       362352              89197    134044.218686
# 2023-11-01  127074       362352              89197    134044.218686
# 2023-12-01  127074       353264              86960    132492.660581
#
#             Forecast_SARIMAX  Forecast_AUTO ARIMAX
# Month-Year
# 2023-01-01     141845.636553         119214.660769
# 2023-02-01     134735.156032         116006.509844
# 2023-03-01     142429.825824         118889.083313
# 2023-04-01     136923.972897         118652.784781
# 2023-05-01     145767.004841         124802.345922
# 2023-06-01     142139.355584         121844.907714
# 2023-07-01     142329.393537         125949.711714
# 2023-08-01     144944.995869         127665.365393
# 2023-09-01     132041.707356         122903.705578
# 2023-10-01     132462.947393         123335.742750
# 2023-11-01     127998.033469         123956.363403
# 2023-12-01     148576.715398         134161.898714

# %%
sales_d.mean()
# Out:
# Sales                   119558.133333
# Market Size             378304.500000
# Marketing Expense       335230.300000
# Forecast_ARIMAX         136880.845936
# Forecast_SARIMAX        139349.562063
# Forecast_AUTO ARIMAX    123115.256658
# dtype: float64

# %%
data = {
    'model': ['ARIMAX', 'AUTO ARIMAX', 'SEASONAL ARIMAX'],
    'MAE': [mae_arimax, mae_auto_arimax, mae_sarimax],  
    'MAPE': [mape_arimax, mape_auto_arimax, mape_sarimax],  
    'MSE': [mse_arimax, mse_auto_arimax, mse_sarimax],  
    'RMSE': [rmse_arimax, rmse_auto_arimax, rmse_sarimax]  
}

model_results = pd.DataFrame(data)
model_results.set_index('model', inplace=True)
model_results
# Out:
#                           MAE      MAPE           MSE          RMSE
# model
# ARIMAX            3980.012603  0.031242  2.733017e+07   5227.826300
# AUTO ARIMAX      11068.677391  0.081343  1.663916e+08  12899.287935
# SEASONAL ARIMAX   6448.728729  0.049489  6.787979e+07   8238.919094

# %% [markdown]
# # TESTING

# %%
auto_arima_1= pm.auto_arima(train['Sales'], start_p=0, start_q=0, max_p=5,max_q=2,
                          start_P=0, start_Q=0, max_P=2 ,max_Q=2 ,  
                          stepwise=False, trace=True,
                          seasonal=True,m=12, exogenous=train[['Market Size','Marketing Expense']])
auto_arima_1
# Out:
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=1029.162, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=1029.090, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,2)[12] intercept   : AIC=1027.011, Time=0.22 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=1028.486, Time=0.05 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=1030.154, Time=0.14 sec
#  ARIMA(0,1,0)(1,0,2)[12] intercept   : AIC=1027.163, Time=0.32 sec
#  ARIMA(0,1,0)(2,0,0)[12] intercept   : AIC=1029.052, Time=0.23 sec
#  ARIMA(0,1,0)(2,0,1)[12] intercept   : AIC=1028.040, Time=0.31 sec
#  ARIMA(0,1,0)(2,0,2)[12] intercept   : AIC=1029.119, Time=0.49 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=1029.921, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=1029.928, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,2)[12] intercept   : AIC=1027.199, Time=0.23 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=1029.327, Time=0.08 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=1031.017, Time=0.13 sec
#  ARIMA(0,1,1)(1,0,2)[12] intercept   : AIC=1026.346, Time=0.36 sec
#  ARIMA(0,1,1)(2,0,0)[12] intercept   : AIC=1029.814, Time=0.27 sec
#  ARIMA(0,1,1)(2,0,1)[12] intercept   : AIC=1027.722, Time=0.36 sec
#  ARIMA(0,1,1)(2,0,2)[12] intercept   : AIC=1028.300, Time=0.59 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=1031.781, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=1031.332, Time=0.12 sec
#  ARIMA(0,1,2)(0,0,2)[12] intercept   : AIC=1027.921, Time=0.40 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=1030.772, Time=0.18 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=1032.699, Time=0.25 sec
#  ARIMA(0,1,2)(1,0,2)[12] intercept   : AIC=1026.804, Time=0.60 sec
#  ARIMA(0,1,2)(2,0,0)[12] intercept   : AIC=1031.361, Time=0.39 sec
#  ARIMA(0,1,2)(2,0,1)[12] intercept   : AIC=1028.310, Time=0.46 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=1030.073, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=1030.132, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,2)[12] intercept   : AIC=1027.601, Time=0.24 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=1029.550, Time=0.13 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=1031.239, Time=0.15 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=1026.887, Time=0.53 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=1030.056, Time=0.35 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=1028.177, Time=0.57 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=1028.832, Time=0.59 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=1029.300, Time=0.31 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=1030.560, Time=0.15 sec
#  ARIMA(1,1,1)(0,0,2)[12] intercept   : AIC=1027.894, Time=0.42 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=1030.346, Time=0.19 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=1032.334, Time=0.27 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=1026.172, Time=0.64 sec
#  ARIMA(1,1,1)(2,0,0)[12] intercept   : AIC=1031.070, Time=0.70 sec
#  ARIMA(1,1,1)(2,0,1)[12] intercept   : AIC=1027.659, Time=0.74 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=1032.344, Time=0.19 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=1031.639, Time=0.25 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=1027.922, Time=0.54 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=1030.776, Time=0.25 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=1032.404, Time=0.35 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=1031.004, Time=0.81 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=1032.149, Time=0.06 sec
#  ARIMA(2,1,0)(0,0,1)[12] intercept   : AIC=1031.467, Time=0.10 sec
#  ARIMA(2,1,0)(0,0,2)[12] intercept   : AIC=1027.643, Time=0.30 sec
#  ARIMA(2,1,0)(1,0,0)[12] intercept   : AIC=1030.558, Time=0.15 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=1032.110, Time=0.24 sec
#  ARIMA(2,1,0)(1,0,2)[12] intercept   : AIC=1026.711, Time=0.58 sec
#  ARIMA(2,1,0)(2,0,0)[12] intercept   : AIC=1030.806, Time=0.51 sec
#  ARIMA(2,1,0)(2,0,1)[12] intercept   : AIC=1028.188, Time=0.80 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=1032.362, Time=0.23 sec
#  ARIMA(2,1,1)(0,0,1)[12] intercept   : AIC=1032.322, Time=0.39 sec
#  ARIMA(2,1,1)(0,0,2)[12] intercept   : AIC=1029.253, Time=0.69 sec
#  ARIMA(2,1,1)(1,0,0)[12] intercept   : AIC=1031.996, Time=0.35 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=1032.664, Time=0.93 sec
#  ARIMA(2,1,1)(2,0,0)[12] intercept   : AIC=1032.544, Time=0.84 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=1033.651, Time=0.23 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=1033.119, Time=0.48 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=1032.628, Time=0.54 sec
#  ARIMA(3,1,0)(0,0,0)[12] intercept   : AIC=1033.881, Time=0.12 sec
#  ARIMA(3,1,0)(0,0,1)[12] intercept   : AIC=1033.291, Time=0.13 sec
#  ARIMA(3,1,0)(0,0,2)[12] intercept   : AIC=1029.628, Time=0.34 sec
#  ARIMA(3,1,0)(1,0,0)[12] intercept   : AIC=1032.421, Time=0.14 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=1034.006, Time=0.23 sec
#  ARIMA(3,1,0)(2,0,0)[12] intercept   : AIC=1032.719, Time=0.62 sec
#  ARIMA(3,1,1)(0,0,0)[12] intercept   : AIC=1033.984, Time=0.25 sec
#  ARIMA(3,1,1)(0,0,1)[12] intercept   : AIC=1034.227, Time=0.46 sec
#  ARIMA(3,1,1)(1,0,0)[12] intercept   : AIC=1033.925, Time=0.39 sec
#  ARIMA(3,1,2)(0,0,0)[12] intercept   : AIC=1035.503, Time=0.28 sec
#  ARIMA(4,1,0)(0,0,0)[12] intercept   : AIC=1035.440, Time=0.09 sec
#  ARIMA(4,1,0)(0,0,1)[12] intercept   : AIC=1035.025, Time=0.11 sec
#  ARIMA(4,1,0)(1,0,0)[12] intercept   : AIC=1034.186, Time=0.20 sec
#  ARIMA(4,1,1)(0,0,0)[12] intercept   : AIC=1035.788, Time=0.32 sec
#  ARIMA(5,1,0)(0,0,0)[12] intercept   : AIC=1037.174, Time=0.15 sec
#
# Best model:  ARIMA(1,1,1)(1,0,2)[12] intercept
# Total fit time: 26.270 seconds
# ARIMA(order=(1, 1, 1), scoring_args={}, seasonal_order=(1, 0, 2, 12),
#       suppress_warnings=True)

# %%
auto_arima_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                       y   No. Observations:                   48
# Model:             SARIMAX(1, 1, 1)x(1, 0, [1, 2], 12)   Log Likelihood                -506.086
# Date:                                 Wed, 08 May 2024   AIC                           1026.172
# Time:                                         19:04:55   BIC                           1039.123
# Sample:                                     01-01-2019   HQIC                          1031.045
#                                           - 12-01-2022
# Covariance Type:                                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    764.6682    921.923      0.829      0.407   -1042.267    2571.604
# ar.L1          0.6368      0.188      3.394      0.001       0.269       1.005
# ma.L1         -0.9100      0.174     -5.227      0.000      -1.251      -0.569
# ar.S.L12      -0.7092      0.898     -0.790      0.430      -2.469       1.051
# ma.S.L12       0.9595      1.030      0.932      0.352      -1.059       2.978
# ma.S.L24       0.4193      0.248      1.692      0.091      -0.066       0.905
# sigma2      1.626e+08      0.002   6.62e+10      0.000    1.63e+08    1.63e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.45   Jarque-Bera (JB):                 3.38
# Prob(Q):                              0.50   Prob(JB):                         0.18
# Heteroskedasticity (H):               1.60   Skew:                             0.19
# Prob(H) (two-sided):                  0.36   Kurtosis:                         4.25
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.14e+27. Standard errors may be unstable.
# """

# %%
forecast_test_auto_1= auto_arima_1.predict(n_periods=len(test), exogenous=test[['Market Size','Marketing Expense']])
sales_d['Forecast_AUTO ARIMA_1']=[None]*len(train)+ list(forecast_test_auto_1)

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(sales_d[['Sales','Forecast_AUTO ARIMA_1']])
plt.title('Product D')
# Out:
# Text(0.5, 1.0, 'Product D')

# %%
mae_auto_arima_1= mean_absolute_error(test['Sales'],forecast_test_auto_1)
mape_auto_arima_1= mean_absolute_percentage_error(test['Sales'],forecast_test_auto_1)
mse_auto_arima_1=mean_squared_error(test['Sales'],forecast_test_auto_1)
rmse_auto_arima_1= np.sqrt(mean_squared_error(test['Sales'],forecast_test_auto_1))

print(f'MAE - AUTO ARIMA: {mae_auto_arima_1}')
print(f'MAPE - AUTO ARIMA: {mape_auto_arima_1}')
print(f'MSE - AUTO ARIMA: {mse_auto_arima_1}')
print(f'RMSE - AUTO ARIMA: {rmse_auto_arima_1}')
# Out:
# MAE - AUTO ARIMA: 12301.926198990162
# MAPE - AUTO ARIMA: 0.09520571373070087
# MSE - AUTO ARIMA: 229302604.24636534
# RMSE - AUTO ARIMA: 15142.740975344104
