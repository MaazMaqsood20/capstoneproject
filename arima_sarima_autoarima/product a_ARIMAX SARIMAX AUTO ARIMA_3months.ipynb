# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error,mean_absolute_error, mean_absolute_percentage_error
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import warnings
warnings.filterwarnings('ignore')
import itertools

# %%
df=pd.read_csv('product a.csv', parse_dates=['Month-Year'], index_col='Month-Year')

# %%
df.head(15)
# Out:
#            Product Name Product Category  Sales  Market Size  \
# Month-Year
# 2019-01-01    Product A   Pain/Analgesic  54555      2738080
# 2019-02-01    Product A   Pain/Analgesic  54293      4637013
# 2019-03-01    Product A   Pain/Analgesic  58798      7079920
# 2019-04-01    Product A   Pain/Analgesic  53229      3744057
# 2019-05-01    Product A   Pain/Analgesic  50558      4196578
# 2019-06-01    Product A   Pain/Analgesic  56326      6396559
# 2019-07-01    Product A   Pain/Analgesic  50125      2545212
# 2019-08-01    Product A   Pain/Analgesic  56414      6294066
# 2019-09-01    Product A   Pain/Analgesic  55658      5454980
# 2019-10-01    Product A   Pain/Analgesic  56203      4923556
# 2019-11-01    Product A   Pain/Analgesic  56943      7661409
# 2019-12-01    Product A   Pain/Analgesic  54800      4807354
# 2020-01-01    Product A   Pain/Analgesic  52172      4003955
# 2020-02-01    Product A   Pain/Analgesic  48942      5393032
# 2020-03-01    Product A   Pain/Analgesic  53422      3786103
#
#             Marketing Expense
# Month-Year
# 2019-01-01             177316
# 2019-02-01             300290
# 2019-03-01             458491
# 2019-04-01             242463
# 2019-05-01             271768
# 2019-06-01             414237
# 2019-07-01             164826
# 2019-08-01             407600
# 2019-09-01             353261
# 2019-10-01             318846
# 2019-11-01             496148
# 2019-12-01             311321
# 2020-01-01             103835
# 2020-02-01             139858
# 2020-03-01              98185

# %%
sales_a= df.drop(['Product Name','Product Category'],axis=1)

# %%
sales_a.shape
# Out:
# (60, 3)

# %%
sales_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 60 entries, 2019-01-01 to 2023-12-01
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sales              60 non-null     int64
#  1   Market Size        60 non-null     int64
#  2   Marketing Expense  60 non-null     int64
# dtypes: int64(3)
# memory usage: 1.9 KB

# %%
print('Total Sales:', sales_a['Sales'].sum())
print('Total Market Size:',sales_a['Market Size'].sum())
print('Total Marketing Expense:', sales_a['Marketing Expense'].sum())
# Out:
# Total Sales: 3213992
# Total Market Size: 360874201
# Total Marketing Expense: 19873176

# %%
plt.figure(figsize=(12,8))
sns.lineplot(sales_a['Sales'])
plt.title('Product A')
# Out:
# Text(0.5, 1.0, 'Product A')

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def adf_test(series):
    result=adfuller(series)
    print('ADF Statistics: {}'.format(result[0]))
    print('p- value: {}'.format(result[1]))
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adf_test(sales_a['Sales'])
# Out:
# ADF Statistics: -10.095004165158468
# p- value: 1.0967344875767964e-17
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
# Plot ACF and PACF
plt.figure(figsize=(12, 6))
plt.subplot(211)
plot_acf(sales_a['Sales'], lags=20, ax=plt.gca())
plt.title('Autocorrelation Function (ACF) - Original Dataset')

plt.subplot(212)
plot_pacf(sales_a['Sales'], lags=20, ax=plt.gca())
plt.title('Partial Autocorrelation Function (PACF) - Original Dataset')

plt.tight_layout()
plt.show()

# %%
train= sales_a[:57]
test=sales_a[57:]

# %%
print(len(train),len(test))
# Out:
# 57 3

# %%
order=[]
for p in range(6):
    # Loop over MA order
    for q in range(2):
        # Fit model        
#       model= ARIMA(sales_b, order=(p,1,q))
        model_t = ARIMA(train['Sales'], order=(p,0,q), exog=train[['Market Size','Marketing Expense']])
        model_test=model_t.fit() 
        pred=model_test.predict(start=len(train), end=(len(sales_a)-1), exog=test[['Market Size','Marketing Expense']])
        mae = mean_absolute_error(test['Sales'], pred)
        mape = np.mean(np.abs((test['Sales'] - pred) / test)) * 100
        mse=mean_squared_error(test['Sales'], pred)
        rmse = np.sqrt(mean_squared_error(test['Sales'], pred))
        # Add order and scores to list        
        order.append((p, q, model_test.aic, model_test.bic,mae, mse, rmse))
#Make DataFrame of model order and AIC/BIC scores
order_df = pd.DataFrame(order, columns=['p','q', 'aic', 'bic', 'mae','mse', 'rmse'])

# %%
# Sort by AIC
print(order_df.sort_values('aic'))
# Out:
#     p  q          aic          bic          mae           mse         rmse
# 10  5  0  1155.815606  1174.203067  1519.272467  4.175902e+06  2043.502303
# 2   1  0  1155.962481  1166.177738   831.141500  7.815916e+05   884.076686
# 6   3  0  1156.724941  1171.026300   561.431734  4.133951e+05   642.958072
# 1   0  1  1157.029392  1167.244648   906.129248  9.547131e+05   977.094194
# 8   4  0  1157.296630  1173.641040  1173.981339  2.382565e+06  1543.555997
# 11  5  1  1157.390229  1177.820742  1283.920312  4.067837e+06  2016.887851
# 4   2  0  1157.982653  1170.240961   834.004473  7.901668e+05   888.913297
# 3   1  1  1158.042789  1170.301097   833.493902  7.879811e+05   887.683012
# 9   4  1  1158.873298  1177.260760  1083.220279  1.797822e+06  1340.828719
# 7   3  1  1159.556483  1175.900893   494.867434  3.025201e+05   550.018285
# 5   2  1  1166.123041  1180.424399   717.244262  5.909591e+05   768.738640
# 0   0  0  1334.234454  1342.406659   716.949244  5.905656e+05   768.482648

# %%
m_arima= ARIMA(train['Sales'], order=(5,0,0), exog=train[['Market Size','Marketing Expense']])
model_arima=m_arima.fit()
print(model_arima.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Sales   No. Observations:                   57
# Model:                 ARIMA(5, 0, 0)   Log Likelihood                -568.908
# Date:                Tue, 14 May 2024   AIC                           1155.816
# Time:                        20:14:16   BIC                           1174.203
# Sample:                    01-01-2019   HQIC                          1162.962
#                          - 09-01-2023
# Covariance Type:                  opg
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               5.32e+04   2.57e-06   2.07e+10      0.000    5.32e+04    5.32e+04
# Market Size          -0.0002      0.000     -0.585      0.559      -0.001       0.000
# Marketing Expense     0.0047      0.006      0.834      0.404      -0.006       0.016
# ar.L1                -0.3234      0.110     -2.950      0.003      -0.538      -0.109
# ar.L2                 0.1311      0.159      0.825      0.410      -0.180       0.443
# ar.L3                 0.2137      0.146      1.466      0.143      -0.072       0.499
# ar.L4                -0.2304      0.173     -1.328      0.184      -0.570       0.110
# ar.L5                -0.2643      0.194     -1.360      0.174      -0.645       0.117
# sigma2             2.882e+07   8.74e-10    3.3e+16      0.000    2.88e+07    2.88e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):                29.35
# Prob(Q):                              0.75   Prob(JB):                         0.00
# Heteroskedasticity (H):               7.84   Skew:                            -0.60
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.98e+31. Standard errors may be unstable.

# %%
residuals= model_arima.resid[1:]
fig,ax=plt.subplots(1,2, figsize=(14, 6))
residuals.plot(title='Residuals',ax=ax[0])
residuals.plot(title='Density',kind='kde',ax=ax[1])
plt.show()

# %%
# Plot ACF and PACF
plt.figure(figsize=(12, 6))
plt.subplot(211)
plot_acf(residuals, lags=20, ax=plt.gca())
plt.title('Autocorrelation Function (ACF)- Residuals')

plt.subplot(212)
plot_pacf(residuals, lags=20, ax=plt.gca())
plt.title('Partial Autocorrelation Function (PACF) - Residuals')

plt.tight_layout()
plt.show()

# %%
# Create the 4 diagostics plots
model_arima.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
#pred_in_sample = model_arima.get_prediction(start=len(train), end=(len(sales_b)-1))
#sales_b['Forecast_ARIMA_p']=[None]*len(train) + list(pred)

# %%
#plt.figure(figsize=(12, 8))
#sns.lineplot(sales_b[['Sales','Forecast_ARIMA_p']])
#plt.title('Product B')
#plt.show()

# %%
pred=model_arima.predict(start=len(train), end=(len(sales_a)-1), exog=test[['Market Size','Marketing Expense']], dynamic = True)
sales_a['Forecast_ARIMA']=[None]*len(train) + list(pred)
#sales_b.plot()

# %%
#pred=model_arima.forecast(steps= len(test))
#sales_b['Forecast_ARIMA']=[None]*len(train) + list(pred)
#sales_b.plot()

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(sales_a[['Sales','Forecast_ARIMA']])
plt.title('Product A')
plt.show()

# %%
mae_arima= mean_absolute_error(test['Sales'],pred)
mse_arima=mean_squared_error(test['Sales'], pred)
mape_arima= mean_absolute_percentage_error(test['Sales'],pred)
rmse_arima= np.sqrt(mean_squared_error(test['Sales'],pred))

print(f'MAE - ARIMA: {mae_arima}')
print(f'MAPE - ARIMA: {mape_arima}')
print(f'MSE - ARIMA: {mse_arima}')
print(f'RMSE - ARIMA: {rmse_arima}')
# Out:
# MAE - ARIMA: 1519.2724667956718
# MAPE - ARIMA: 0.027454542369956533
# MSE - ARIMA: 4175901.661372002
# RMSE - ARIMA: 2043.5023027567163

# %% [markdown]
# # SARIMA

# %%
import statsmodels.api as sm

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Perform seasonal decomposition
decomposition = seasonal_decompose(sales_a['Sales'], model='additive', period=12)

# Plot the decomposition
#fig = decomposition.plot(figsize=(12,8))
#plt.show()
# Create a new figure with the specified size
plt.figure(figsize=(12, 8))

# Plot each component separately
plt.subplot(411)
plt.plot(decomposition.observed, label='Observed')
plt.legend()

plt.subplot(412)
plt.plot(decomposition.trend, label='Trend')
plt.legend()

plt.subplot(413)
plt.plot(decomposition.seasonal, label='Seasonal')
plt.legend()

plt.subplot(414)
plt.plot(decomposition.resid, label='Residual')
plt.legend()

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
# Plot ACF and PACF
plt.figure(figsize=(12, 6))
plt.subplot(211)
plot_acf(sales_a['Sales'], lags=24, ax=plt.gca())
plt.title('Autocorrelation Function (ACF) - Original Data')

plt.subplot(212)
plot_pacf(sales_a['Sales'], lags=24, ax=plt.gca())
plt.title('Partial Autocorrelation Function (PACF) - Original Data')

plt.tight_layout()
plt.show()

# %%
order_SARIMAX=[]
# Loop over P order
for P in range(6):
    # Loop over Q order
    for Q in range(2):
        # Fit model
        model_s = sm.tsa.statespace.SARIMAX(train['Sales'], order=(5, 0, 0), seasonal_order=(P, 1, Q, 12),exog=train[['Market Size','Marketing Expense']])
        model_test_s = model_s.fit() 
        pred = model_test_s.predict(start=57, end=59, dynamic=True, exog=test[['Market Size','Marketing Expense']])
        mae = mean_absolute_error(test['Sales'], pred)
        mse = mean_squared_error(test['Sales'], pred)
        # Add order and scores to list        
        order_SARIMAX.append((P, Q, model_test_s.aic, model_test_s.bic, mae, mse))

# Make DataFrame of model order and scores
order_SARIMAX_df = pd.DataFrame(order_SARIMAX, columns=['P', 'Q', 'aic', 'bic', 'mae', 'mse'])

# %%
# Sort by AIC
print(order_SARIMAX_df.sort_values('aic'))
# Out:
#     P  Q         aic         bic          mae           mse
# 0   0  0  941.470821  955.924121   600.848726  3.674089e+05
# 1   0  1  943.371815  959.631778   322.007326  1.519808e+05
# 2   1  0  944.098058  960.358021   447.080347  2.237739e+05
# 3   1  1  945.154847  963.221472   564.738958  3.987468e+05
# 4   2  0  945.322732  963.389357   289.934141  1.200659e+05
# 6   3  0  946.469340  966.342628   944.732918  9.402405e+05
# 8   4  0  947.298660  968.978610   937.861406  8.842854e+05
# 5   2  1  947.493785  967.367072   550.630577  3.097719e+05
# 10  5  0  948.117098  971.603710  2045.981125  4.918032e+06
# 7   3  1  948.413371  970.093321   959.718012  1.006592e+06
# 9   4  1  950.687467  974.174079   987.039359  9.810002e+05
# 11  5  1  952.175107  977.468382  1349.229146  2.205122e+06

# %%
sarima=sm.tsa.statespace.SARIMAX(train['Sales'],order=(4, 0, 0),seasonal_order=(0,0,0,12),exog=train[['Market Size','Marketing Expense']])
sarima_model=sarima.fit()
print(sarima_model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Sales   No. Observations:                   57
# Model:               SARIMAX(4, 0, 0)   Log Likelihood                -606.144
# Date:                Tue, 14 May 2024   AIC                           1226.287
# Time:                        20:19:16   BIC                           1240.589
# Sample:                    01-01-2019   HQIC                          1231.845
#                          - 09-01-2023
# Covariance Type:                  opg
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Market Size           0.0006      0.002      0.224      0.823      -0.004       0.005
# Marketing Expense     0.0014      0.035      0.040      0.968      -0.066       0.069
# ar.L1                -0.1924      0.521     -0.369      0.712      -1.213       0.828
# ar.L2                 0.6234      0.499      1.250      0.211      -0.354       1.601
# ar.L3                 0.4370      0.535      0.817      0.414      -0.612       1.486
# ar.L4                 0.1121      0.677      0.166      0.868      -1.215       1.439
# sigma2             2.061e+08   6.87e-10      3e+17      0.000    2.06e+08    2.06e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.22   Jarque-Bera (JB):                 7.18
# Prob(Q):                              0.64   Prob(JB):                         0.03
# Heteroskedasticity (H):               3.77   Skew:                            -0.43
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.68e+34. Standard errors may be unstable.

# %%
sarima_model.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
forecast_test_sarima=sarima_model.predict(start=57, end=59, dynamic=True, exog=test[['Market Size','Marketing Expense']])

# %%
sales_a['Forecast_SARIMA']=[None]*len(train)+ list(forecast_test_sarima)
#sales_b[['Sales','Forecast_SARIMA']].plot(figsize=(12,8))

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(sales_a[['Sales','Forecast_SARIMA']])
plt.title('Product A')
# Out:
# Text(0.5, 1.0, 'Product A')

# %%
mae_sarima= mean_absolute_error(test['Sales'],forecast_test_sarima)
mape_sarima= mean_absolute_percentage_error(test['Sales'],forecast_test_sarima)
mse_sarima=mean_squared_error(test['Sales'], forecast_test_sarima)
rmse_sarima= np.sqrt(mean_squared_error(test['Sales'],forecast_test_sarima))

print(f'MAE - SARIMA: {round(mae_sarima,3)}')
print(f'MAPE - SARIMA: {round(mape_sarima,3)}')
print(f'MSE - SARIMA: {round(mse_sarima,3)}')
print(f'RMSE - SARIMA: {round(rmse_sarima,3)}')
# Out:
# MAE - SARIMA: 670.152
# MAPE - SARIMA: 0.012
# MSE - SARIMA: 861963.835
# RMSE - SARIMA: 928.42

# %% [markdown]
# # AUTO-ARIMA

# %%
import pmdarima as pm

# %%
auto_arima= pm.auto_arima(train['Sales'], start_p=0,  start_q=0, max_p=6,max_q=2,
                          start_P=0, start_Q=0, max_P=6 ,max_Q=2 ,  
                          stepwise=False, trace=True,
                          seasonal=True,m=12, exogenous=train[['Market Size','Marketing Expense']])
auto_arima
# Out:
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=1156.237, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : AIC=1158.081, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,2)[12] intercept   : AIC=1159.936, Time=0.08 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : AIC=1158.236, Time=0.10 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(0,0,0)(1,0,2)[12] intercept   : AIC=1161.936, Time=0.25 sec
#  ARIMA(0,0,0)(2,0,0)[12] intercept   : AIC=1159.954, Time=0.13 sec
#  ARIMA(0,0,0)(2,0,1)[12] intercept   : AIC=1161.953, Time=0.58 sec
#  ARIMA(0,0,0)(2,0,2)[12] intercept   : AIC=1163.931, Time=0.50 sec
#  ARIMA(0,0,0)(3,0,0)[12] intercept   : AIC=1161.702, Time=0.67 sec
#  ARIMA(0,0,0)(3,0,1)[12] intercept   : AIC=1163.625, Time=1.11 sec
#  ARIMA(0,0,0)(3,0,2)[12] intercept   : AIC=1165.120, Time=3.60 sec
#  ARIMA(0,0,0)(4,0,0)[12] intercept   : AIC=1163.558, Time=4.94 sec
#  ARIMA(0,0,0)(4,0,1)[12] intercept   : AIC=1165.052, Time=9.45 sec
#  ARIMA(0,0,0)(5,0,0)[12] intercept   : AIC=1165.220, Time=8.20 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=1154.134, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=1155.758, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,2)[12] intercept   : AIC=1157.756, Time=0.22 sec
#  ARIMA(0,0,1)(1,0,0)[12] intercept   : AIC=1156.126, Time=0.28 sec
#  ARIMA(0,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(0,0,1)(1,0,2)[12] intercept   : AIC=1159.744, Time=0.37 sec
#  ARIMA(0,0,1)(2,0,0)[12] intercept   : AIC=1157.943, Time=0.26 sec
#  ARIMA(0,0,1)(2,0,1)[12] intercept   : AIC=1159.742, Time=0.63 sec
#  ARIMA(0,0,1)(2,0,2)[12] intercept   : AIC=1161.719, Time=1.73 sec
#  ARIMA(0,0,1)(3,0,0)[12] intercept   : AIC=1159.942, Time=1.46 sec
#  ARIMA(0,0,1)(3,0,1)[12] intercept   : AIC=1161.693, Time=1.82 sec
#  ARIMA(0,0,1)(4,0,0)[12] intercept   : AIC=1161.896, Time=4.77 sec
#  ARIMA(0,0,2)(0,0,0)[12] intercept   : AIC=1152.907, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,1)[12] intercept   : AIC=1154.499, Time=0.07 sec
#  ARIMA(0,0,2)(0,0,2)[12] intercept   : AIC=1156.458, Time=0.23 sec
#  ARIMA(0,0,2)(1,0,0)[12] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(0,0,2)(1,0,1)[12] intercept   : AIC=1166.612, Time=0.64 sec
#  ARIMA(0,0,2)(1,0,2)[12] intercept   : AIC=1158.416, Time=0.57 sec
#  ARIMA(0,0,2)(2,0,0)[12] intercept   : AIC=1156.489, Time=0.27 sec
#  ARIMA(0,0,2)(2,0,1)[12] intercept   : AIC=1158.422, Time=0.63 sec
#  ARIMA(0,0,2)(3,0,0)[12] intercept   : AIC=1158.473, Time=1.54 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=1153.316, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=1154.866, Time=0.11 sec
#  ARIMA(1,0,0)(0,0,2)[12] intercept   : AIC=1156.865, Time=0.23 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=1155.197, Time=0.25 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.39 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=1158.862, Time=0.50 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=1157.065, Time=0.42 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=1158.860, Time=0.74 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=1160.849, Time=1.55 sec
#  ARIMA(1,0,0)(3,0,0)[12] intercept   : AIC=1159.052, Time=1.26 sec
#  ARIMA(1,0,0)(3,0,1)[12] intercept   : AIC=1160.834, Time=2.03 sec
#  ARIMA(1,0,0)(4,0,0)[12] intercept   : AIC=1161.015, Time=6.62 sec
#  ARIMA(1,0,1)(0,0,0)[12] intercept   : AIC=1156.588, Time=0.08 sec
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : AIC=1158.237, Time=0.18 sec
#  ARIMA(1,0,1)(0,0,2)[12] intercept   : AIC=1160.236, Time=0.38 sec
#  ARIMA(1,0,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.53 sec
#  ARIMA(1,0,1)(1,0,2)[12] intercept   : AIC=1160.825, Time=1.20 sec
#  ARIMA(1,0,1)(2,0,0)[12] intercept   : AIC=1159.365, Time=0.73 sec
#  ARIMA(1,0,1)(2,0,1)[12] intercept   : AIC=1160.829, Time=1.01 sec
#  ARIMA(1,0,1)(3,0,0)[12] intercept   : AIC=1160.997, Time=1.95 sec
#  ARIMA(1,0,2)(0,0,0)[12] intercept   : AIC=1155.723, Time=0.13 sec
#  ARIMA(1,0,2)(0,0,1)[12] intercept   : AIC=1157.237, Time=0.28 sec
#  ARIMA(1,0,2)(0,0,2)[12] intercept   : AIC=1159.220, Time=0.65 sec
#  ARIMA(1,0,2)(1,0,0)[12] intercept   : AIC=1161.548, Time=0.78 sec
#  ARIMA(1,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=1.14 sec
#  ARIMA(1,0,2)(2,0,0)[12] intercept   : AIC=1159.087, Time=0.90 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=1155.328, Time=0.22 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=1156.888, Time=0.27 sec
#  ARIMA(2,0,0)(0,0,2)[12] intercept   : AIC=1158.888, Time=0.87 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=1157.094, Time=0.43 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=1162.212, Time=1.08 sec
#  ARIMA(2,0,0)(1,0,2)[12] intercept   : AIC=1160.887, Time=0.70 sec
#  ARIMA(2,0,0)(2,0,0)[12] intercept   : AIC=1159.042, Time=0.63 sec
#  ARIMA(2,0,0)(2,0,1)[12] intercept   : AIC=1160.886, Time=1.10 sec
#  ARIMA(2,0,0)(3,0,0)[12] intercept   : AIC=1161.037, Time=1.43 sec
#  ARIMA(2,0,1)(0,0,0)[12] intercept   : AIC=1157.122, Time=0.14 sec
#  ARIMA(2,0,1)(0,0,1)[12] intercept   : AIC=1158.635, Time=0.37 sec
#  ARIMA(2,0,1)(0,0,2)[12] intercept   : AIC=1160.633, Time=0.60 sec
#  ARIMA(2,0,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.76 sec
#  ARIMA(2,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.86 sec
#  ARIMA(2,0,1)(2,0,0)[12] intercept   : AIC=1160.703, Time=1.26 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=1150.633, Time=0.48 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=1152.435, Time=0.60 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=inf, Time=0.89 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : AIC=1153.531, Time=0.13 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=1155.030, Time=0.35 sec
#  ARIMA(3,0,0)(0,0,2)[12] intercept   : AIC=1157.006, Time=0.41 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=1155.141, Time=0.46 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.67 sec
#  ARIMA(3,0,0)(2,0,0)[12] intercept   : AIC=1157.141, Time=0.83 sec
#  ARIMA(3,0,1)(0,0,0)[12] intercept   : AIC=1155.353, Time=0.22 sec
#  ARIMA(3,0,1)(0,0,1)[12] intercept   : AIC=1156.949, Time=0.40 sec
#  ARIMA(3,0,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.80 sec
#  ARIMA(3,0,2)(0,0,0)[12] intercept   : AIC=1152.720, Time=0.52 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : AIC=1154.046, Time=0.32 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : AIC=1155.944, Time=0.27 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : AIC=1155.997, Time=0.52 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : AIC=1155.619, Time=0.25 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : AIC=1153.246, Time=0.30 sec
#
# Best model:  ARIMA(2,0,2)(0,0,0)[12] intercept
# Total fit time: 90.115 seconds
# ARIMA(order=(2, 0, 2), scoring_args={}, seasonal_order=(0, 0, 0, 12),
#       suppress_warnings=True)

# %%
auto_arima.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   57
# Model:               SARIMAX(2, 0, 2)   Log Likelihood                -569.317
# Date:                Tue, 14 May 2024   AIC                           1150.633
# Time:                        20:21:25   BIC                           1162.892
# Sample:                    01-01-2019   HQIC                          1155.397
#                          - 09-01-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   8.622e+04   1.49e+04      5.779      0.000     5.7e+04    1.15e+05
# ar.L1         -0.0526      0.143     -0.368      0.713      -0.333       0.228
# ar.L2         -0.5576      0.195     -2.865      0.004      -0.939      -0.176
# ma.L1         -0.2260      0.109     -2.065      0.039      -0.441      -0.012
# ma.L2          0.9662      0.167      5.793      0.000       0.639       1.293
# sigma2      3.192e+07      4.729   6.75e+06      0.000    3.19e+07    3.19e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                11.28
# Prob(Q):                              0.89   Prob(JB):                         0.00
# Heteroskedasticity (H):               6.06   Skew:                            -0.63
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.17e+24. Standard errors may be unstable.
# """

# %%
auto_arima.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
forecast_test_auto= auto_arima.predict(n_periods=len(test), exogenous=test[['Market Size','Marketing Expense']])
sales_a['Forecast_AUTO ARIMA']=[None]*len(train)+ list(forecast_test_auto)
#sales_b[['Sales','Forecast_AUTO ARIMA']].plot()

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(sales_a[['Sales','Forecast_AUTO ARIMA']])
plt.title('Product A')
# Out:
# Text(0.5, 1.0, 'Product A')

# %%
mae_auto_arima= mean_absolute_error(test['Sales'],forecast_test_auto)
mape_auto_arima= mean_absolute_percentage_error(test['Sales'],forecast_test_auto)
mse_auto_arima=mean_squared_error(test['Sales'],forecast_test_auto)
rmse_auto_arima= np.sqrt(mean_squared_error(test['Sales'],forecast_test_auto))

print(f'MAE - AUTO ARIMA: {mae_auto_arima}')
print(f'MAPE - AUTO ARIMA: {mape_auto_arima}')
print(f'MSE - AUTO ARIMA: {mse_auto_arima}')
print(f'RMSE - AUTO ARIMA: {rmse_auto_arima}')
# Out:
# MAE - AUTO ARIMA: 3150.4133390134252
# MAPE - AUTO ARIMA: 0.05688777458750194
# MSE - AUTO ARIMA: 11038162.117146365
# RMSE - AUTO ARIMA: 3322.3729647868204

# %%
sales_a.tail(12)
# Out:
#             Sales  Market Size  Marketing Expense  Forecast_ARIMA  \
# Month-Year
# 2023-01-01  63171      2955148             236101             NaN
# 2023-02-01  31168     10151977             811092             NaN
# 2023-03-01  70380      5636182             450302             NaN
# 2023-04-01  53078      9134343             729788             NaN
# 2023-05-01  43741      3980872             318051             NaN
# 2023-06-01  63919      9490711             758260             NaN
# 2023-07-01  54485      5339196             426575             NaN
# 2023-08-01  54869      9714819             776165             NaN
# 2023-09-01  55607      5938316             474441             NaN
# 2023-10-01  55575      9714819             776165    55045.428412
# 2023-11-01  55311      6133652             490048    51859.192018
# 2023-12-01  55281      9910156             791771    55857.437831
#
#             Forecast_SARIMA  Forecast_AUTO ARIMA
# Month-Year
# 2023-01-01              NaN                  NaN
# 2023-02-01              NaN                  NaN
# 2023-03-01              NaN                  NaN
# 2023-04-01              NaN                  NaN
# 2023-05-01              NaN                  NaN
# 2023-06-01              NaN                  NaN
# 2023-07-01              NaN                  NaN
# 2023-08-01              NaN                  NaN
# 2023-09-01              NaN                  NaN
# 2023-10-01     55413.870076         58550.459469
# 2023-11-01     53734.445701         53356.320630
# 2023-12-01     55553.773158         50759.898822

# %%
sales_a.mean()
# Out:
# Sales                  5.356653e+04
# Market Size            6.014570e+06
# Marketing Expense      3.312196e+05
# Forecast_ARIMA         5.425402e+04
# Forecast_SARIMA        5.490070e+04
# Forecast_AUTO ARIMA    5.422223e+04
# dtype: float64

# %%
sales_a.tail(12)
# Out:
#             Sales  Market Size  Marketing Expense  Forecast_ARIMA  \
# Month-Year
# 2023-01-01  63171      2955148             236101             NaN
# 2023-02-01  31168     10151977             811092             NaN
# 2023-03-01  70380      5636182             450302             NaN
# 2023-04-01  53078      9134343             729788             NaN
# 2023-05-01  43741      3980872             318051             NaN
# 2023-06-01  63919      9490711             758260             NaN
# 2023-07-01  54485      5339196             426575             NaN
# 2023-08-01  54869      9714819             776165             NaN
# 2023-09-01  55607      5938316             474441             NaN
# 2023-10-01  55575      9714819             776165    55045.428412
# 2023-11-01  55311      6133652             490048    51859.192018
# 2023-12-01  55281      9910156             791771    55857.437831
#
#             Forecast_SARIMA  Forecast_AUTO ARIMA
# Month-Year
# 2023-01-01              NaN                  NaN
# 2023-02-01              NaN                  NaN
# 2023-03-01              NaN                  NaN
# 2023-04-01              NaN                  NaN
# 2023-05-01              NaN                  NaN
# 2023-06-01              NaN                  NaN
# 2023-07-01              NaN                  NaN
# 2023-08-01              NaN                  NaN
# 2023-09-01              NaN                  NaN
# 2023-10-01     55413.870076         58550.459469
# 2023-11-01     53734.445701         53356.320630
# 2023-12-01     55553.773158         50759.898822

# %%
data = {
    'model': ['ARIMAX', 'AUTO ARIMAX', 'SEASONAL ARIMAX'],
    'MAE': [mae_arima, mae_auto_arima, mae_sarima],  
    'MAPE': [mape_arima, mape_auto_arima, mape_sarima],  
    'MSE': [mse_arima, mse_auto_arima, mse_sarima],  
    'RMSE': [rmse_arima, rmse_auto_arima, rmse_sarima]  
}

model_results = pd.DataFrame(data)
model_results.set_index('model', inplace=True)
model_results
# Out:
#                          MAE      MAPE           MSE         RMSE
# model
# ARIMAX           1519.272467  0.027455  4.175902e+06  2043.502303
# AUTO ARIMAX      3150.413339  0.056888  1.103816e+07  3322.372965
# SEASONAL ARIMAX   670.152460  0.012112  8.619638e+05   928.420075

# %% [markdown]
# # TESTING

# %%
auto_arima_1= pm.auto_arima(train['Sales'], start_p=0, start_q=0, max_p=5,max_q=3,
                          start_P=0, start_Q=0, max_P=2 ,max_Q=2 ,  
                          stepwise=False, trace=True,
                          seasonal=True,m=12, exogenous=train[['Market Size','Marketing Expense']])
auto_arima_1
# Out:
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=1374.393, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=1376.384, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,2)[12] intercept   : AIC=1377.119, Time=0.16 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=1376.387, Time=0.06 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=1378.263, Time=0.10 sec
#  ARIMA(0,1,0)(1,0,2)[12] intercept   : AIC=1378.671, Time=0.23 sec
#  ARIMA(0,1,0)(2,0,0)[12] intercept   : AIC=1377.144, Time=0.09 sec
#  ARIMA(0,1,0)(2,0,1)[12] intercept   : AIC=1378.530, Time=0.22 sec
#  ARIMA(0,1,0)(2,0,2)[12] intercept   : AIC=1380.459, Time=0.51 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=1350.206, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=1350.297, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,2)[12] intercept   : AIC=1351.489, Time=0.18 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=1352.086, Time=0.10 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(0,1,1)(1,0,2)[12] intercept   : AIC=inf, Time=0.95 sec
#  ARIMA(0,1,1)(2,0,0)[12] intercept   : AIC=1348.440, Time=0.12 sec
#  ARIMA(0,1,1)(2,0,1)[12] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(0,1,1)(2,0,2)[12] intercept   : AIC=inf, Time=0.59 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=1344.726, Time=0.04 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=1342.778, Time=0.08 sec
#  ARIMA(0,1,2)(0,0,2)[12] intercept   : AIC=1344.706, Time=0.19 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=1346.439, Time=0.07 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(0,1,2)(1,0,2)[12] intercept   : AIC=inf, Time=0.81 sec
#  ARIMA(0,1,2)(2,0,0)[12] intercept   : AIC=1345.302, Time=0.14 sec
#  ARIMA(0,1,2)(2,0,1)[12] intercept   : AIC=inf, Time=0.71 sec
#  ARIMA(0,1,3)(0,0,0)[12] intercept   : AIC=1340.947, Time=0.06 sec
#  ARIMA(0,1,3)(0,0,1)[12] intercept   : AIC=1340.085, Time=0.07 sec
#  ARIMA(0,1,3)(0,0,2)[12] intercept   : AIC=1342.075, Time=0.24 sec
#  ARIMA(0,1,3)(1,0,0)[12] intercept   : AIC=1342.699, Time=0.08 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(0,1,3)(2,0,0)[12] intercept   : AIC=1342.470, Time=0.18 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=1349.586, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=1349.307, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,2)[12] intercept   : AIC=1350.244, Time=0.17 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=1350.109, Time=0.07 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=1350.220, Time=0.11 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=1352.127, Time=0.26 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=1351.149, Time=0.14 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=1352.091, Time=0.29 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=1354.150, Time=0.45 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=1338.439, Time=0.07 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=1336.463, Time=0.13 sec
#  ARIMA(1,1,1)(0,0,2)[12] intercept   : AIC=1337.997, Time=0.35 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=1339.776, Time=0.13 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=inf, Time=0.73 sec
#  ARIMA(1,1,1)(2,0,0)[12] intercept   : AIC=1338.057, Time=0.37 sec
#  ARIMA(1,1,1)(2,0,1)[12] intercept   : AIC=inf, Time=0.62 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=1345.546, Time=0.07 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=1342.264, Time=0.11 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=inf, Time=0.43 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=1347.053, Time=0.11 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=1344.034, Time=0.28 sec
#  ARIMA(1,1,3)(0,0,0)[12] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(1,1,3)(0,0,1)[12] intercept   : AIC=1337.310, Time=0.17 sec
#  ARIMA(1,1,3)(1,0,0)[12] intercept   : AIC=1338.840, Time=0.17 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=1344.947, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,1)[12] intercept   : AIC=1344.986, Time=0.07 sec
#  ARIMA(2,1,0)(0,0,2)[12] intercept   : AIC=1346.210, Time=0.21 sec
#  ARIMA(2,1,0)(1,0,0)[12] intercept   : AIC=1345.461, Time=0.07 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(2,1,0)(1,0,2)[12] intercept   : AIC=inf, Time=0.54 sec
#  ARIMA(2,1,0)(2,0,0)[12] intercept   : AIC=1346.689, Time=0.18 sec
#  ARIMA(2,1,0)(2,0,1)[12] intercept   : AIC=inf, Time=0.51 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=1337.275, Time=0.09 sec
#  ARIMA(2,1,1)(0,0,1)[12] intercept   : AIC=1336.804, Time=0.10 sec
#  ARIMA(2,1,1)(0,0,2)[12] intercept   : AIC=1338.555, Time=0.26 sec
#  ARIMA(2,1,1)(1,0,0)[12] intercept   : AIC=1338.580, Time=0.11 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(2,1,1)(2,0,0)[12] intercept   : AIC=1338.613, Time=0.30 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=inf, Time=0.42 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(2,1,3)(0,0,0)[12] intercept   : AIC=1339.149, Time=0.16 sec
#  ARIMA(3,1,0)(0,0,0)[12] intercept   : AIC=1337.080, Time=0.06 sec
#  ARIMA(3,1,0)(0,0,1)[12] intercept   : AIC=1336.830, Time=0.09 sec
#  ARIMA(3,1,0)(0,0,2)[12] intercept   : AIC=1338.626, Time=0.20 sec
#  ARIMA(3,1,0)(1,0,0)[12] intercept   : AIC=1336.997, Time=0.08 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=1338.764, Time=0.17 sec
#  ARIMA(3,1,0)(2,0,0)[12] intercept   : AIC=1338.788, Time=0.24 sec
#  ARIMA(3,1,1)(0,0,0)[12] intercept   : AIC=1335.579, Time=0.18 sec
#  ARIMA(3,1,1)(0,0,1)[12] intercept   : AIC=1335.120, Time=0.12 sec
#  ARIMA(3,1,1)(1,0,0)[12] intercept   : AIC=1335.640, Time=0.12 sec
#  ARIMA(3,1,2)(0,0,0)[12] intercept   : AIC=1338.465, Time=0.10 sec
#  ARIMA(4,1,0)(0,0,0)[12] intercept   : AIC=1336.387, Time=0.05 sec
#  ARIMA(4,1,0)(0,0,1)[12] intercept   : AIC=1335.684, Time=0.11 sec
#  ARIMA(4,1,0)(1,0,0)[12] intercept   : AIC=1335.472, Time=0.10 sec
#  ARIMA(4,1,1)(0,0,0)[12] intercept   : AIC=1338.141, Time=0.13 sec
#  ARIMA(5,1,0)(0,0,0)[12] intercept   : AIC=1338.208, Time=0.06 sec
#
# Best model:  ARIMA(3,1,1)(0,0,1)[12] intercept
# Total fit time: 20.067 seconds
# ARIMA(order=(3, 1, 1), scoring_args={}, seasonal_order=(0, 0, 1, 12),
#       suppress_warnings=True)

# %%
auto_arima_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                   48
# Model:             SARIMAX(3, 1, 1)x(0, 0, 1, 12)   Log Likelihood                -660.560
# Date:                            Wed, 08 May 2024   AIC                           1335.120
# Time:                                    18:26:04   BIC                           1348.071
# Sample:                                01-01-2019   HQIC                          1339.994
#                                      - 12-01-2022
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   4.218e+04   2.76e+04      1.529      0.126   -1.19e+04    9.63e+04
# ar.L1         -0.7728      0.212     -3.647      0.000      -1.188      -0.358
# ar.L2         -0.4947      0.256     -1.934      0.053      -0.996       0.007
# ar.L3         -0.3294      0.161     -2.051      0.040      -0.644      -0.015
# ma.L1         -0.6157      0.175     -3.516      0.000      -0.959      -0.272
# ma.S.L12       0.3138      0.234      1.340      0.180      -0.145       0.773
# sigma2       8.38e+10      0.007   1.17e+13      0.000    8.38e+10    8.38e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.70   Jarque-Bera (JB):                 0.90
# Prob(Q):                              0.40   Prob(JB):                         0.64
# Heteroskedasticity (H):               1.03   Skew:                            -0.17
# Prob(H) (two-sided):                  0.96   Kurtosis:                         2.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.21e+29. Standard errors may be unstable.
# """

# %%
forecast_test_auto_1= auto_arima_1.predict(n_periods=len(test), exogenous=test[['Market Size','Marketing Expense']])
sales_b['Forecast_AUTO ARIMA_1']=[None]*len(train)+ list(forecast_test_auto_1)

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(sales_b[['Sales','Forecast_AUTO ARIMA_1']])
plt.title('Product B')
# Out:
# Text(0.5, 1.0, 'Product B')

# %%
mae_auto_arima_1= mean_absolute_error(test['Sales'],forecast_test_auto_1)
mape_auto_arima_1= mean_absolute_percentage_error(test['Sales'],forecast_test_auto_1)
mse_auto_arima_1=mean_squared_error(test['Sales'],forecast_test_auto_1)
rmse_auto_arima_1= np.sqrt(mean_squared_error(test['Sales'],forecast_test_auto_1))

print(f'MAE - AUTO ARIMA: {mae_auto_arima_1}')
print(f'MAPE - AUTO ARIMA: {mape_auto_arima_1}')
print(f'MSE - AUTO ARIMA: {mse_auto_arima_1}')
print(f'RMSE - AUTO ARIMA: {rmse_auto_arima_1}')
# Out:
# MAE - AUTO ARIMA: 361595.78675793833
# MAPE - AUTO ARIMA: 0.4301972486948735
# MSE - AUTO ARIMA: 201684310197.0093
# RMSE - AUTO ARIMA: 449092.7634654218
